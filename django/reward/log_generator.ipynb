# %% [markdown]
# # 시나리오 기반 보상 시스템 테스트 계획서

# %% [markdown]
# ## 개요
#
# 보상 로그를 다양한 방식으로 생성하고 보상룰을 설정하고 테스트한다.

# %%
from datetime import datetime, timedelta
import random

# %% [markdown]
# **시작 시간** ISO시간으로 설정 '2021-04-01T00:00:00+09:00'
# **로그 기간** 30일로 설정 `days=30`

# %%
#start_dt = datetime.fromisoformat('2021-04-01T00:00:00+09:00')
start_dt = datetime.fromisoformat('2021-04-01T00:00:00')
t_total = timedelta(days=30)
end_dt = start_dt + t_total
print(start_dt.isoformat(), end_dt.isoformat())
# Out:
# 2021-04-01T00:00:00 2021-05-01T00:00:00

# %% [markdown]
# ## 시나리오 1
#
# **소규모 데이터셋 생성**

# %%
n_user = 10            # 총 사용자 수
n_news = 100           # 뉴스 글 갯수
n_post = 30            # 일반 글 갯수

n_view = 100           # 총 조회수
n_reply = 100          # 총 댓글수
n_rereply = 100        # 총 대댓글 수
n_reaction = 100       # 총 reaction 수(본문)
n_reaction_reply = 100 # 댓글 reaction 갯수

n_best = 10            # 우수 콘텐츠 수
n_bookmark = 10        # bookmark
n_share = 10           # bookmark

# group 생성
groups = ['press', 'community']
group_share = [ 0.2, 0.8 ]

# 그룹 별 뉴스 생성 비율, post생성 비율
news_share = [ 0.9, 0.1 ]
post_share = [ 0.1, 0.9 ]


n_login = 100          # 로그인 횟수
n_invitation = 10      # 초대 횟수
n_recommendation = 10  # 추천 횟수

# %% [markdown]
# ## 시나리오 2
#
# **대규모 데이터셋 생성**

# %%
n_user = 100            # 총 사용자 수
n_news = 1000           # 뉴스 글 갯수
n_post = 300            # 일반 글 갯수

n_view = 30000          # 총 조회수
n_reply = 1000          # 총 댓글수
n_rereply = 1000        # 총 대댓글 수
n_reaction = 1000       # 총 reaction 수(본문)
n_reaction_reply = 1000 # 댓글 reaction 갯수

n_best = 10             # 우수 콘텐츠 수
n_bookmark = 100        # bookmark
n_share = 100           # bookmark

# group 생성
groups = ['press', 'community']
group_share = [ 0.2, 0.8 ]

# 그룹 별 뉴스 생성 비율, post생성 비율
news_share = [ 0.9, 0.1 ]
post_share = [ 0.1, 0.9 ]


n_login = 100          # 로그인 횟수
n_invitation = 10      # 초대 횟수
n_recommendation = 10  # 추천 횟수

# %% [markdown]
# **사용자 생성**

# %%
# user 생성
def make_tower(weights):
    #tower_total = sum(weights)
    tower_total = weights[0]
    for i in range(1, len(weights)):
        tower_total += weights[i]
    total = weights[0]
    tower = [total/tower_total]
    for i in range(1, len(weights)):
        total += weights[i]
        tower.append(total/tower_total)
    return tower

def select_tower(tower):
    a = random.uniform(0.0, 1.0)
    for i in range(len(tower)):
        if a < tower[i]:
            return i
    
def create_users(n, group_share):
    users = []
    tower = make_tower(group_share)
    for i in range(n):
        group = groups[select_tower(tower)]
        user = { 'user_id': 'u%06i'%(i+1), 
                 'user_type': group}
        users.append(user)
    return users

users = create_users(n_user, group_share)

# %%
users_by_group = []
for i in range(len(groups)):
    users_by_group.append([])

for user in users:
    for i in range(len(groups)):
        if user['user_type'] == groups[i]:
            break
    users_by_group[i].append(user)

# %%
users_by_group[0]
# Out:
# [{'user_id': 'u000008', 'user_type': 'press'},
#  {'user_id': 'u000009', 'user_type': 'press'},
#  {'user_id': 'u000010', 'user_type': 'press'}]

# %%
users_by_group[1]
# Out:
# [{'user_id': 'u000001', 'user_type': 'community'},
#  {'user_id': 'u000002', 'user_type': 'community'},
#  {'user_id': 'u000003', 'user_type': 'community'},
#  {'user_id': 'u000004', 'user_type': 'community'},
#  {'user_id': 'u000005', 'user_type': 'community'},
#  {'user_id': 'u000006', 'user_type': 'community'},
#  {'user_id': 'u000007', 'user_type': 'community'}]

# %% [markdown]
# **본문 글쓰기 로그 생성**

# %%
def create_article(start_dt, t_total, n_news, n_post, news_share, post_share, users_by_group):
    list_t = []
    n = n_news + n_post
    articles = []
    news_group_tower = make_tower(news_share)
    post_group_tower = make_tower(post_share)
    for i in range(n):
        if (i < n_news):
            article_type = 0 # news
            group = select_tower(news_group_tower)
            prefix = 'COAT'
            content_type = 'article'
        else:
            article_type = 1 # post
            group = select_tower(post_group_tower)
            prefix = 'COPT'
            content_type = 'post'
                   
        user = random.choice(users_by_group[article_type])
        a = random.uniform(0.0, 1.0)
        t = a*t_total
        dt = start_dt + t
        articles.append({
            'timestamp': dt.isoformat(),
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'action_group': user['user_type'], # action group과 user_type의 차이?
            'action': 'create',
            'action_key': user['user_type']+'/create1',
            'log_type': 'content',
            'type_id': prefix,
            'content_type': content_type,
        })
        
    articles = sorted(articles, key=lambda article: (article['timestamp']))
    for i in range(n):
       articles[i]['content_id'] = prefix + '.%04i'%(i+1)
    
        
    return articles

# %%
post_log = create_article(start_dt, t_total, n_news, n_post, news_share, post_share, users_by_group)

# %%
post_log
# Out:
# [{'timestamp': '2021-04-01T12:02:56.993322',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0001'},
#  {'timestamp': '2021-04-02T00:40:07.197579',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0002'},
#  {'timestamp': '2021-04-02T13:25:07.996260',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0003'},
#  {'timestamp': '2021-04-02T14:28:15.091120',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0004'},
#  {'timestamp': '2021-04-02T17:06:04.668087',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0005'},
#  {'timestamp': '2021-04-03T00:37:46.002019',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0006'},
#  {'timestamp': '2021-04-03T08:27:27.185635',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0007'},
#  {'timestamp': '2021-04-03T11:34:22.592077',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0008'},
#  {'timestamp': '2021-04-03T21:23:30.113917',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0009'},
#  {'timestamp': '2021-04-04T00:19:51.528754',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0010'},
#  {'timestamp': '2021-04-04T00:31:28.186438',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0011'},
#  {'timestamp': '2021-04-04T01:31:13.887613',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0012'},
#  {'timestamp': '2021-04-04T13:48:34.556386',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0013'},
#  {'timestamp': '2021-04-04T17:40:44.078489',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0014'},
#  {'timestamp': '2021-04-04T18:16:17.877317',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0015'},
#  {'timestamp': '2021-04-05T03:16:51.791162',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0016'},
#  {'timestamp': '2021-04-05T06:28:27.158041',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0017'},
#  {'timestamp': '2021-04-05T07:27:52.257018',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0018'},
#  {'timestamp': '2021-04-05T09:19:35.077508',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0019'},
#  {'timestamp': '2021-04-05T20:44:15.522996',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0020'},
#  {'timestamp': '2021-04-05T22:05:28.584952',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0021'},
#  {'timestamp': '2021-04-06T02:23:09.721947',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0022'},
#  {'timestamp': '2021-04-06T10:40:47.540914',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0023'},
#  {'timestamp': '2021-04-06T15:17:42.599709',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0024'},
#  {'timestamp': '2021-04-06T16:38:09.911829',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0025'},
#  {'timestamp': '2021-04-06T18:52:43.123834',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0026'},
#  {'timestamp': '2021-04-07T19:44:51.822495',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0027'},
#  {'timestamp': '2021-04-08T03:31:47.831976',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0028'},
#  {'timestamp': '2021-04-08T07:31:57.319638',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0029'},
#  {'timestamp': '2021-04-09T04:37:54.208999',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0030'},
#  {'timestamp': '2021-04-09T05:38:16.710288',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0031'},
#  {'timestamp': '2021-04-09T07:25:11.099298',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0032'},
#  {'timestamp': '2021-04-09T10:47:08.321617',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0033'},
#  {'timestamp': '2021-04-09T15:53:11.623443',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0034'},
#  {'timestamp': '2021-04-09T15:54:13.137535',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0035'},
#  {'timestamp': '2021-04-09T21:36:37.022494',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0036'},
#  {'timestamp': '2021-04-10T08:22:10.459025',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0037'},
#  {'timestamp': '2021-04-10T10:16:03.594913',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0038'},
#  {'timestamp': '2021-04-10T19:02:49.259797',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0039'},
#  {'timestamp': '2021-04-10T21:13:24.008818',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0040'},
#  {'timestamp': '2021-04-11T00:47:19.324424',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0041'},
#  {'timestamp': '2021-04-11T12:15:02.208726',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0042'},
#  {'timestamp': '2021-04-11T23:26:26.833219',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0043'},
#  {'timestamp': '2021-04-12T07:02:28.776717',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0044'},
#  {'timestamp': '2021-04-12T15:12:41.332980',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0045'},
#  {'timestamp': '2021-04-12T19:41:49.194004',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0046'},
#  {'timestamp': '2021-04-12T20:35:56.166762',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0047'},
#  {'timestamp': '2021-04-13T16:14:49.509298',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0048'},
#  {'timestamp': '2021-04-13T16:31:00.595728',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0049'},
#  {'timestamp': '2021-04-14T03:46:15.101383',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0050'},
#  {'timestamp': '2021-04-14T05:24:00.807524',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0051'},
#  {'timestamp': '2021-04-14T06:23:29.129262',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0052'},
#  {'timestamp': '2021-04-14T10:06:26.916757',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0053'},
#  {'timestamp': '2021-04-14T11:06:24.796258',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0054'},
#  {'timestamp': '2021-04-14T11:48:33.129933',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0055'},
#  {'timestamp': '2021-04-14T12:05:29.871155',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0056'},
#  {'timestamp': '2021-04-14T17:11:51.888737',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0057'},
#  {'timestamp': '2021-04-14T19:16:38.043579',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0058'},
#  {'timestamp': '2021-04-14T21:45:30.675364',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0059'},
#  {'timestamp': '2021-04-15T03:06:58.661830',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0060'},
#  {'timestamp': '2021-04-15T04:00:53.090720',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0061'},
#  {'timestamp': '2021-04-15T04:14:22.917386',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0062'},
#  {'timestamp': '2021-04-15T12:04:11.291159',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0063'},
#  {'timestamp': '2021-04-16T01:07:13.878712',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0064'},
#  {'timestamp': '2021-04-16T06:53:54.840550',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0065'},
#  {'timestamp': '2021-04-16T16:42:46.862144',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0066'},
#  {'timestamp': '2021-04-16T18:19:40.852241',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0067'},
#  {'timestamp': '2021-04-16T23:48:26.693114',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0068'},
#  {'timestamp': '2021-04-17T04:19:13.198979',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0069'},
#  {'timestamp': '2021-04-17T07:01:15.828604',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0070'},
#  {'timestamp': '2021-04-17T07:32:16.719386',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0071'},
#  {'timestamp': '2021-04-17T12:53:43.888606',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0072'},
#  {'timestamp': '2021-04-18T02:56:38.068310',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0073'},
#  {'timestamp': '2021-04-18T04:09:50.957685',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0074'},
#  {'timestamp': '2021-04-18T23:32:40.611771',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0075'},
#  {'timestamp': '2021-04-19T01:49:31.640193',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0076'},
#  {'timestamp': '2021-04-19T10:18:44.636811',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0077'},
#  {'timestamp': '2021-04-19T12:23:23.689610',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0078'},
#  {'timestamp': '2021-04-19T14:37:49.450132',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0079'},
#  {'timestamp': '2021-04-20T08:41:35.423882',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0080'},
#  {'timestamp': '2021-04-20T10:09:00.175891',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0081'},
#  {'timestamp': '2021-04-20T17:43:48.871020',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0082'},
#  {'timestamp': '2021-04-20T19:04:44.298901',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0083'},
#  {'timestamp': '2021-04-20T21:55:29.343114',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0084'},
#  {'timestamp': '2021-04-21T01:41:32.258078',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0085'},
#  {'timestamp': '2021-04-21T04:40:02.600964',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0086'},
#  {'timestamp': '2021-04-21T04:48:53.278953',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0087'},
#  {'timestamp': '2021-04-21T06:37:30.981062',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0088'},
#  {'timestamp': '2021-04-21T07:07:24.940837',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0089'},
#  {'timestamp': '2021-04-21T08:38:37.210580',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0090'},
#  {'timestamp': '2021-04-21T16:01:58.855848',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0091'},
#  {'timestamp': '2021-04-21T22:16:16.488243',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0092'},
#  {'timestamp': '2021-04-22T01:06:43.004770',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0093'},
#  {'timestamp': '2021-04-22T08:36:10.391007',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0094'},
#  {'timestamp': '2021-04-22T11:55:17.540692',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0095'},
#  {'timestamp': '2021-04-22T14:45:46.715559',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0096'},
#  {'timestamp': '2021-04-22T18:14:08.931324',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0097'},
#  {'timestamp': '2021-04-22T22:28:44.980195',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0098'},
#  {'timestamp': '2021-04-23T02:16:25.194314',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0099'},
#  {'timestamp': '2021-04-23T03:37:00.266312',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0100'},
#  {'timestamp': '2021-04-23T03:41:12.345625',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0101'},
#  {'timestamp': '2021-04-23T12:02:56.566228',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0102'},
#  {'timestamp': '2021-04-23T14:59:30.168996',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0103'},
#  {'timestamp': '2021-04-23T16:07:25.868700',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0104'},
#  {'timestamp': '2021-04-23T18:02:26.646709',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0105'},
#  {'timestamp': '2021-04-23T21:18:55.116928',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0106'},
#  {'timestamp': '2021-04-24T04:02:59.866322',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0107'},
#  {'timestamp': '2021-04-24T09:40:12.461805',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0108'},
#  {'timestamp': '2021-04-24T17:32:59.470612',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0109'},
#  {'timestamp': '2021-04-24T21:50:35.192004',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0110'},
#  {'timestamp': '2021-04-26T01:36:09.667169',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0111'},
#  {'timestamp': '2021-04-26T02:11:43.582163',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0112'},
#  {'timestamp': '2021-04-26T04:31:28.661289',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0113'},
#  {'timestamp': '2021-04-26T04:52:28.606266',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0114'},
#  {'timestamp': '2021-04-26T12:03:34.826988',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0115'},
#  {'timestamp': '2021-04-27T04:28:23.945394',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0116'},
#  {'timestamp': '2021-04-27T12:56:26.642813',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0117'},
#  {'timestamp': '2021-04-27T18:36:30.414424',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0118'},
#  {'timestamp': '2021-04-27T23:05:22.121578',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0119'},
#  {'timestamp': '2021-04-29T01:12:48.859243',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0120'},
#  {'timestamp': '2021-04-29T01:47:22.641290',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0121'},
#  {'timestamp': '2021-04-29T02:05:14.560327',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0122'},
#  {'timestamp': '2021-04-29T04:46:39.983723',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0123'},
#  {'timestamp': '2021-04-29T12:26:44.869571',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0124'},
#  {'timestamp': '2021-04-29T13:14:55.562012',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0125'},
#  {'timestamp': '2021-04-29T16:34:18.562612',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0126'},
#  {'timestamp': '2021-04-29T20:22:52.322501',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0127'},
#  {'timestamp': '2021-04-30T12:38:37.146709',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0128'},
#  {'timestamp': '2021-04-30T17:21:00.840146',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0129'},
#  {'timestamp': '2021-04-30T23:05:24.098674',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0130'}]

# %% [markdown]
# **댓글 생성 로그**

# %%
def create_reply(start_dt, t_total, n_reply, post_log, users, depth='1'):
    end_dt = start_dt + t_total
    n_post = len(post_log)
    t_post_list = []
    t_post_total = timedelta(seconds=0)
    for i in range(n_post):
        t_post = datetime.fromisoformat(post_log[i]['timestamp'])
        t_remain = end_dt - t_post
        t_post_list.append(t_remain)
    post_tower = make_tower(t_post_list)
    reply_log_list = []
    for i in range(n_reply):
        post_i = select_tower(post_tower)
        t_post = datetime.fromisoformat(post_log[post_i]['timestamp'])
        t_remain = end_dt - t_post
        t_reply = t_post + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        reply_log = {
            'timestamp': t_reply.isoformat(),
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'action_group': user['user_type'],
            'action': 'create',
            'action_key':  user['user_type']+'/create3',
            'parent_id': post_log[post_i]['content_id'],
            'parent_user_id': post_log[post_i]['user_id'],
            'type_id': 'CMMT', # comment
            'val': '1',        # reply
            'log_type': 'content',
            'content_type': 'comment',
            'voting_power': 'y',
        }
        reply_log_list.append(reply_log)
        
    reply_log_list = sorted(reply_log_list, key=lambda article: (article['timestamp']))
    for i in range(n_reply):
       reply_log_list[i]['content_id'] = reply_log_list[i]['type_id']+'%i.%04i'%(1,i+1)
    return reply_log_list

# %%
reply_log = create_reply(start_dt, t_total, n_reply, post_log, users)

# %%
reply_log
# Out:
# [{'timestamp': '2021-04-06T15:08:36.911592',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0012',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0001'},
#  {'timestamp': '2021-04-06T17:41:09.583586',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0002'},
#  {'timestamp': '2021-04-06T23:12:22.104760',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0020',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0003'},
#  {'timestamp': '2021-04-07T03:13:45.891274',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0013',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0004'},
#  {'timestamp': '2021-04-07T07:14:02.750086',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0005'},
#  {'timestamp': '2021-04-07T11:34:51.099858',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0005',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0006'},
#  {'timestamp': '2021-04-08T09:59:08.248391',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0007'},
#  {'timestamp': '2021-04-09T01:50:35.175317',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0017',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0008'},
#  {'timestamp': '2021-04-09T21:54:53.740262',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0028',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0009'},
#  {'timestamp': '2021-04-10T02:01:33.856187',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0012',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0010'},
#  {'timestamp': '2021-04-10T10:05:54.046585',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0016',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0011'},
#  {'timestamp': '2021-04-11T09:49:51.900729',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0041',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0012'},
#  {'timestamp': '2021-04-11T16:49:02.127283',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0034',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0013'},
#  {'timestamp': '2021-04-12T07:30:05.445520',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0032',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0014'},
#  {'timestamp': '2021-04-12T17:18:46.527043',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0017',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0015'},
#  {'timestamp': '2021-04-13T19:09:58.213887',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0010',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0016'},
#  {'timestamp': '2021-04-13T19:29:49.355482',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0023',
#   'parent_user_id': 'u000005',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0017'},
#  {'timestamp': '2021-04-14T01:37:28.593657',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0004',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0018'},
#  {'timestamp': '2021-04-14T04:20:58.979984',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0047',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0019'},
#  {'timestamp': '2021-04-14T16:43:10.902256',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0009',
#   'parent_user_id': 'u000005',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0020'},
#  {'timestamp': '2021-04-15T02:06:29.688496',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0007',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0021'},
#  {'timestamp': '2021-04-15T16:38:46.603244',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0022'},
#  {'timestamp': '2021-04-15T18:08:17.638981',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0050',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0023'},
#  {'timestamp': '2021-04-16T01:01:43.101197',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0039',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0024'},
#  {'timestamp': '2021-04-16T06:25:23.563078',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0026',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0025'},
#  {'timestamp': '2021-04-16T09:44:55.772631',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0024',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0026'},
#  {'timestamp': '2021-04-16T23:02:57.549379',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0012',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0027'},
#  {'timestamp': '2021-04-17T09:09:54.504691',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0061',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0028'},
#  {'timestamp': '2021-04-17T13:17:10.944865',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0025',
#   'parent_user_id': 'u000002',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0029'},
#  {'timestamp': '2021-04-17T14:03:51.554229',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0048',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0030'},
#  {'timestamp': '2021-04-17T19:00:39.568859',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0069',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0031'},
#  {'timestamp': '2021-04-17T22:47:25.789933',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0036',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0032'},
#  {'timestamp': '2021-04-18T00:00:29.868074',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0033'},
#  {'timestamp': '2021-04-18T04:41:58.112748',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0048',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0034'},
#  {'timestamp': '2021-04-18T13:58:12.380083',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0035'},
#  {'timestamp': '2021-04-18T22:06:10.705228',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0030',
#   'parent_user_id': 'u000005',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0036'},
#  {'timestamp': '2021-04-19T12:28:00.097838',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0067',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0037'},
#  {'timestamp': '2021-04-19T13:21:38.140816',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0049',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0038'},
#  {'timestamp': '2021-04-19T23:26:04.651341',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0075',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0039'},
#  {'timestamp': '2021-04-20T02:58:33.837405',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0006',
#   'parent_user_id': 'u000004',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0040'},
#  {'timestamp': '2021-04-20T18:16:03.676516',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0072',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0041'},
#  {'timestamp': '2021-04-21T05:09:10.803540',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0053',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0042'},
#  {'timestamp': '2021-04-21T14:48:58.170496',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0078',
#   'parent_user_id': 'u000005',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0043'},
#  {'timestamp': '2021-04-21T23:35:26.279368',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0084',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0044'},
#  {'timestamp': '2021-04-22T05:46:03.626402',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0027',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0045'},
#  {'timestamp': '2021-04-22T08:30:03.777111',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0064',
#   'parent_user_id': 'u000005',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0046'},
#  {'timestamp': '2021-04-22T08:47:41.926738',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0047'},
#  {'timestamp': '2021-04-22T15:58:56.874366',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0088',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0048'},
#  {'timestamp': '2021-04-22T16:44:29.712655',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0031',
#   'parent_user_id': 'u000003',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0049'},
#  {'timestamp': '2021-04-22T18:48:14.611027',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0018',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0050'},
#  {'timestamp': '2021-04-22T23:06:05.361605',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0044',
#   'parent_user_id': 'u000001',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0051'},
#  {'timestamp': '2021-04-23T01:10:35.915993',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0084',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0052'},
#  {'timestamp': '2021-04-23T02:46:30.946727',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0047',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0053'},
#  {'timestamp': '2021-04-23T08:30:03.889889',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0085',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0054'},
#  {'timestamp': '2021-04-23T10:21:56.612402',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0051',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0055'},
#  {'timestamp': '2021-04-23T12:42:45.511364',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0041',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0056'},
#  {'timestamp': '2021-04-23T19:41:09.984627',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0057'},
#  {'timestamp': '2021-04-23T20:39:54.798351',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0094',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0058'},
#  {'timestamp': '2021-04-23T21:21:16.025541',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0017',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0059'},
#  {'timestamp': '2021-04-24T05:55:21.165843',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0013',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0060'},
#  {'timestamp': '2021-04-24T15:38:06.774298',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0070',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0061'},
#  {'timestamp': '2021-04-25T04:11:31.056609',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0069',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0062'},
#  {'timestamp': '2021-04-25T08:11:31.452914',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0007',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0063'},
#  {'timestamp': '2021-04-25T13:03:18.529520',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0019',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0064'},
#  {'timestamp': '2021-04-25T15:00:45.955154',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0065'},
#  {'timestamp': '2021-04-25T15:49:35.137124',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0074',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0066'},
#  {'timestamp': '2021-04-25T22:52:20.283947',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0059',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0067'},
#  {'timestamp': '2021-04-25T23:01:20.820635',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0002',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0068'},
#  {'timestamp': '2021-04-25T23:09:53.141632',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0063',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0069'},
#  {'timestamp': '2021-04-26T02:37:49.877293',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0056',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0070'},
#  {'timestamp': '2021-04-26T05:07:43.346453',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0005',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0071'},
#  {'timestamp': '2021-04-26T05:23:41.132077',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0044',
#   'parent_user_id': 'u000001',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0072'},
#  {'timestamp': '2021-04-26T12:12:35.653775',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0071',
#   'parent_user_id': 'u000001',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0073'},
#  {'timestamp': '2021-04-26T19:39:26.358911',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0074'},
#  {'timestamp': '2021-04-27T10:27:56.444268',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0020',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0075'},
#  {'timestamp': '2021-04-27T12:57:41.169748',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0078',
#   'parent_user_id': 'u000005',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0076'},
#  {'timestamp': '2021-04-27T15:55:25.340199',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0072',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0077'},
#  {'timestamp': '2021-04-27T19:22:30.964149',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0091',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0078'},
#  {'timestamp': '2021-04-27T22:17:27.780981',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0118',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0079'},
#  {'timestamp': '2021-04-28T12:56:50.172455',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0108',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0080'},
#  {'timestamp': '2021-04-28T15:54:46.867799',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0095',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0081'},
#  {'timestamp': '2021-04-28T18:23:20.210864',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0109',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0082'},
#  {'timestamp': '2021-04-28T19:57:27.760585',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0059',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0083'},
#  {'timestamp': '2021-04-29T00:47:23.802191',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0051',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0084'},
#  {'timestamp': '2021-04-29T01:14:10.989427',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0112',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0085'},
#  {'timestamp': '2021-04-29T04:08:35.640040',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0067',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0086'},
#  {'timestamp': '2021-04-29T07:45:23.210453',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0056',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0087'},
#  {'timestamp': '2021-04-29T14:42:58.199281',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0015',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0088'},
#  {'timestamp': '2021-04-29T20:09:17.541527',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0098',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0089'},
#  {'timestamp': '2021-04-30T01:59:52.463790',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0040',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0090'},
#  {'timestamp': '2021-04-30T02:09:08.204774',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0077',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0091'},
#  {'timestamp': '2021-04-30T04:27:23.293915',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0057',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0092'},
#  {'timestamp': '2021-04-30T13:56:28.728317',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0057',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0093'},
#  {'timestamp': '2021-04-30T14:15:23.851112',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0091',
#   'parent_user_id': 'u000008',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0094'},
#  {'timestamp': '2021-04-30T14:26:41.399406',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0003',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0095'},
#  {'timestamp': '2021-04-30T16:57:27.295655',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create3',
#   'parent_id': 'COPT.0068',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0096'},
#  {'timestamp': '2021-04-30T18:02:02.409289',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0116',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0097'},
#  {'timestamp': '2021-04-30T22:17:19.966500',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0044',
#   'parent_user_id': 'u000001',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0098'},
#  {'timestamp': '2021-04-30T22:30:46.682255',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0016',
#   'parent_user_id': 'u000009',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0099'},
#  {'timestamp': '2021-04-30T22:53:17.143587',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create3',
#   'parent_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'type_id': 'CMMT',
#   'val': '1',
#   'log_type': 'content',
#   'content_type': 'comment',
#   'voting_power': 'y',
#   'content_id': 'CMMT.0100'}]

# %% [markdown]
# **대댓글 생성로그**

# %%
def create_rereply(start_dt, t_total, n_rereply, reply_log, users):
    end_dt = start_dt + t_total
    n_reply = len(reply_log)
    t_reply_list = []
    t_reply_total = timedelta(seconds=0)
    for i in range(n_reply):
        t_reply = datetime.fromisoformat(reply_log[i]['timestamp'])
        t_remain = end_dt - t_reply
        t_reply_list.append(t_remain)
    reply_tower = make_tower(t_reply_list)
    rereply_log_list = []
    for i in range(n_rereply):
        reply_i = select_tower(reply_tower)
        t_reply = datetime.fromisoformat(reply_log[reply_i]['timestamp'])
        t_remain = end_dt - t_reply
        t_rereply = t_reply + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        rereply_log = {
            'timestamp': t_rereply.isoformat(),
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'action_group': user['user_type'],
            'action': 'create',
            'action_key': user['user_type']+'/create4',
            'parent_id': reply_log[reply_i]['content_id'],
            'parent_user_id': reply_log[reply_i]['user_id'],
            'type_id': 'CMMT', # comment
            'val': '2',        # re-reply
            'log_type': 'content',
            'content_type': 'comment',
            'voting_power': 'y',
        }
        rereply_log_list.append(rereply_log)
        
    rereply_log_list = sorted(rereply_log_list, key=lambda article: (article['timestamp']))
    for i in range(n_rereply):
       rereply_log_list[i]['content_id'] = rereply_log_list[i]['type_id']+'.%i%04i'%(2,i+1)
    return rereply_log_list

# %%
rereply_log = create_rereply(start_dt, t_total, n_rereply, reply_log, users)

# %%
rereply_log

# %% [markdown]
# **조회 로그**

# %%
def create_view(start_dt, t_total, n_view, post_log, users):
    end_dt = start_dt + t_total
    n_post = len(post_log)
    t_post_list = []
    t_post_total = timedelta(seconds=0)
    for i in range(n_post):
        t_post = datetime.fromisoformat(post_log[i]['timestamp'])
        t_remain = end_dt - t_post
        t_post_list.append(t_remain)
    post_tower = make_tower(t_post_list)
    view_log_list = []
    for i in range(n_view):
        post_i = select_tower(post_tower)
        t_post = datetime.fromisoformat(post_log[post_i]['timestamp'])
        t_remain = end_dt - t_post
        t_reply = t_post + random.uniform(0.0, 1.0)*t_remain
        #user = random.choice(users)
        view_log = {
            'timestamp': t_reply.isoformat(),
            'log_type': 'info',
            'action': 'view',
            'action_key': post_log[post_i]['action_group'] + '/view',
            'action_group': post_log[post_i]['action_group'],
            'user_id': post_log[post_i]['user_id'],
            'user_type': post_log[post_i]['user_type'],
            'content_type': post_log[post_i]['content_type'],
            'content_id': post_log[post_i]['content_id'],
            'value': 1,             # TO-DO 1시간 간격
        }
        view_log_list.append(view_log)
        
    view_log_list = sorted(view_log_list, key=lambda article: (article['timestamp']))
    return view_log_list

view_log = create_view(start_dt, t_total, n_view, post_log, users)
view_log
# Out:
# [{'timestamp': '2021-04-05T18:56:35.320921',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0006',
#   'value': 1},
#  {'timestamp': '2021-04-07T07:22:45.425774',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0018',
#   'value': 1},
#  {'timestamp': '2021-04-08T08:15:31.787699',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0021',
#   'value': 1},
#  {'timestamp': '2021-04-08T08:48:52.370491',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0018',
#   'value': 1},
#  {'timestamp': '2021-04-08T21:10:17.484823',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0025',
#   'value': 1},
#  {'timestamp': '2021-04-10T18:49:45.633503',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0026',
#   'value': 1},
#  {'timestamp': '2021-04-11T05:50:32.218558',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0002',
#   'value': 1},
#  {'timestamp': '2021-04-12T16:27:00.918043',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'value': 1},
#  {'timestamp': '2021-04-13T11:02:29.663437',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'value': 1},
#  {'timestamp': '2021-04-13T14:14:44.801009',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'value': 1},
#  {'timestamp': '2021-04-14T14:51:03.710884',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0018',
#   'value': 1},
#  {'timestamp': '2021-04-14T17:11:42.188156',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0029',
#   'value': 1},
#  {'timestamp': '2021-04-14T22:45:06.651703',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0023',
#   'value': 1},
#  {'timestamp': '2021-04-15T02:20:04.332571',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0047',
#   'value': 1},
#  {'timestamp': '2021-04-16T02:09:59.604379',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0003',
#   'value': 1},
#  {'timestamp': '2021-04-16T08:32:55.837358',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0027',
#   'value': 1},
#  {'timestamp': '2021-04-16T12:23:54.397397',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'value': 1},
#  {'timestamp': '2021-04-16T21:10:48.600576',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0040',
#   'value': 1},
#  {'timestamp': '2021-04-16T21:47:04.420349',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0017',
#   'value': 1},
#  {'timestamp': '2021-04-16T23:00:57.606918',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0061',
#   'value': 1},
#  {'timestamp': '2021-04-17T02:41:48.445749',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0006',
#   'value': 1},
#  {'timestamp': '2021-04-17T07:33:12.786649',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0056',
#   'value': 1},
#  {'timestamp': '2021-04-17T16:06:40.233043',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'value': 1},
#  {'timestamp': '2021-04-17T16:17:50.137243',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0061',
#   'value': 1},
#  {'timestamp': '2021-04-17T18:20:55.673741',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0027',
#   'value': 1},
#  {'timestamp': '2021-04-17T21:02:27.696969',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'value': 1},
#  {'timestamp': '2021-04-19T10:14:47.523345',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0026',
#   'value': 1},
#  {'timestamp': '2021-04-19T10:44:02.715241',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0051',
#   'value': 1},
#  {'timestamp': '2021-04-19T13:41:36.942461',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0049',
#   'value': 1},
#  {'timestamp': '2021-04-20T15:04:59.454189',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0057',
#   'value': 1},
#  {'timestamp': '2021-04-21T02:23:10.316256',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'value': 1},
#  {'timestamp': '2021-04-21T04:21:57.912776',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0059',
#   'value': 1},
#  {'timestamp': '2021-04-21T08:07:58.479363',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'value': 1},
#  {'timestamp': '2021-04-21T10:26:41.394955',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0002',
#   'value': 1},
#  {'timestamp': '2021-04-21T15:54:39.379514',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0009',
#   'value': 1},
#  {'timestamp': '2021-04-21T19:23:19.337335',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0085',
#   'value': 1},
#  {'timestamp': '2021-04-21T21:50:13.884789',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0085',
#   'value': 1},
#  {'timestamp': '2021-04-21T22:03:40.314075',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'value': 1},
#  {'timestamp': '2021-04-22T02:14:40.278518',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0073',
#   'value': 1},
#  {'timestamp': '2021-04-22T09:29:51.765485',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0056',
#   'value': 1},
#  {'timestamp': '2021-04-22T10:52:10.681383',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0069',
#   'value': 1},
#  {'timestamp': '2021-04-22T16:36:22.018878',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0053',
#   'value': 1},
#  {'timestamp': '2021-04-22T16:40:12.231270',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0077',
#   'value': 1},
#  {'timestamp': '2021-04-22T19:55:29.548809',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0019',
#   'value': 1},
#  {'timestamp': '2021-04-23T02:45:54.240878',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0090',
#   'value': 1},
#  {'timestamp': '2021-04-23T03:09:55.404506',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0032',
#   'value': 1},
#  {'timestamp': '2021-04-23T03:28:46.379550',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0040',
#   'value': 1},
#  {'timestamp': '2021-04-23T03:42:44.682448',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0085',
#   'value': 1},
#  {'timestamp': '2021-04-23T05:52:58.502916',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0024',
#   'value': 1},
#  {'timestamp': '2021-04-24T06:20:38.253224',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0033',
#   'value': 1},
#  {'timestamp': '2021-04-24T08:23:42.979479',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0075',
#   'value': 1},
#  {'timestamp': '2021-04-24T08:24:31.614986',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0095',
#   'value': 1},
#  {'timestamp': '2021-04-24T10:55:35.660273',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'value': 1},
#  {'timestamp': '2021-04-24T21:02:02.508534',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0014',
#   'value': 1},
#  {'timestamp': '2021-04-24T21:55:05.671098',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0027',
#   'value': 1},
#  {'timestamp': '2021-04-25T03:42:52.652048',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0096',
#   'value': 1},
#  {'timestamp': '2021-04-25T05:53:35.632330',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0096',
#   'value': 1},
#  {'timestamp': '2021-04-25T06:39:04.449379',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'value': 1},
#  {'timestamp': '2021-04-25T17:24:17.715838',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0013',
#   'value': 1},
#  {'timestamp': '2021-04-25T20:04:12.697199',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0042',
#   'value': 1},
#  {'timestamp': '2021-04-25T21:56:59.875915',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0016',
#   'value': 1},
#  {'timestamp': '2021-04-25T21:57:08.471160',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0070',
#   'value': 1},
#  {'timestamp': '2021-04-25T22:24:47.945448',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0073',
#   'value': 1},
#  {'timestamp': '2021-04-26T04:38:37.986487',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0112',
#   'value': 1},
#  {'timestamp': '2021-04-26T06:20:02.188740',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0012',
#   'value': 1},
#  {'timestamp': '2021-04-26T09:50:15.866560',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0050',
#   'value': 1},
#  {'timestamp': '2021-04-26T12:59:14.929938',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0087',
#   'value': 1},
#  {'timestamp': '2021-04-26T15:41:01.544723',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0026',
#   'value': 1},
#  {'timestamp': '2021-04-26T17:41:49.720631',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0089',
#   'value': 1},
#  {'timestamp': '2021-04-26T18:50:49.979020',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0017',
#   'value': 1},
#  {'timestamp': '2021-04-26T21:55:17.270531',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0103',
#   'value': 1},
#  {'timestamp': '2021-04-27T00:26:12.543203',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0076',
#   'value': 1},
#  {'timestamp': '2021-04-27T01:20:10.680814',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0043',
#   'value': 1},
#  {'timestamp': '2021-04-27T03:00:04.190471',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0108',
#   'value': 1},
#  {'timestamp': '2021-04-27T04:13:12.821456',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0109',
#   'value': 1},
#  {'timestamp': '2021-04-27T07:02:52.596120',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0026',
#   'value': 1},
#  {'timestamp': '2021-04-27T10:02:48.258879',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0014',
#   'value': 1},
#  {'timestamp': '2021-04-27T10:08:27.010448',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0098',
#   'value': 1},
#  {'timestamp': '2021-04-27T22:26:53.927651',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0039',
#   'value': 1},
#  {'timestamp': '2021-04-27T23:24:53.791507',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0076',
#   'value': 1},
#  {'timestamp': '2021-04-28T03:54:27.199609',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0065',
#   'value': 1},
#  {'timestamp': '2021-04-28T15:37:36.917733',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0039',
#   'value': 1},
#  {'timestamp': '2021-04-28T17:30:34.902029',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0074',
#   'value': 1},
#  {'timestamp': '2021-04-28T19:03:53.793319',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0092',
#   'value': 1},
#  {'timestamp': '2021-04-28T21:50:20.751751',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0062',
#   'value': 1},
#  {'timestamp': '2021-04-29T00:24:04.171333',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'value': 1},
#  {'timestamp': '2021-04-29T05:16:37.784765',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0069',
#   'value': 1},
#  {'timestamp': '2021-04-29T09:29:05.460051',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0106',
#   'value': 1},
#  {'timestamp': '2021-04-29T18:25:20.188955',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0049',
#   'value': 1},
#  {'timestamp': '2021-04-29T18:51:34.100642',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0030',
#   'value': 1},
#  {'timestamp': '2021-04-29T21:35:44.662074',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0085',
#   'value': 1},
#  {'timestamp': '2021-04-29T23:25:24.216605',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0118',
#   'value': 1},
#  {'timestamp': '2021-04-30T04:27:33.117674',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0024',
#   'value': 1},
#  {'timestamp': '2021-04-30T07:46:20.819790',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0127',
#   'value': 1},
#  {'timestamp': '2021-04-30T09:24:42.895566',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0037',
#   'value': 1},
#  {'timestamp': '2021-04-30T10:23:00.037548',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0079',
#   'value': 1},
#  {'timestamp': '2021-04-30T13:46:43.875156',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0103',
#   'value': 1},
#  {'timestamp': '2021-04-30T21:09:17.295081',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0036',
#   'value': 1},
#  {'timestamp': '2021-04-30T21:31:52.787515',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'community/view',
#   'action_group': 'community',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0071',
#   'value': 1},
#  {'timestamp': '2021-04-30T23:19:13.231221',
#   'log_type': 'info',
#   'action': 'view',
#   'action_key': 'press/view',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0041',
#   'value': 1}]

# %% [markdown]
# **우수 콘텐츠 로그 생성**

# %%
def create_best(start_dt, t_total, n_best, post_log, users):
    end_dt = start_dt + t_total
    n_post = len(post_log)
    
    best_log_list = []
    for i in range(n_best):
        post = random.choice(post_log)
        t_post = datetime.fromisoformat(post['timestamp'])
        t_remain = end_dt - t_post
        t_reply = t_post + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        best_log = {
            'timestamp': t_reply.isoformat(),
            'log_type': 'info',
            'action': 'best',
            'action_key': post['action_group'] + '/best',
            'action_group': post['action_group'],
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'content_type': post['content_type'],
            'content_id': post['content_id'],
            'value': 1,             # TO-DO 1시간 간격
        }
        best_log_list.append(best_log)
        
    best_log_list = sorted(best_log_list, key=lambda article: (article['timestamp']))
    return best_log_list

# %%
best_log = create_best(start_dt, t_total, n_best, post_log, users)

# %%
best_log
# Out:
# [{'timestamp': '2021-04-10T18:59:28.763662',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0012',
#   'value': 1},
#  {'timestamp': '2021-04-20T09:51:35.021456',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0036',
#   'value': 1},
#  {'timestamp': '2021-04-23T17:03:20.630781',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0003',
#   'value': 1},
#  {'timestamp': '2021-04-25T16:51:17.212205',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0108',
#   'value': 1},
#  {'timestamp': '2021-04-25T18:06:54.157138',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'community/best',
#   'action_group': 'community',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0101',
#   'value': 1},
#  {'timestamp': '2021-04-27T01:26:20.432501',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0090',
#   'value': 1},
#  {'timestamp': '2021-04-27T05:08:27.367175',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0094',
#   'value': 1},
#  {'timestamp': '2021-04-30T06:53:42.252634',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0094',
#   'value': 1},
#  {'timestamp': '2021-04-30T11:05:19.616303',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0122',
#   'value': 1},
#  {'timestamp': '2021-04-30T21:19:53.205760',
#   'log_type': 'info',
#   'action': 'best',
#   'action_key': 'press/best',
#   'action_group': 'press',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0128',
#   'value': 1}]

# %% [markdown]
# **리액션 로그(본문)**

# %%
def create_reaction(start_dt, t_total, n_reaction, post_log, users):
    end_dt = start_dt + t_total
    n_post = len(post_log)
    t_post_list = []
    t_post_total = timedelta(seconds=0)
    for i in range(n_post):
        t_post = datetime.fromisoformat(post_log[i]['timestamp'])
        t_remain = end_dt - t_post
        t_post_list.append(t_remain)
    post_tower = make_tower(t_post_list)
    reaction_log_list = []
    for i in range(n_reaction):
        post_i = select_tower(post_tower)
        t_post = datetime.fromisoformat(post_log[post_i]['timestamp'])
        t_remain = end_dt - t_post
        t_reply = t_post + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        reaction_log = {
            'timestamp': t_reply.isoformat(),
            'log_type': 'relation', # reaction?
            'action': 'like',
            'action_key': post_log[post_i]['action_group'] + '/like',
            'action_group': post_log[post_i]['action_group'],
            'value': random.choice([1, 2]), # like, dislike
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'content_type': post_log[post_i]['content_type'],
            'content_id': post_log[post_i]['content_id'],
            'parent_user_id': post_log[post_i]['user_id'],
            'voting_power': 'y',
        }
        reaction_log_list.append(reaction_log)
        
    reaction_log_list = sorted(reaction_log_list, key=lambda article: (article['timestamp']))
    return reaction_log_list

reaction_log = create_reaction(start_dt, t_total, n_view, post_log, users)
reaction_log
# Out:
# [{'timestamp': '2021-04-03T08:48:17.503786',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0006',
#   'parent_user_id': 'u000004',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-05T03:38:00.518283',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0010',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-06T07:12:37.868717',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0018',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-06T11:36:23.883714',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-07T11:55:53.895027',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0014',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-09T04:59:49.411427',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0013',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-10T07:05:56.130415',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0014',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-10T16:35:31.816829',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0009',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-12T11:43:47.429130',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0035',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-12T11:53:55.764466',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0043',
#   'parent_user_id': 'u000002',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T00:40:52.304321',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0028',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T04:50:12.196730',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0006',
#   'parent_user_id': 'u000004',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T15:28:13.390925',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0010',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T22:41:25.781397',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0034',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-14T08:51:32.001615',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0010',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-14T10:21:48.069671',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0036',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-14T19:25:32.433508',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0053',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-14T21:00:35.007964',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0040',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-14T23:33:45.677670',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T00:44:11.778461',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0004',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T06:37:34.051323',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0039',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T11:04:50.706307',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T13:16:57.462960',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T13:35:46.582383',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0046',
#   'parent_user_id': 'u000006',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T18:53:28.449064',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-16T00:37:57.973349',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0059',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-16T01:45:00.576926',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0010',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-16T09:56:47.968618',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T08:17:31.125144',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T17:09:45.835633',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0014',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T17:44:14.277549',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0062',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T07:12:36.728081',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0028',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T17:10:08.223462',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0026',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-19T02:29:59.000148',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0063',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T04:20:23.196995',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T09:22:45.861612',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0074',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T13:08:00.428798',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0030',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T14:27:37.693775',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0057',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T19:10:03.763456',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0006',
#   'parent_user_id': 'u000004',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T23:49:23.486688',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0024',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T01:04:28.229986',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0013',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T03:44:46.737091',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'parent_user_id': 'u000007',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T04:11:47.043112',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0082',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T04:12:20.453648',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0061',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T09:29:16.124432',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T15:42:23.356462',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0030',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T23:05:06.143485',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T02:16:50.812592',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0083',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T09:57:55.931211',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0091',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T12:23:34.938682',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0091',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T13:08:16.823955',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0004',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T13:31:47.019935',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0038',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T14:59:36.632241',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0012',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T22:26:39.474945',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T23:07:14.809837',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T00:34:35.651480',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T04:31:02.653402',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0053',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T05:50:29.342577',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0021',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T10:37:05.406492',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0069',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T10:50:06.342138',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0086',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T14:57:05.087982',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0092',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T19:06:35.893425',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0100',
#   'parent_user_id': 'u000002',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T19:18:55.058740',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0062',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T22:08:46.114337',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0093',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T08:02:41.278363',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0097',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T09:10:31.162172',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0083',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T14:05:46.958338',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0056',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T21:30:02.535102',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0065',
#   'parent_user_id': 'u000004',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T00:43:41.646248',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0038',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T04:37:27.528475',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0018',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T05:51:06.823076',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T09:30:30.647218',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0002',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T17:32:34.951395',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T23:02:18.673832',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0039',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T05:15:20.846945',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0097',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T05:19:40.222530',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0041',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T15:21:15.607623',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0088',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T22:42:23.558673',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0003',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T07:22:46.581680',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0037',
#   'parent_user_id': 'u000003',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T10:05:32.909266',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T13:03:40.765860',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0074',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T16:24:27.940097',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0107',
#   'parent_user_id': 'u000001',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T19:06:50.465240',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0078',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T03:12:03.978249',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T04:00:36.810409',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0087',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T19:32:55.838692',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0059',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T20:26:28.545962',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0115',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T04:36:34.851253',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0032',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T04:54:13.964747',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0041',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T14:07:46.402437',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0116',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T22:13:51.026249',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0066',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T01:20:31.374606',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0116',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T04:45:05.003340',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0043',
#   'parent_user_id': 'u000002',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T05:33:26.607167',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0037',
#   'parent_user_id': 'u000003',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T10:25:47.094770',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0096',
#   'parent_user_id': 'u000001',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T12:33:48.544299',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0023',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T14:00:41.422484',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0020',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T17:38:42.629047',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0106',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T18:27:58.841374',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T23:59:03.195092',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0012',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'}]

# %% [markdown]
# **리액션(댓글) 로그 생성**

# %%
def create_reaction_reply(start_dt, t_total, n_reaction_reply, reply_log, users):
    end_dt = start_dt + t_total
    n_reply = len(reply_log)
    t_reply_list = []
    t_reply_total = timedelta(seconds=0)
    for i in range(n_reply):
        t_reply = datetime.fromisoformat(reply_log[i]['timestamp'])
        t_remain = end_dt - t_reply
        t_reply_list.append(t_remain)
    reply_tower = make_tower(t_reply_list)
    reaction_log_list = []
    for i in range(n_view):
        reply_i = select_tower(reply_tower)
        t_reply = datetime.fromisoformat(reply_log[reply_i]['timestamp'])
        t_remain = end_dt - t_reply
        t_reply = t_reply + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        reaction_log = {
            'timestamp': t_reply.isoformat(),
            'log_type': 'relation', # reaction?
            'action': 'like',
            'action_key': reply_log[reply_i]['action_group'] + '/like',
            'action_group': reply_log[reply_i]['action_group'],
            'value': random.choice([1, 2]), # like, dislike
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'content_type': reply_log[reply_i]['content_type'],
            'content_id': reply_log[reply_i]['content_id'],
            'parent_user_id': reply_log[reply_i]['user_id'],
            'voting_power': 'y',
        }
        reaction_log_list.append(reaction_log)
        
    reaction_log_list = sorted(reaction_log_list, key=lambda article: (article['timestamp']))
    return reaction_log_list

reaction_reply_log = create_reaction_reply(start_dt, t_total, n_view, post_log, users)
reaction_reply_log
# Out:
# [{'timestamp': '2021-04-02T15:34:33.774208',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0002',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-04T21:21:22.088503',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-05T03:24:22.099691',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0003',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-05T06:29:11.414537',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0015',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-05T08:20:05.845815',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-05T15:34:34.946607',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0003',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-07T15:14:13.102104',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0020',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-07T21:24:06.383094',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0017',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-08T07:55:43.280197',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-08T08:26:31.451311',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0018',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-08T16:05:02.930878',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0025',
#   'parent_user_id': 'u000002',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-09T05:23:27.838883',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0019',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-09T11:06:13.644219',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-09T20:27:28.534570',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-11T04:41:23.018303',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T03:46:59.429169',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0020',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T11:56:13.057264',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0028',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-13T16:50:37.186555',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0040',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-14T07:18:26.846475',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'parent_user_id': 'u000007',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T09:48:04.114959',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0009',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-15T21:42:43.622921',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0050',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-16T06:51:46.060213',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-16T11:55:59.738215',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0052',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-16T19:33:25.410912',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0031',
#   'parent_user_id': 'u000003',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T05:41:19.127615',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T13:30:40.369666',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0048',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T14:35:46.370351',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0006',
#   'parent_user_id': 'u000004',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T15:37:42.727652',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0024',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-17T22:03:37.154963',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T02:02:01.088636',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0028',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T04:28:59.319259',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0047',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T07:41:14.960859',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T10:55:52.332283',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0058',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-18T21:59:40.091574',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0050',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T08:30:35.957219',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0079',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T08:31:27.300997',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'parent_user_id': 'u000007',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T10:33:41.053400',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0081',
#   'parent_user_id': 'u000003',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T18:11:42.042792',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-20T23:45:24.653810',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'parent_user_id': 'u000007',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T09:35:44.513353',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0088',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T12:57:43.324369',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0005',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T13:08:41.304067',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0061',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-21T16:19:30.270347',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0017',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T02:43:27.780320',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0015',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T02:48:02.189552',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0089',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T06:16:26.313204',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0079',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T14:17:48.607827',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0084',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T15:06:48.885592',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0045',
#   'parent_user_id': 'u000007',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T18:15:41.617518',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0074',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T18:50:35.506936',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T21:39:18.320236',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0033',
#   'parent_user_id': 'u000001',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-22T23:49:46.993815',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T00:11:30.292180',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T09:12:32.537983',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T12:49:58.969578',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0098',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-23T18:24:13.840660',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T14:04:54.212664',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0003',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T19:56:19.090478',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0050',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-24T23:43:48.527965',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0016',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T01:30:26.133400',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T07:00:52.473521',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0027',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T08:04:35.073458',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0054',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T08:30:50.328269',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0051',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T08:36:44.962219',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0036',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T09:51:05.345240',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0062',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T10:41:42.451425',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0066',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T12:19:18.906909',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0097',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T13:50:23.409306',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0076',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-25T22:48:18.890024',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0050',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T03:20:55.802761',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0004',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T07:06:02.153113',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0085',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T09:21:57.838564',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0059',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T09:27:27.612871',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0029',
#   'parent_user_id': 'u000002',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T16:04:30.611776',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0098',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-26T18:14:31.511695',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0087',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T01:52:35.126240',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0058',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T05:50:01.746392',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T09:50:39.557952',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0048',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T13:47:22.743037',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0049',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T19:58:06.455202',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0114',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-27T21:24:26.350215',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0097',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T01:48:41.663871',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0094',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T03:13:51.344286',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0103',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T03:15:01.788037',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0093',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T08:20:13.023121',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0083',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T12:46:10.921730',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0015',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-28T12:58:05.139983',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T01:23:04.537496',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0035',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T02:21:49.394565',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0055',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T05:20:52.086589',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0031',
#   'parent_user_id': 'u000003',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T08:54:17.326854',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T10:57:04.156834',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0094',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T12:24:14.644170',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0109',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T14:36:58.002818',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 2,
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0078',
#   'parent_user_id': 'u000005',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T14:52:10.795978',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0047',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T22:01:19.601185',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 1,
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0016',
#   'parent_user_id': 'u000009',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-29T22:25:11.099049',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0102',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T10:39:31.873714',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'community/like',
#   'action_group': 'community',
#   'value': 1,
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0025',
#   'parent_user_id': 'u000002',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T14:44:46.278669',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0063',
#   'parent_user_id': 'u000008',
#   'voting_power': 'y'},
#  {'timestamp': '2021-04-30T21:17:53.774062',
#   'log_type': 'relation',
#   'action': 'like',
#   'action_key': 'press/like',
#   'action_group': 'press',
#   'value': 2,
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0059',
#   'parent_user_id': 'u000010',
#   'voting_power': 'y'}]

# %% [markdown]
# **Bookmark 로그 생성**

# %%
def create_bookmark(start_dt, t_total, n_bookmark, post_log, users):
    end_dt = start_dt + t_total
    n_post = len(post_log)
    
    bookmark_log_list = []
    for i in range(n_bookmark):
        post = random.choice(post_log)
        t_post = datetime.fromisoformat(post['timestamp'])
        t_remain = end_dt - t_post
        t_reply = t_post + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        bookmark_log = {
            'timestamp': t_reply.isoformat(),
            'log_type': 'relation',
            'action': 'bookmark',
            'action_key': post['action_group'] + '/bookmark',
            'action_group': post['action_group'],
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'content_type': post['content_type'],
            'content_id': post['content_id'],
        }
        bookmark_log_list.append(bookmark_log)
        
    bookmark_log_list = sorted(bookmark_log_list, key=lambda article: (article['timestamp']))
    return bookmark_log_list

bookmark_log = create_bookmark(start_dt, t_total, n_bookmark, post_log, users)
bookmark_log
# Out:
# [{'timestamp': '2021-04-14T20:12:36.673864',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0021'},
#  {'timestamp': '2021-04-17T15:19:05.945631',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'community/bookmark',
#   'action_group': 'community',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0033'},
#  {'timestamp': '2021-04-19T18:13:15.371065',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'community/bookmark',
#   'action_group': 'community',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0065'},
#  {'timestamp': '2021-04-21T00:06:16.327446',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0012'},
#  {'timestamp': '2021-04-22T07:57:53.733961',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0079'},
#  {'timestamp': '2021-04-24T09:08:00.037330',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0003'},
#  {'timestamp': '2021-04-26T07:23:19.376068',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0003'},
#  {'timestamp': '2021-04-26T07:30:47.072580',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'community/bookmark',
#   'action_group': 'community',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0065'},
#  {'timestamp': '2021-04-28T09:56:04.188955',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0067'},
#  {'timestamp': '2021-04-30T09:35:47.732354',
#   'log_type': 'relation',
#   'action': 'bookmark',
#   'action_key': 'press/bookmark',
#   'action_group': 'press',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0112'}]

# %% [markdown]
# **공유 로그**

# %%
def create_share(start_dt, t_total, n_share, post_log, users):
    end_dt = start_dt + t_total
    n_post = len(post_log)
    
    share_log_list = []
    for i in range(n_share):
        post = random.choice(post_log)
        t_post = datetime.fromisoformat(post['timestamp'])
        t_remain = end_dt - t_post
        t_reply = t_post + random.uniform(0.0, 1.0)*t_remain
        user = random.choice(users)
        share_log = {
            'timestamp': t_reply.isoformat(),
            'log_type': 'relation',
            'action': 'share',
            'action_key': post['action_group'] + '/share',
            'action_group': post['action_group'],
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'content_type': post['content_type'],
            'content_id': post['content_id'],
        }
        share_log_list.append(share_log)
        
    share_log_list = sorted(share_log_list, key=lambda article: (article['timestamp']))
    return share_log_list

share_log = create_share(start_dt, t_total, n_share, post_log, users)
share_log
# Out:
# [{'timestamp': '2021-04-17T19:04:11.255288',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'community/share',
#   'action_group': 'community',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'content_type': 'post',
#   'content_id': 'COPT.0046'},
#  {'timestamp': '2021-04-18T03:18:29.522614',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0058'},
#  {'timestamp': '2021-04-18T08:03:16.303754',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0056'},
#  {'timestamp': '2021-04-26T07:00:35.643993',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0005'},
#  {'timestamp': '2021-04-27T23:54:11.425466',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0082'},
#  {'timestamp': '2021-04-28T18:01:17.628493',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0109'},
#  {'timestamp': '2021-04-29T21:53:49.751312',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0004'},
#  {'timestamp': '2021-04-30T01:48:49.651711',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'community/share',
#   'action_group': 'community',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'content_type': 'post',
#   'content_id': 'COPT.0104'},
#  {'timestamp': '2021-04-30T03:04:02.769394',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'content_type': 'article',
#   'content_id': 'COPT.0084'},
#  {'timestamp': '2021-04-30T15:39:16.735549',
#   'log_type': 'relation',
#   'action': 'share',
#   'action_key': 'press/share',
#   'action_group': 'press',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'content_type': 'article',
#   'content_id': 'COPT.0123'}]

# %% [markdown]
# **Login 로그 생성**

# %%
def create_login(start_dt, t_total, n_login, users):
    login_list = []
    for i in range(n_login):
        user = random.choice(users)
        a = random.uniform(0.0, 1.0)
        t = a*t_total
        dt = start_dt + t
        login_list.append({
            'timestamp': dt.isoformat(),
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'action_group': 'common', # action group과 user_type의 차이?
            'action': 'login',
            'action_key': 'common/login',
            'log_type': 'activity',
            'value': 1,
        })
        
    login_list = sorted(login_list, key=lambda article: (article['timestamp']))
        
    return login_list

login_log = create_login(start_dt, t_total, n_login, users)
login_log
# Out:
# [{'timestamp': '2021-04-01T01:29:42.298475',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-01T05:21:27.431553',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-01T07:48:51.975471',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-01T08:03:16.747507',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-01T11:29:29.982820',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-01T12:20:16.562499',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-02T10:34:33.909345',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-02T16:00:47.371410',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-03T12:00:06.127363',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-03T12:17:20.167660',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-03T12:22:10.729715',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-03T18:00:17.855574',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-03T18:35:32.981513',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-03T20:14:18.760748',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-04T04:35:24.510854',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-04T20:31:17.023859',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-05T17:35:00.327288',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-06T20:58:22.942663',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-06T21:55:43.520528',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-07T04:23:34.492848',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-07T04:53:31.583447',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-07T08:08:41.566447',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-07T20:27:53.979371',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-08T02:28:43.595404',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-08T02:53:14.908583',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-08T12:40:26.710017',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-08T13:31:17.850770',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-08T15:27:06.333084',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-08T17:45:56.434707',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-09T07:05:29.773966',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-09T12:42:43.359672',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-09T21:42:51.787987',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-10T01:28:18.538676',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-10T03:23:01.978386',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-10T04:17:43.310059',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-10T13:09:23.804323',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-10T15:42:47.844423',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-10T16:55:55.048439',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-11T06:54:01.178343',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-11T09:27:42.453059',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-12T02:39:30.106196',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-12T09:30:19.272820',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-12T11:10:05.011987',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-12T14:17:13.465763',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-12T15:46:26.008796',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-12T20:15:00.640591',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-13T07:57:55.520896',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-13T11:26:50.351295',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-14T06:54:11.310904',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-14T15:16:44.591906',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-14T23:34:18.161333',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-15T01:02:19.703291',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-15T08:37:08.807774',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-15T19:35:51.159449',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-16T04:24:46.106173',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-16T05:46:44.506832',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-17T01:54:32.449172',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-17T03:09:14.694260',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-17T09:49:45.231265',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-17T20:08:22.037111',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-17T23:41:20.051287',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-18T07:26:26.277465',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-19T12:48:58.988529',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-20T06:50:38.427510',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-20T14:21:50.894586',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-21T02:37:26.991623',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-21T06:22:51.075342',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-21T12:44:12.769791',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-21T13:33:39.591296',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-21T22:16:52.509315',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-22T03:36:07.125393',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-22T04:19:16.818260',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-22T06:39:17.987692',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-23T04:50:41.884730',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-23T08:25:40.103712',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-23T09:34:25.424776',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-23T13:11:32.971753',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-23T17:03:03.082652',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-23T21:45:27.861925',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-24T01:08:28.370179',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-24T05:59:25.267345',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-24T09:15:45.436056',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-25T15:42:44.952350',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-26T06:38:52.886613',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-26T23:40:57.098583',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-27T05:11:17.181680',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-27T07:19:11.292700',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-27T07:52:08.035227',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-27T13:24:06.675117',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-28T02:35:29.160140',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-28T03:14:24.766801',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-29T02:29:03.317690',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-29T08:12:27.349386',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-29T09:13:04.631245',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-29T18:07:07.963082',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-30T04:25:12.421303',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-30T08:12:00.953194',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-30T10:03:23.186955',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-30T16:58:48.338563',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1},
#  {'timestamp': '2021-04-30T17:51:40.701181',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1}]

# %% [markdown]
# **초대 로그**

# %%
def create_invitation(start_dt, t_total, n_invitation, users):
    invitation_list = []
    for i in range(n_invitation):
        user = random.choice(users)
        a = random.uniform(0.0, 1.0)
        t = a*t_total
        dt = start_dt + t
        invitation_list.append({
            'timestamp': dt.isoformat(),
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'action_group': 'common', # action group과 user_type의 차이?
            'action': 'invitation',
            'action_key': 'common/invitation',
            'log_type': 'social',
            'invite_code': 'user.3.xxxxx', #TO-DO
        })
        
    invitation_list = sorted(invitation_list, key=lambda article: (article['timestamp']))
        
    return invitation_list

invitation_log = create_invitation(start_dt, t_total, n_invitation, users)
invitation_log
# Out:
# [{'timestamp': '2021-04-01T18:13:43.821218',
#   'user_id': 'u000002',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-03T14:40:51.390822',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-04T15:06:04.512360',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-08T03:28:09.863646',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-09T07:05:17.034667',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-14T07:05:44.999635',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-18T06:57:23.501512',
#   'user_id': 'u000008',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-23T04:19:56.969866',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-24T11:41:57.980731',
#   'user_id': 'u000010',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-24T21:59:46.105638',
#   'user_id': 'u000006',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'}]

# %% [markdown]
# **추천 로그**

# %%
def create_recommend(start_dt, t_total, n_recommend, users):
    recommend_list = []
    for i in range(n_recommend):
        user = random.choice(users)
        a = random.uniform(0.0, 1.0)
        t = a*t_total
        dt = start_dt + t
        recommend_list.append({
            'timestamp': dt.isoformat(),
            'user_id': user['user_id'],
            'user_type': user['user_type'],
            'action_group': 'common', # action group과 user_type의 차이?
            'action': 'recommender',
            'action_key': 'common/recommender',
            'log_type': 'social',
            'invite_code': 'user.3.xxxxx', #TO-DO
        })
        
    recommend_list = sorted(recommend_list, key=lambda article: (article['timestamp']))
        
    return recommend_list

recommend_log = create_recommend(start_dt, t_total, n_recommendation, users)
recommend_log
# Out:
# [{'timestamp': '2021-04-05T03:29:36.908988+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-05T18:11:19.618859+09:00',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-08T13:04:25.667181+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-10T01:03:04.039254+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-11T18:13:43.434599+09:00',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-15T22:22:35.059028+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-17T21:53:29.676277+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-25T09:03:02.864046+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-28T18:56:01.267964+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-30T14:29:19.784764+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'}]

# %%
# Out:
# [{'timestamp': '2021-04-04T01:59:07.384292+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-04T10:50:38.622007+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-06T07:44:13.943625+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-10T22:07:07.303581+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-16T23:44:41.830762+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-19T11:56:57.829558+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-21T05:09:37.503516+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-25T18:15:37.260559+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-29T16:44:44.594265+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'},
#  {'timestamp': '2021-04-30T16:38:50.898111+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx'}]

# %%
log_list = post_log + reply_log + rereply_log + view_log + best_log + reaction_log + reaction_reply_log
log_list += bookmark_log + share_log
log_list += login_log + invitation_log + recommend_log
print(len(log_list))
# Out:
# 780

# %%
#for log in log_list:
#    if log['action_key'] == 'press/like':
#        print(log)

# %% [markdown]
# **후처리**

# %%
# 없는 필드 채우기
def fill_keys(log_list):
    keys = [
        'log_type',
        'user_type',
        'action',
        'value',
        'action_group',
        'action_key',
        'content_type',
        'type_id',
        'content_id',
        'parent_user_id',
        'parent_type',
        'parent_id',
        'voting_power',
        'invite_code',
        'reward_user_id',
        'reward_value',
        'timestamp',
        'voting_power',
        'invite_code',
    ]
    for log in log_list:
        for key in keys:
            if key not in log.keys():
                log[key] = ''

fill_keys(log_list)

# %%
log_list = sorted(log_list, key=lambda article: (article['timestamp']))
log_list

# %% [markdown]
# **파일에 로그 데이터 저장**

# %%
import json
with open('log.json', 'w') as fp:
    json.dump(log_list, fp)

# %% [markdown]
# ## MongoDB 등록
# **주의: DB에 기록됨**

# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
import pymysql
import random
import time


db_host = '182.237.86.231'
db_port = 27217
db_name = 'newmingDB'
db_user = 'newming'
db_pwd = 'u8Yto93qrAgW'

client = MongoClient(db_host, db_port)
db = client['newmingDB']

for log in log_list:
    col = db[log['action_group']]
    col.insert_one(log)

# %%
import json

with open("log.json", "r") as st_json:
    log2 = json.load(st_json)

# %%
log2
# Out:
# [{'timestamp': '2021-04-01T03:34:01.095162+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0001',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-01T05:47:38.853937+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0002',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-01T17:04:36.415728+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0003',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-01T18:29:24.239817+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0004',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-02T03:15:54.116433+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0005',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-02T14:19:23.114336+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0006',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-02T14:53:16.820079+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0007',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-02T17:12:46.200917+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0008',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-03T00:05:29.031666+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0009',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-03T15:26:33.820256+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0010',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T00:36:46.916220+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0011',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T03:32:14.066737+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0012',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T07:08:56.606047+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0013',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T14:18:51.580760+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0014',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T20:09:21.580088+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0015',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T22:29:57.204046+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0016',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-06T05:38:38.779257+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0017',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-06T12:13:04.550526+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0018',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-06T14:38:51.471714+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0019',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T01:06:37.268494+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0020',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T05:48:45.686189+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0021',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T09:03:46.935098+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0022',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T11:32:15.221266+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0023',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T16:09:57.276107+09:00',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0024',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T19:04:58.211649+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0025',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-07T22:45:24.278729+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0026',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T02:53:40.679528+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0027',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T11:23:07.870083+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0028',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T13:23:07.612114+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0029',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T13:52:34.890806+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0030',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-09T02:49:20.123701+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0031',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-09T03:36:41.765572+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0032',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-09T06:49:41.436145+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0033',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-09T16:08:02.378350+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0034',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-09T19:22:02.816394+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0035',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-09T23:27:45.495535+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0036',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-10T06:22:57.802007+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0037',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-10T11:45:50.075332+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0038',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-10T17:13:14.484169+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0039',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-11T09:58:37.905934+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0040',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-11T23:11:18.940285+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0041',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-12T00:01:06.557664+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0042',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-12T14:13:15.518741+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0043',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-12T22:15:33.596991+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0044',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-13T05:26:26.464667+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0045',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-13T06:29:50.650143+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0046',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-13T12:39:48.094911+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0047',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-13T15:06:24.099532+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0048',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-14T13:41:46.382268+09:00',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0049',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-14T15:08:29.054531+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0050',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-14T21:33:38.531166+09:00',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0051',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-14T21:41:50.142057+09:00',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0052',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-15T01:34:15.094697+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0053',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-15T03:42:00.139122+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0054',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-15T18:22:59.336056+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0055',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-16T02:17:23.650098+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0056',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-16T11:58:45.090368+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0057',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-16T20:04:18.257660+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0058',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T02:16:46.283066+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0059',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T05:03:46.583863+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0060',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T08:04:07.694306+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0061',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T13:27:11.847926+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0062',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T14:03:49.042184+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0063',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T16:24:46.800134+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0064',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T18:22:16.750984+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0065',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T23:05:06.907861+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0066',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T01:49:12.339994+09:00',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0067',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T03:46:30.849908+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0068',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T15:49:25.047592+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0069',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T19:29:31.856799+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0070',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T19:51:51.814593+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0071',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-19T03:02:19.058058+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0072',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-19T05:34:29.895380+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0073',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-19T09:25:26.739969+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0074',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-19T12:38:23.491254+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0075',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-19T23:09:52.571825+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0076',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-20T00:15:56.948486+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0077',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-20T08:22:42.576045+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0078',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-20T10:26:47.684442+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0079',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-20T23:14:38.860149+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0080',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-21T07:11:58.465722+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0081',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-21T10:11:32.885458+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0082',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-21T14:08:44.227512+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0083',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-21T16:43:17.024460+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0084',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-21T21:46:42.458149+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0085',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-22T00:23:42.452448+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0086',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-22T02:00:37.536341+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0087',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-22T11:54:41.351767+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0088',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-22T20:34:16.308172+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0089',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-22T23:33:18.558090+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0090',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-23T06:14:01.609011+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0091',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T00:54:13.901283+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0092',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T02:18:36.805304+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0093',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T09:42:37.186208+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0094',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T11:46:16.357735+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0095',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T15:16:03.173155+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0096',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T04:48:59.693501+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0097',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T07:14:14.489935+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0098',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T08:15:33.522018+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0099',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T09:19:03.428652+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0100',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T15:15:19.172493+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'community',
#   'action': 'create',
#   'action_key': 'community/create1',
#   'log_type': 'content',
#   'type_id': 'COPT',
#   'content_type': 'post',
#   'content_id': 'COPT.0101',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T17:13:48.042142+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0102',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T17:18:31.135048+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0103',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T18:43:43.366581+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0104',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-26T14:23:27.883765+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'press',
#   'action': 'create',
#   'action_key': 'press/create1',
#   'log_type': 'content',
#   'type_id': 'COAT',
#   'content_type': 'article',
#   'content_id': 'COPT.0105',
#   'value': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-26T19:46:41.090288+09:00',
#   'user_id': 'u000009',
# ...
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T00:10:47.981539+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-24T13:11:02.457431+09:00',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T06:01:58.712105+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T06:19:34.985296+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-26T01:10:59.196922+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-26T08:29:38.126760+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-26T22:05:44.198727+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-27T11:09:21.816124+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-27T20:57:29.472573+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-28T08:11:48.631438+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-29T20:41:37.726436+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-29T22:56:16.244461+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-30T08:53:23.246965+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-30T20:13:36.542152+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-30T21:13:25.020102+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'login',
#   'action_key': 'common/login',
#   'log_type': 'activity',
#   'value': 1,
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'invite_code': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T08:53:50.885330+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T15:13:19.431752+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T23:57:53.289210+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-12T07:05:37.459296+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T04:06:16.506817+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T04:10:37.975419+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-18T08:28:22.744147+09:00',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-22T03:58:23.472538+09:00',
#   'user_id': 'u000001',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-30T00:03:46.248467+09:00',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-30T23:54:38.104103+09:00',
#   'user_id': 'u000003',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'invitation',
#   'action_key': 'common/invitation',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T03:29:36.908988+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-05T18:11:19.618859+09:00',
#   'user_id': 'u000007',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-08T13:04:25.667181+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-10T01:03:04.039254+09:00',
#   'user_id': 'u000010',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-11T18:13:43.434599+09:00',
#   'user_id': 'u000005',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-15T22:22:35.059028+09:00',
#   'user_id': 'u000004',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-17T21:53:29.676277+09:00',
#   'user_id': 'u000009',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-25T09:03:02.864046+09:00',
#   'user_id': 'u000008',
#   'user_type': 'community',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-28T18:56:01.267964+09:00',
#   'user_id': 'u000006',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''},
#  {'timestamp': '2021-04-30T14:29:19.784764+09:00',
#   'user_id': 'u000002',
#   'user_type': 'press',
#   'action_group': 'common',
#   'action': 'recommender',
#   'action_key': 'common/recommender',
#   'log_type': 'social',
#   'invite_code': 'user.3.xxxxx',
#   'value': '',
#   'content_type': '',
#   'type_id': '',
#   'content_id': '',
#   'parent_user_id': '',
#   'parent_type': '',
#   'parent_id': '',
#   'voting_power': '',
#   'reward_user_id': '',
#   'reward_value': ''}]

# %% [markdown]
# # 이전 소스

# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
import pymysql
import random
import time


db_host = '182.237.86.231'
db_port = 27217
db_name = 'newmingDB'
db_user = 'newming'
db_pwd = 'u8Yto93qrAgW'


def str_time_prop(start, end, format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formated in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, format))
    etime = time.mktime(time.strptime(end, format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%Y-%m-%dT%H:%I:%S', prop)



client = MongoClient(db_host, db_port)
db = client['newmingDB']

for i in range(17):

    log_type = ''
    user_type = ''
    action = ''
    value = ''
    action_group = ''
    action_key = ''
    content_type = ''
    type_id = ''
    content_id = ''
    parent_user_id = ''
    parent_type = ''
    parent_id = ''
    voting_power = ''
    invite_code = ''
    reward_user_id = ''
    reward_value = ''
    timestamp = ''

    if i == 0:
        col = db['press']
        log_type = 'content'
        user_type = 'press'
        action = 'create'
        action_group = 'press'
        action_key = 'press/create1'
        content_type = 'article'
        type_id = 'COAT'
        content_id = 'COAT.key'

    elif i == 1:
        col = db['press']
        log_type = 'info'
        action = 'view'
        value = random.randrange(1, 100)
        action_group = 'press'
        action_key = 'press/view'
        content_type = 'article'
        type_id = 'COAT'
        content_id = 'COAT.key'
    elif i == 2:
        col = db['press']
        log_type = 'content'
        user_type = random.choice(['user', 'expert'])
        action = 'create'
        value = random.randrange(1, 100)
        action_group = 'press'
        action_key = 'press/create2'
        content_type = 'comment'
        type_id = 'CMMT'
        content_id = 'CMMT.seq'
        parent_type = 'article'
        parent_id = 'COAT.key'
        voting_power = random.choice(['y', 'n'])
    elif i == 3:
        col = db['press']
        log_type = 'relation'
        user_type = random.choice(['user', 'expert'])
        action = 'like'
        value = random.randrange(1, 100)
        action_group = 'press'
        action_key = 'press/like'
        content_type = 'article'
        type_id = 'COAT'
        content_id = 'COAT.key'
        voting_power = random.choice(['y', 'n'])
    elif i == 4:
        col = db['press']
        log_type = 'relation'
        user_type = random.choice(['user', 'expert'])
        action = 'bookmark'
        value = random.randrange(1, 100)
        action_group = 'press'
        action_key = 'press/bookmark'
        content_type = 'article'
        type_id = 'COAT'
        content_id = 'COAT.key'
        voting_power = random.choice(['y', 'n'])
    elif i == 5:
        col = db['press']
        log_type = 'relation'
        user_type = random.choice(['user', 'expert'])
        action = 'share'
        action_group = 'press'
        action_key = 'press/share'
        content_type = 'article'
        type_id = 'COAT'
        content_id = 'COAT.key'
    elif i == 6:
        col = db['community']
        log_type = 'content'
        user_type = random.choice(['user', 'expert'])
        action = 'create'
        action_group = 'community'
        action_key = 'community/create1'
        content_type = 'post'
        type_id = 'COPT'
        content_id = 'COPT.key'
    elif i == 7:
        col = db['community']
        log_type = 'content'
        user_type = random.choice(['user', 'expert'])
        action = 'create'
        action_group = 'community'
        action_key = 'community/create2'
        content_type = 'post'
        type_id = 'COPT'
        content_id = 'COPT.key'
        parent_user_id = random.randrange(1, 100)
        parent_type = 'article'
        parent_id = 'COAT.key'
    elif i == 8:
        col = db['community']
        log_type = 'info'
        action = 'view'
        value = random.randrange(1, 100)
        action_group = 'community'
        action_key = 'community/view'
        content_type = 'post'
        type_id = 'COPT'
        content_id = 'COPT.key'
    elif i == 9:
        col = db['community']
        log_type = 'content'
        user_type = random.choice(['press', 'user', 'expert'])
        action = 'create'
        action_group = 'community'
        action_key = 'community/create3'
        content_type = 'comment'
        type_id = 'CMMT'
        content_id = 'CMMT.seq'
        parent_user_id = random.randrange(1, 100)
        parent_type = 'post'
        parent_id = 'COAT.key'
        voting_power = random.choice(['y', 'n'])
    elif i == 10:
        col = db['community']
        log_type = 'relation'
        user_type = random.choice(['user', 'expert'])
        action = 'like'
        value = random.randrange(1, 100)
        action_group = 'community'
        action_key = 'community/like'
        content_type = 'post'
        type_id = 'COPT'
        content_id = 'COPT.key'
        voting_power = random.choice(['y', 'n'])
    elif i == 11:
        col = db['community']
        log_type = 'relation'
        user_type = random.choice(['user', 'expert'])
        action = 'bookmark'
        value = random.randrange(1, 100)
        action_group = 'community'
        action_key = 'community/bookmark'
        content_type = 'post'
        type_id = 'COPT'
        content_id = 'COPT.key'
        voting_power = random.choice(['y', 'n'])
    elif i == 12:
        col = db['community']
        log_type = 'relation'
        user_type = random.choice(['user', 'expert'])
        action = 'share'
        action_group = 'community'
        action_key = 'community/share'
        content_type = 'post'
        type_id = 'COPT'
        content_id = 'COPT.key'
    elif i == 13:
        col = db['community']
        log_type = 'content'
        user_type = random.choice(['user', 'expert'])
        action = 'create'
        value = random.randrange(1, 100)
        action_group = 'community'
        action_key = 'community/create4'
        content_type = 'post'
        type_id = 'CMMT'
        content_id = 'CMMT.seq'
        parent_type = 'comment'
        parent_id = 'CMMT.seq'
        voting_power = random.choice(['y', 'n'])
    elif i == 14:
        col = db['common']
        log_type = 'social'
        user_type = random.choice(['user', 'expert'])
        action = 'recommender'
        action_group = 'common'
        action_key = 'common/recommender'
        invite_code = 'user.3.xxxxxx'
    elif i == 15:
        col = db['common']
        log_type = 'social'
        user_type = random.choice(['user', 'expert'])
        action = 'invitation'
        action_group = 'common'
        action_key = 'common/invitation'
    elif i == 16:
        col = db['common']
        log_type = 'activity'
        user_type = random.choice(['press', 'user', 'expert'])
        action = 'login'
        value = random.randrange(1, 100)
        action_group = 'common'
        action_key = 'common/login'

    for j in range(100):
        if i in [2, 8]:
            user_id = ''
        else:
            user_id = i

        d = {
            'log_type': log_type,
            'user_type': user_type,
            'user_id': j,
            'action': action,
            'action_key': action_key,
            'value': value,
            'action_group': action_group,
            'content_type': content_type,
            'content_id': content_id,
            'parent_user_id': parent_user_id,
            'parent_type': parent_type,
            'parent_id': parent_id,
            'voting_power': voting_power,
            'invite_code': invite_code,
            'reward_user_id': reward_user_id,
            'reward_value': reward_value,
            'timestamp' : random_date("2021-03-01T01:01:01", "2021-04-30T01:01:01", random.random()),
        }

        #x = col.insert_one(d)
