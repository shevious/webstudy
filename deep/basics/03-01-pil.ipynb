# %%
from tensorflow import keras
import numpy as np
from matplotlib import pyplot as plt

# URL로부터 이미지 파일 저장

img_url = 'http://sipi.usc.edu/database/preview/misc/4.2.01.png'
filename = 'milk.png'
#img_url = 'https://www.fnordware.com/superpng/pnggrad16rgba.png'
#filename = 'alpha.png'
#img_url = 'http://data.si.re.kr/photo_ndownload/21555'
#filename = 'seoul.jpg'

img_path = keras.utils.get_file(filename, img_url)
img_path
# Out:
# '/home/kotech/.keras/datasets/milk.png'

# %%
import cv2

image = cv2.imread(img_path)
#cv2.imwrite('test.png', image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imsave('test.png', img)

# %%
from PIL import Image
img = Image.open('test.png')
print(img.mode)
np.array(img).shape # channel is 4!!!
# Out:
# RGBA
# (600, 600, 4)

# %%
from matplotlib import image as mp_image
img = mp_image.imread('test.png')
img.shape
# Out:
# (600, 600, 4)

# %%
img = cv2.imread('test.png')
img.shape
# Out:
# (600, 600, 3)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from tensorflow import keras
import matplotlib.pyplot as plt
import cv2
image_path = keras.utils.get_file("Lampuuk_beach.jpg", "https://images.unsplash.com/photo-1506477331477-33d5d8b3dc85?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=674&q=80")
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(3248/250, 2425/250))
plt.xticks([])
plt.yticks([])
plt.imshow(image)
plt.show()
# Out:
# ...
# 188416/177791 [===============================] - 0s 0us/step

# %%
kernel = np.array([[1, 1, 1],
                   [1, 1, 1],
                   [1, 1, 1],],)
image2 = cv2.filter2D(image, -1, kernel, borderType=cv2.BORDER_CONSTANT)
