# %%
from modules.utils import load_yaml, save_pickle, save_json, load_csv, save_csv
from modules.datasets import QADataset
from models.utils import get_model

from transformers import ElectraTokenizerFast, AutoTokenizer

from torch.utils.data import DataLoader

from datetime import datetime, timezone, timedelta
from tqdm import tqdm
import numpy as np
import pandas as pd
import random
import os
import torch

# %%
# Config
PROJECT_DIR = os.path.dirname('.')
predict_config = load_yaml(os.path.join(PROJECT_DIR, 'config', 'predict_config.yml'))

# Serial
train_serial = predict_config['TRAIN']['train_serial']
kst = timezone(timedelta(hours=9))
predict_timestamp = datetime.now(tz=kst).strftime("%Y%m%d_%H%M%S")
predict_serial = train_serial + '_' + predict_timestamp

# Predict directory
PREDICT_DIR = os.path.join(PROJECT_DIR, 'results', 'predict', predict_serial)
os.makedirs(PREDICT_DIR, exist_ok=True)

# Data Directory
DATA_DIR = predict_config['DIRECTORY']['dataset']

# Train config
RECORDER_DIR = os.path.join(PROJECT_DIR, 'results', 'train', train_serial)
train_config = load_yaml(os.path.join(RECORDER_DIR, 'train_config.yml'))

# SEED
torch.manual_seed(predict_config['PREDICT']['seed'])
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(predict_config['PREDICT']['seed'])
random.seed(predict_config['PREDICT']['seed'])

# GPU
os.environ['CUDA_VISIBLE_DEVICES'] = str(predict_config['PREDICT']['gpu'])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load tokenizer

tokenizer_dict = {'ElectraTokenizerFast': AutoTokenizer}
tokenizer = tokenizer_dict[train_config['TRAINER']['tokenizer']].from_pretrained(train_config['TRAINER']['pretrained'])

# Load data

test_dataset = QADataset(data_dir=os.path.join(DATA_DIR, 'test.json'), tokenizer = tokenizer, max_seq_len = 512, mode = 'test')

question_ids = test_dataset.question_ids

BATCH_SIZE = train_config['DATALOADER']['batch_size']

test_dataloader = DataLoader(dataset=test_dataset,
                            batch_size=BATCH_SIZE,
                            num_workers=train_config['DATALOADER']['num_workers'],
                            shuffle=False,
                            pin_memory=train_config['DATALOADER']['pin_memory'],
                            drop_last=train_config['DATALOADER']['drop_last'])

# Load model
model_name = train_config['TRAINER']['model']
# model_args = train_config['MODEL'][model_name]
model = get_model(model_name=model_name, pretrained=train_config['TRAINER']['pretrained']).to(device)

checkpoint = torch.load(os.path.join(RECORDER_DIR, 'model.pt'))

if train_config['TRAINER']['amp'] == True:
    from apex import amp
    model = amp.initialize(model, opt_level='O1')
    model.load_state_dict(checkpoint['model'])
    amp.load_state_dict(checkpoint['amp'])

else:
    model.load_state_dict(checkpoint['model'])

model.eval()
pred_df = load_csv(os.path.join(DATA_DIR, 'sample_submission.csv'))

for batch_index, batch in enumerate(tqdm(test_dataloader, leave=True)):
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)

    # Inference
    outputs = model(input_ids, attention_mask=attention_mask)

    start_score = outputs.start_logits
    end_score = outputs.end_logits

    start_idx = torch.argmax(start_score, dim=1).cpu().tolist()
    end_idx = torch.argmax(end_score, dim=1).cpu().tolist()

    y_pred = []
    for i in range(len(input_ids)):
        if start_idx[i] > end_idx[i]:
            output = ''

        ans_txt = tokenizer.decode(input_ids[i][start_idx[i]:end_idx[i]+1]).replace('#','')

        if ans_txt == '[CLS]':
            ans_txt == ''

        y_pred.append(ans_txt)

    q_end_idx = BATCH_SIZE*batch_index + len(y_pred)
    for q_id, pred in zip(question_ids[BATCH_SIZE*batch_index:q_end_idx], y_pred):
        pred_df.loc[pred_df['question_id'] == q_id,'answer_text'] = pred

save_csv(os.path.join(PREDICT_DIR, 'prediction.csv'), pred_df)
# Out:
# Some weights of the model checkpoint at monologg/koelectra-base-v3-discriminator were not used when initializing ElectraForQuestionAnswering: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForQuestionAnswering were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 102/102 [00:07<00:00, 13.96it/s]

# %%
pred_df
# Out:
#           question_id               answer_text
# 0     QUES_cyOI2451l1                한국원자력안전기술원
# 1     QUES_pz2vbWpWWo                  가출청소년 문제
# 2     QUES_1g3jI4y7eo                      고등학생
# 3     QUES_qzwOZwaeeY                 Prime Air
# 4     QUES_hfdtXCtdzf                  장애인케어서비스
# ...               ...                       ...
# 1621  QUES_JtsKBSQITG                 고령층 임금근로자
# 1622  QUES_IajaDLmxvq                     가처분소득
# 1623  QUES_lR6hjzsptY                대체보육서비스 비용
# 1624  QUES_ACwZJGYBfp  IBM Food Trust Labeyrie사
# 1625  QUES_UB3Fj0NPIX                     2009년
#
# [1626 rows x 2 columns]

# %%
test_df = pd.read_csv('test_raw.csv')

# %%
total_count = 0
correct_count = 0
for i, row in test_df.iterrows():
    pred = pred_df[pred_df['question_id']==row.question_id]['answer_text'].values[0]
    row.pred = pred
    if row.pred.strip(' ') == row.answer.strip(' '):
        correct_count += 1
    else:
        print(row.answer, "!=", row.pred)
    total_count += 1
print(total_count, correct_count)
print('accuracy =', correct_count/float(total_count))
# Out:
# 탐색기 != 고등학생
# 사례 담당자 != 사례 담당자의 배치가 필요하다. 이를 위해서는 우선적으로 현재 활동지원서비스 중개기관과는 별도로 활동지원서비스를 모니터링 할 수 있는 새로운 기관이나 인력의 배치가 필요하다. 대표적인 방법이 국민연금공단에 장애인 사례담당인력
# 정시도착률 != 리포팅 항공사 ’ 들의 운항 정보는 항공교통이용자 보고서에 기존처럼 계속 포함되고, 이에 더하여 ‘ 마케팅 항공사 ( marketing carrier ) ’ 들의 항공 서비스 품질 데이터가 추가된 것이다. 예로, 지난 7월 한 달 동안의 데이터를 바탕으로 마련된 최신 항공교통이용자 보고서는 정시도착률이 가장 높았던 ‘ 마케팅 항공사 ’ 를 순서대로 하와이안항공 네트워크
# 유나이티드익스프레스 != 간선 항공사
# ADS-B 리베이트 프로그램 != ADS - B 리베이트 프로그램
# 인센티브 경매 != 자발적 권리 반납은 주파수에 대한 완전한 권리의 포기뿐만 아니라 타 대역으로의 주파수 이동, 주파수 공유를 포함하고 있다. 따라서 기존의 주파수 할당에서 볼 수 없는 주파수 재배치 과정
# 3년 이하 != 3년
# 물리적 세계 및 프로세스 != 디지털 트윈
# 대외적 구속력 != 작용법적 근거 마련
# 잠열 저장 != 현열 저장
# 스타트업 != 관광스타트업
# 2014년 !=
# 선택적/수직적 수단 != 선택적 / 수직적 수단
# 시민권 행사 !=
# 유교윤리 != 간음행위
# 위법성조각사유의 법적 한계 !=
# 위-수탁의 관계 !=
# 근린재생형 != 도시재생 활성화 미 지원에 관한 특별법
# 주요 수종별 및 임령별 != IPCC GPG 산출방법의 검토 및 적용성 검증이 필요하다. 산림 내 잔존하는 바이오매스 부후에 대한 보다 과학적인 접근법이 요구되며, 고사목에 대한 탄소저장량 추정을 위한 모델 구축이 필요하다. 토양탄소 저장량 / 변화량 도출을 위한 모니터링 시스템 구축 및 토양탄소모델 개발
# 범죄피해재산 != 범죄피해재산의 피해자 환부제도
# 진실과 정의의 원칙 != 범죄피해재산의 회복에 관여하는 것이 법적인 관점에서 합리성이 인정된다면 다음으로는 입법정책상 필요한가의 논의로 이어져야 할 것이다. 행정정책상 제도
# 독일 != 형집행정지심의위원회
# 국립병원 != 보호관찰소
# 병원별․근속기간별 !=
# 미국 != 미국의 체납징수 민간위탁
# 2006년도 != 민간위탁징수제도
# 쿠퍼스미스 !=
# 통계청 != 초등학교
# 6% != 6 % 대의
# 스위스 !=
# 19% != 8천6백만 배럴 / 일을 상회하며 이 중 32 % 가 중동지역에서, 20 % 가 유럽과 러시아지역에서, 19 % 가 북미지역에서 생산되고 있다. 국가단위로 최대 석유생산국은 사우디아라비아, 러시아, 미국 순으로 전 세계 원유생산의 약 40 % 가 이 3개 국가에서 생산되고 있다. 세계 석유시장에서 국제거래량은 2007 - 2008년의 금융위기 기간 이전까지 엄청난 속도로 증가해 전 세계적으로 3조 달러에 달했다. 금융 위기 기간을 거치며 절반수준으로 하락하였으나 최근 들어 다시 소폭 증가하는 추세를 보이고 있다. 석유 거래의 방식과 거래 시장은 몇 가지 특징에 의해서 분류된다. 먼저 거래 시점에서 실물이 인수되는지 여부에 따라 실물시장과 파생상품시장
# 리모델링 주택조합 또는 주택건설사업계획 != 신탁등기
# 접근성 != 소규모 노인복지관
# 123억 3,300만원 != 세대간상생고용지원 사업
# 적절한 기업현장교사 != 기업현장교사
# PAS 기반 후각센 != PAS 기반 후각센서는
# 한국경제의 성장률 하향조정 != 메르스
# 저량 != 유량 ( flow ) 분석
# 전공-직무 불일치 확률 != 전공 - 직무 불일치 확률
# 5.31 교육개혁 != 5. 31 교육개혁
# 부산 진로진학지원센터 != 진로체험정보는 학생들이 진로체험을 할 수 있는 교육프로그램이나 체험처에 관한 것이다. 세종시를 포함하여 17개 시 · 도 중에서 8개 지역의 진로진학정보센터가 진로체험정보를 제공하고 있다. 정보량은 지역에 따라 큰 편차가 있으나 체험처에 관한 정보는 체험프로그램을 제공하는 기관명, 소요시간, 운영기간, 참가대상, 담당자 연락처, 등이다. 부산, 대전, 광주, 전남, 제주의 진로진학센터가 상대적으로 풍부한 정보를 제공하고 있다. 진로체험정보는 대부분 지역 교육청이나 진로진학정보센터가 직접 생산한 정보들로 교육 현장의 수요를 반영하고 있다는 점에서 매우 의의가 크다. 17개 시 · 도 중에서 9개 지역은 인터넷홈페이지에서 진로체험정보를 제공하지 못하고 있으니. 이들 지역에서도 오프라인으로 공문이나 교원연수 등을 통해 진로체험프로그램이나 체험처에 관한 정보를 제공할 가능성도 있다. 부산 진로진학지원센터
# 특성화고등학교 관련 정보서비스 != 특성화고등학교 관련 정보서비스 제공 사이트
# 자문회의 != 공연장상주단체육성지원사업
# 온실가스 감축 != 시장을 이용한 온실가스 감축
# 국토교통부 산하 != 국토교통부
# 100% != 인권추진원 제도는 직업선택의 자유, 취업의 기회 균등과 고용촉진을 도모하기 위하여 상시 사용하는 종업원의 수가 50인 이상인 사업장, 상시 사용하는 종업원의 수가 50인 미만이며 채용 차별사건 또는 그것과 유사한 상황을 야기한 사업장에 대해 공공직업안정소가 인권추진원
# 영국 != 평등인권위원회
# 2018년 7월 != 등록대상 기존 화학물질
# 시장․군수․구청장 != 시장 ․ 군수 ․ 구청장
# 맥락 !=
# 착취 != 탐관오리
# 5~7년 != 방사청의 전문 인력이 국방부 및 각 군의 전력지원체계 부서에 순환 근무하는 프로그램을 운영하여 획득 전문기법을 전파할 필요가 있다. 현재 방사청
# 약 3조 4,725억원 != 혈세 먹는 하마
# KEEP != 한국교육고용패널
# 토지등소유자 != 토지등소유자 과반수
# 주거환경개선사업 != 지역 간 불균형
# 공동체기반의 구역선정과 사업계획 수립 != 인천 저층주거지관리사업
# 거더 단부 상단 !=
# 한국 != 한국사
# 보험요율 산출 != 다수경제
# 미러관계 != 3단계 실천과제 수행을 통해 구체화될 수 있다. 대러 외교
# 성취평가제 != 일반 교사의 역량 강화
# 행 재정적인 지원 방안 != 교사공동체
# 2009년도 != 한국국제아트페어 ( KIAF ) 에 개최 이후 가장 적은 수의 ( 16개국 168개 ) 화랑이 참여하여 역대 가장 저조한 참여율을 보였다. 이를 포함하여 지속되어 왔던 문제점 중 하나인 전시형태문제를 극복하기 위해 한국국제아트페어 ( KIAF ) 는 2011년
# 내/외부의 전문가 패널 != 군사전략은 종종 실패하기도 했으며, 전략가들은 끊임없이 실패하지 않는 전략을 만들기 위해 노력해 왔다. 군사전략의 실패원인이 때로는 의사결정의 실수
# EU != 니트
# 비즈니스 모델 != 특허괴물
# 친환경주택에 대한 초기비용투자 != 티핑포인트
# 경제성 != 에너지절감비용
# 군사적으로 개입 != 인도적 개입
# 2002년 11월 25일 != 국토안보부는 테러방지 및 대응과 관련된 일을 하는 연방기관 중에서 가장 늦게 생겼으면서도 가장 복잡한 기관이다. 국토안보구가 설립된 2002년 이전에는 국가안보와 관련된 업무는 40개 이상의 연방정부에 의해 수행되어왔다. 앞에서 설명했듯이 국토안보부와 유사한 기능을 가진 기관의 설립에 대한 제안은 9 ･ 11 테러사건 이전부터 있었으나 부시행정부는 초기에 이러한 기관의 설립과 관련된 법안에 반대하였다. 그러나 9 ･ 11 사건 이후 부시행정부는 결국 이러한 법안을 지지하게 되었고 당초 의회에서 제안된 법안보다 더 확장된 법안인 국토안보법 ( Homeland Security Act of 2002 ) 을 제안하였고 2002년 11월 25일
# 협력체계 !=
# 루트비히 1세 != 발할라는
# 성분조성 != 지렁이분
# 냉방수요 != 시설의 냉방수요
# 지역 브랜드자산 !=
# 사용자의 지위 != 사업이전
# EEC 경제사회위원회 !=
# 일·가정 양립 직장문화 != 직장의 근로여건
# 18조 != 통계승인업무처리 지침
# 미국 != 반접근 / 지역거부 전략
# 책임을 스스로 인정하는 것 != 스스로 인정하는 것
# WEO 2015 != 저유가
# 사과 != 맛있는 사과
# 연령 분리적인 사회 != 연령 통합성을 제고하기 위한 노력이 이루어져야 할 것이다. 현재 우리 사회는 모든 정책과 제도가 노동을 준비하기 위한 교육 단계인 청소년기와, 노동의 시기인 중년기, 은퇴 후 사회로부터 분리되어 여가를 즐기는 노년기라는 엄격한 구분에 기초한 연령 분리적인 사회
# 560톤 != 패션프루트
# 논문·특허 성과 != 논문 · 특허 성과
# 의약바이오 != 의약바이오의 경우 타 분야보다 개발기간이 매우 긴 의약바이오분야
# 5위 != 한국자동차산업협회
# 지표 != 건전한 투자자
# 사단 작전참모 != 군수지원능력
# 경제활동참여율 != 여성의 경제활동참여율
# Kossek & O zeki != 일 - 가정 갈등지각이 높을수록 경력만족에 부정적인 영향을 미친다는 것을 밝혔다. M artins
# 가정생활 != 가정생활 만족
# 아오모리현 != 고향의사지원제도
# 인구정책의 설계와 평가 != 인구정책
# 유연성 !=
# 수업 != 순차적 구조
# 유목민족 != 유목민족들
# 진상 != 허위
# 7월 != 2012년 전국 다문화가족 실태조사 」 ( 이하, 다문화조사 ) 의 원자료 ( raw data ) 이다. 다문화조사는 우리나라의 다문화 가정에 대한 전반적인 조사를 하는 데이터일 뿐만 아니라 전국을 대표하고 있는 유일한 데이터이다. 따라서 이 데이터를 사용한 연구는 모집단의 특성에 가장 가까운 결과를 도출할 수 있는 최대 장점이 있다. 이 조사는 2012년 7월 10일～2012년 7월 31일에 걸쳐서 이루어졌고, 조사 대상은 네 부류로 나눌 수 있는데, 전국의 다문화가족 15, 341가구, 결혼이민자 ․ 귀화자 총 15, 001명 ( 여성 12, 531명, 남성 2, 470명 ), 결혼이민자의 배우자 총 13, 859명 ( 여성 2, 278명, 남성 11, 581명 ), 만 9～24세의 결혼이민자 자녀 총 4, 775명 ( 여성 2, 271명, 남성 2, 504명 ) 으로 구성된다. [SEP] 2012년 전국 다문화가족 실태조사가 진행된 건 몇 월
# 언어 능력 != 이민국의 언어 능력
# 복잡한 설계방식을 채택하는 방식 != 복잡한 설계방식
# 왓슨 포 지노믹스 != 왓슨 포 온콜로지
# 공동체 의식 !=
# ILO != 연성법 이니셔티브
# 관련 부처 및 이해당사자 != OECD 스킬 전략
# 핀란드 != 덴마크
# Holton과 Baldwin !=
# 위험추구 != 과도한 위험추구 ( excessive risk - taking ) 경향
# 행정처분 !=
# 부작용 != 태반주사
# 헬레보러스 != 헬레보러스 ( Helleborus niger ) 는 미나리아재비과에 속하는 여러해살이풀이다. 유럽 중부와 동남부, 아시아 서부지역의 숲, 초원, 바위틈 등지에 15 종이 분포하며 원예종으로 많은 품종이 나와 있다. 크리스마스로즈
# 발명진흥법 != 구 발명진흥법
# UNFCCC != 기후변화
# 80% !=
# 교과서 != 창의성 사고를 지향한다고 하겠습니다. 따라서 비록 그 장이 학교이고, 주인공은 학생과 교육자 학부모
# 소상공인법 제13조 제2항 !=
# 곤충사육사, 드론조종사 != 곤충사육사, 드론조종사 등의 직업
# 고용연금부의 웹싸이트 != 고용 지원 서비스를 받게 될 지 알 권리가 있다. 따라서 서비스 공급자들은 입찰 조건의 하나로 자신들이 제공할 최소한의 서비스를 포함한 모든 서비스를 제시해야 한다. 이 서비스 내용은 입찰 심사의 평가 대상이며, 계약 체결 후에도 지켜져야만 한다. 실업자들은 자신이 ‘ 고용계획 ’ 에 위탁될 때 자신들이 받게 될 최소한의 서비스에 대한 설명을 듣게 되며 이는 고용연금부의 웹싸이트에 공지된다. 이런 장치는 고용지원 서비스의 투명성과 공급자의 책임감을 높여준다. 이와 관련하여 ‘ 고용계획 ’ 은 고객 불만 처리 제도 ( customer complaints process ) 도 도입했다. 서비스 공급자들은 구직센터 플러스 ( JCP ) 로부터 실업자들을 위탁받을 때 이들에게 불만 제기 절차를 알려줘야만 한다. 만약 공급자가 ‘ 고용계획 ’ 참여자의 불만을 만족스럽게 해소시켜주지 못한다면, 참여자는 고용연급부가 별도로 계약을 맺은 조정자인 독립 사건 조사관
# 35% !=
# 5.3% != 중소기업 기술혁신개발사업
# 절도죄 != 사기죄의 보호법익에 관한 문제부터 짚어볼 필요가 있다. 확실히 학설이 인정하는 대로 사기죄의 보호법익에는─의사결정의 자유는 별론으로 하고─재산이 포함된다. 따라서 사기죄는 그것이 침해범임을 전제로 할 때에 보호법익인 재산이 침해되어야 기수에 이른다. 그렇다면 이제 논의의 흐름에 따라, 보호법익으로서의 재산이 침해된다고 하는 것이 대체 무슨 함의를 가지는지를 살펴볼 순서이다. 절도죄를 예로 들면, 동죄의 기수는 재물이 점유자로부터 행위자에게 옮겨간 때에 성립한다. 즉, 기수의 성립에 점유의 이전을 필요로 한다는 점에서 절도죄는 이전죄 ( 移 轉 罪 ) 라고 설명된다. 설사 행위자가 재물을 절취하면서 그 가치만큼의 금전을 놓고 나왔더라도 절도죄의 성립에는 소장이 없다. 절도죄에서 법익의 침해는 재물의 점유를 빼앗아 감으로써 권리자가 이를 용익 ․ 처분하는 것을 방해하는 데에 그 본질이 있기 때문이다. 판례가 절도죄
# 싱가포르 != 싱가포르 탐오조사국
# 헌법상 한계 영역 != 시원적 행정 영역
# 통근강도 != 지역노동시장권
# 육아휴직 보너스제도 != 남성 육아휴직 보너스제도
# 가사노동시간 != 육아휴직
# 2017년 6월 18일 !=
# 대통령 또는 기획재정부 장관 != 주무기관의 장이 임명한다 ( 공운법 제25조 제1항 ). 공기업 및 준정부기관의 이사회는 기관장을 포함하여 15인 이내의 이사로 구성된다. 시장형 공기업과 자산 규모가 2조원 이상인 준시장형 공기업의 이사회 의장은 선임비상임이사가 되며, 자산 규모가 2조원 미만인 준시장형 공기업과 준정부기관의 이사회의장은 기관장이 된다. 공기업의 상임이사는 공기업의 장이 임명한다. 다만, 감사위원회의 감사위원이 되는 상임이사 ( 상임감사위원
# 극영화나 애니메이션 != K - drama
# 프랑스 != 운전면허 후보자가 시험을 본다고 한다. 대학입시 응시생 34만 명이니, 이를 훌쩍 뛰어넘는 수준이다. 그나마 운전면허 합격률은 60 % 에 불과하기 때문에 40 % 는 다음 해로 이월되곤 한다. 유럽공동체에서는 각 회원국의 운전면허제도의 통일성을 기하기 위해 가칭 “ 길버트 위원회 ” 를 조직하여 2013년 가을부터 9개월 동안 각국을 조사하여, 실태 보고서를 발간했다. 그 보고서 중에서, 프랑스 내무부 장관인 베르나르 까즈뇌브
# 통합군사령부 != 유엔군사령부
# 교사 학습 공동체 != 교사 학습 공동체 ( Teacher ’ s Learning Communities ) ’ 를 통한 협력적 태도이다. 학습 공동체
# 월드 뱅크 != MINT ( 멕시코, 인도네이시아, 나이지리아, 터키 ) 와 같은 유망시장을 발굴하여 맞춤형 진출 지원방안을 모색하는 정책 노력은 시장 위험을 줄여주면서 진출 가능성을 높일 수 있다는 점에서 매우 바람직하다. 셋째, 저성장 탈출 대책의 일환으로 핀테크, 클라우드, 빅데이터, IOT, 바이오, 헬스케어 등 ICT융복합 첨단산업 육성을 통해 내수 진작을 도모하는 선진국의 산업 정책을 활용하여 중소기업의 글로벌화를 촉진하는 방안을 생각할 수 있다. 이들 분야의 기술력을 갖춘 우리 중소기업들은 전통적 중소기업에 비해 태생적으로 도전적 성향이 강한 글로벌 스타트업 또는 본 글로벌
# 자아 != 자아정체성
# 대남무력도발 != 무력도발
# 자아존중감 != 자아존중감의 하락
# 클라우드컴퓨팅법 != 클라우드에 저장된 이용자의 정보
# 형사 소송법 != 기록명령부 압수 ( 記 [UNK] 命 令 付 差 [UNK] [UNK] ) 제도 ’ 를 도입 ( 日 本 刑 訴 法 第 99 [UNK] の2 ) 하였고, 압수할 물건이 “ 전자적 기록에 관련된 기록매체 ( 電 磁 的 記 [UNK] に 係 る 記 [UNK] [UNK] [UNK] ) 일 경우 ” 에 있어서 그 구체적 압수방법 ( 日 本 刑 訴 法 第 110 [UNK] の2 ) 을 명문화하였다. 우리나라의 경우에도 그동안의 연구결과를 토대로 2011년 ｢ 형사소송법 ｣ 이 개정되어 “ 정보저장매체 등에 관한 압수의 범위와 방법을 명시 ” 하는 등 전자정보 압수수색에 관한 종래의 법적 미비상태를 어느 정도 보완하였다. [SEP] 일본은 어떤 법 개정을 통해 기록명령부 압수 제도
# 세금계산서 != 허위의 세금계산서
# 부가가치세, 법인세 및 소득세 등에 대한 부당감면의 목적 !=
# 과학기술 != 과학기술의 발달도 노동시장에서 일하고 있는 인적자원의 역량을 퇴화시킨다. 과학기술의 발달
# 핀란드 != 대학입학자격시험을 치루지 않고 고졸 재직근로자가 정규대학으로 바로 입학하는 경우는 드물다. 따라서 고졸 재직근로자들은 성인직업교육훈련 제공기관이나 고용주를 위한 노조 ( ammattiliitot ) 및 직무능력 신장을 위한 기구 ( ammatinedistämislaitos ) 에서 제공하는 비형식교육훈련을 받는다. 또 대학부설의 개방대학 ( Avoin Yliopisto, Open university ) 이나 계속교육센터 ( täydennyskoulutuskeskukset, Center for Continuing Education ) 와 같은 형식교육을 통해 고등교육에 접근한다. 새로운 자격획득이나 소프트웨어 장비 및 기술사용을 목적으로 제공하는 대부분의 전문직무역량 강화훈련은 고용주들이 훈련기관에 단기과정으로 위탁한다. 핀란드
# 산림기본법 !=
# 2차 피해를 입히는 문제 !=
# 간음죄 != 업무상 위력에 의한 간음죄
# 695점 != 아랍에미리트 ( 13점 ) 뿐이었다. 싱가포르와 상하이 - 중국을 포함한 6개국은 남녀 간 성차가 없었다. PISA 2012 CBAM의 성취도를 백분위별 점수로 살펴본 결과, 우리나라 학생들의 상위 5 % ( 95백분위 ) 에 해당하는 점수는 695점
# 세 번째 != 6수준
# 세종실록 60권 != 양화소록
# 확인대상발명 != 확인대상발명은 당해 특허발명과 서로 대비할 수 있을 만큼 구체적으로 특정되어야 하는 것인바, 그 특정을 위하여 대상물의 구체적인 구성을 전부 기재할 필요는 없다고 하더라도 특허발명의 구성요건에 대응하는 부분의 구체적인 구성을 기재하여야 하며, 그 구체적인 구성의 기재는 특허발명의 구성요건에 대비하여 그 차이점을 판단함에 필요한 정도는 되어야 할 것이고, 만약 확인대상발명
# 교육부 != 조기 개입에 해당하는 서비스를 받고 있는 것으로 나타나고 있다. 보건복지부가 시행 중인 ‘ 영유아건강검진 ’ 을 통한 장애 조기 발견 과정과 조기 개입의 연계가 체계적으로 이루어지지 않아서, 발달평가를 통한 선별 후 장애인등록 ( 장애 ) 진단서 특수교육대상자 판정 등의 과정을 거쳐서 조기 개입이 필요한 추정 영유아의 16. 9 % 만이 무상교육이나 보육 서비스
# 13.5% != 조기퇴사
# 박근혜 정부 != 능력중심 사회
# 배우자 != 배우자의 소득 수준
# 정례적인 이벤트 != 보상
# 현문수 != 참여형 아카이브
# 1,799원 != 전자담배
# 한국전력 != 러시아 원목 수출 금지법
# 비상사태특조령 != 부역자로 사형이 확정된 사람에 대하여 검찰국장, 법무부장관, 국무총리의 순서를 거쳐 무기징역으로의 감형 재가가 이어지자 대통령이 형량을 15년형으로 낮출 것을 허가하는 과정에서 나타났다. 감형대상자
# 6개월 이내 !=
# 13명 != 송월숲 아이들의 휘파람 소리
# 간호사 != 간호사 면허증
# 전력거래소 != 전력거래소는 EMS의 SCED 기능을 통해 전력계통의 안전도 제약 조건 ( 송전제약, 발전기 운전제약, 예비력 제약 ) 을 고려하여 급전 대상 발전기에 대한 출력 상하 · 한범위를 결정하고 있다. ｢ 운영규칙 ｣ 제5. 4. 2조에 따르면 전력거래소는 전력계통 제약 및 혼잡을 가장 경제적이고 효과적으로 관리하도록 되어 있고, ｢ 전력계통 신뢰도 및 전기품질 유지기준 ｣ ( 산업통상자원부 고시 제2015 - 112호 ) 제9조에 따르면 전력거래소는 주요 간선계통에 이중고장이 발생하더라도 계통분리 또는 전압 불안정이 발생하지 않도록 안정성 유지기준을 준수하도록 되어 있다. 그리고 EMS의 SCED 기능
# 기하평균 !=
# 진상규명 != 3차 가해
# 특별법 제정 !=
# 학부모회 != 학교 취업률이 낮아졌다. 그 이유는 무엇인가? 주지하다시피, 우리나라 학부모의 자녀 학력에 대한 기대 수준은 상당히 높다 ( 강창동, 2008 ; 김경근, 2003 ). 비록 여러 가지 이유로 특성화고에 진학을 하였다고 할지라도 기회가 주어진다면 자녀가 대학교육을 받길 기대한다. 본 연구에서도 이러한 점을 확인할 수 있는데, 조사대상 학부모의 88. 3 % 는 자녀가 전문대학 이상의 학력을 취득하길 기대하고 있다. 학교운영위원회는 학교 경영 전반에 관한 ‘ 심의 ’ 권한을 가진 법정기구이며, 학부모회는 학교 운영에 필요한 인적 ․ 물적 자원을 지원하기 위한 비법정단체로서 학부모는 이들 두 단체의 활동을 통해 학교 운영에 관한 그들의 기대와 요구를 공식적 ․ 비공식적으로 전달하게 된다. 학부모의 경영참여
# 1960년대 != 특성화고는 고교 수준의 기능인력 양성과 졸업 후 취업을 목표로 하는 완성교육의 성격을 가지고 운영되었다. 그러나 1990년대 들어 특성화고의 취업률이 점차 낮아지기 시작하면서 직업교육기관으로서의 정체성에 대한 문제가 제기되었다. 2002년
# 사립학교교직원연금공단 이사장 !=
# 1995. 12. 29 != 1995. 12. 29. 신설되어 1996. 1. 1
# 이론면, 실천면, 현장 경험면 != 특별 교과 도덕
# 학교 != 특별 교과 도덕
# 신학습지도요령 != 학교 주 5일제
# 독일 != 교통교육
# 재해대책기본법 != JARTIC
# 긍정적인 영향 != 부정적 고용효과
# 키르기스스탄 정부 != 지하경제 양성화
# 2억 5천만 원 != 광제산영농협동조합법인
# 한-터키 성실무역업체 상호인정약정 != 한 - 터키 성실무역업체 상호인정약정 ( 이하 AEO MRA ) ’ 을 체결하여 유라시아 지역으로의 수출증진을 위한 교두보를 마련했다. 한 - 터키 AEO MRA
# 관련성 != 절차적 정당성
# 장전된 총기를 은폐하여 소지한 혐의 != Riley v. California, 573 U. S. ( 2014 ) ’ 판결에서는 디지털 증거와 관련된 사안이 다루어지게 되었다. Riely는 승용차 번호판 기간이 만료되었고, 면허가 정지된 사실로 인해 차량이 견인조치 되었고, 그 과정에서 차량 안에 숨겨져 있었던 장전된 총 두 자루가 발견되었다. 그래서 경찰은 장전된 총기를 은폐하여 소지한 혐의로 Riely를 체포한 뒤 그의 스마트폰
# 해군사령부 !=
# 취업 != 취업제한
# 1984 != 1984년
# 연방경찰 외국인담당 부서 != 영주권을 받고 2년 이상 거주한 자의 가족 ( 위에 언급한 가족 ) 은 외국에서 대학원, 특별 직업훈련, 연구직 등에 종사하고 있을 경우 연령에 제한 없이 가족과 합류할 수 있도록 영주권이 발급됩니다. 브라질 내에서는 연방경찰 외국인담당 부서
# 커다란 배 모양 != 스시 & 사시미 세트 메뉴
# 2015년 != 2012년
# 2013년 != 2013년 이후
# 실주행 데이터 != 자율주행차
# 연산력 증대 != 개방형 블록체인
# 각국 법원의 권한 !=
# 중재판정부 != 둘 이상의 투자자들이 투자유치국의 특정 조치에 대하여 공동으로 투자중재를 제소하거나, ‘ 투자 ’ 에 공동으로 출자하여 지분을 가지고 있는 경우 등 다양한 이해관계를 가지고 투자중재를 제기한 경우이다. 중재 신청인이 복수인 경우, 중재판정부
# 남북정상회담과 북미정상회담 !=
# 무분별한 포괄임금제 !=
# 탄금대 != 쇠돛대
# 2015년과 2016년 !=
# 자율주행자동차 !=
# 아동청소년 != 아동친화도시 원칙으로는 국가 및 학교의 아동권리 전략 개발, 관련 예산의 확보, 아동권리의 홍보를 통해 이룰 수 있다. 지역사회에서의 소극적 권리
# 광복70년기념사업추진위원회 != 세종문화회관 세종홀
# 베를린 != 신탁관리청
# 국·공립 유치원 != 국 · 공립 유치원
# 0∼2세 != 교육부
# 사고와 활동의 레퍼토리 !=
# 미국이나 영국 != 경제협력에 대한 중요성이 크다. 이러한 관점에서 한국과 유사한 공여국이 독일, 일본, 프랑스 등이다. 따라서 한국의 개발협력체계 구성이 이 국가들과 비슷한 방향으로 진화하고 있는 것은 자연스러운 일로 보인다. 한국이 북유럽 국가들과 같이 전액 무상원조를 통한 외교적 채널과 국제규범 형성을 통해 자국의 영향력을 극대화하거나, 미국이나 영국과 같이 세계질서 운영의 관점에서 영향을 미치는 방향으로 개발협력체계를 설계하는 것은 매우 비합리적일 것이다. 한국의 개발협력의 목적과 전략에 대한 분명한 의식과 합의가 있어야 한다. 한국의 짧은 개발협력 역사로 인해 이러한 문제의식의 부재가 개발협력 집행에 있어서 수많은 비효율과 낭비를 초래하고 있다. 한국 개발협력체제에 개발금융을 도입하는 문제에 관한 많은 논의가 생산적인 방향으로 진행되지 못하고 있는 큰 이유도 이와 관련되어있다. 개발금융
# 3939 != CIRA
# 9.7% != 9. 7 %
# 경찰국가 지배체제 != 독일 검찰제도는 근대 자유주의적 법치국가 이념의 투쟁과 규문주의 재판제도 및 강력한 경찰국가에 대한 반동에서 잉태되었다. 그 연원은 18세기 중엽 프로이센까지 거슬러 올라간다. 당시 프로이센은 절대왕정 하에서 강력한 경찰국가 지배체제
# 정부 및 운항현장 != 안전관리 활성화
# 변리사 != 변리사가 자신의 비전문분야 수임 후 명세사 등 비변리사에 업무처리를 위탁하는 관행 ’ 의 상존으로 변리서비스에 대한 신뢰를 떨어뜨리고 있다. 변리서비스 소비자들은 이에 지속적으로 문제를 제기해와 변리사의 윤리의식 강화
# 주택 구입 !=
# 2년 미만 != 2년 미만이므로 자격 업무에 대한 전문성과 지속성을 확보하는 데 어려움이 있는 것으로 나타났다. 특히, 소관부처 담당자는 전체 업무에서 자격 업무가 차지하는 비율이 30 % 미만으로 자격 관련 업무에 집중할 수 있는 여건이 마련되지 못한 것으로 나타났다. 둘째, 소관부처와 검정기관 담당자의 95 % 이상은 자격정책
# 영국 != 해양에너지는 글로벌 시장에서 조력발전과 해수열 외에는 아직 상용화 단계에 진입하지 못하였으나, 유럽과 미국을 중심으로 개발 및 실증시험이 활발하게 진행 중이다. 영국
# 2014년 12월 != 환경영향평가 협의의견
# 공적가치 !=
# 반드시 서면 != 서면
# 자아존중감, 우울 != 가정과 일 양립의 어려움
# 텔레매틱스 != 커넥티드 자율주행차량 ( Connected automated vehicle ) 의 실용화
# 관할 교육청 != 학교운영위원회
# 장쑤성 != 15분 건강권
# 국무원 판공청 != 공립병원 개혁
# 납세자 != 미국형
# 2012년 12월 28일 != 공중밀집장소추행죄
# 환경적 요소들 !=
# 수익성 != 적절한 임금이 노동자들의 일에 대한 만족과 ( Dyer and Theriault, 1976 ; Konovsky, Folger, and Cropanzano, 1987 ; Berkowitz and Fraser, 1987 ) 일의 성과에 긍정적인 영향을 준다는 것을 거듭 보여주었다 ( Lawler, 1971 ; Milkovich, Newman, and Gerhart, 2013 ; Tremblay, St - Onge, and Toulouse, 1997 ). 그렇기 때문에, 뛰어난 인적자원의 역할이 점점 더 커지는 현대 지식경제 속에서 많은 기업들은 우수한 인재를 고용하기 위해서 높은 임금을 지불하는 것을 가치 있는 투자라고 생각한다. 그러나, 문제는 인재를 얻기 위해 무조건 후한 임금을 지불할 수는 없다는 것이다. 대부분의 기업들에 임금관리의 관건은 우수한 인재를 유치하는 비용과 회사의 수익성
# 심리적 계약 != 심리적 계약 ( psychological contract ) 의 유형틀
# 외국인 학생과 교수진의 비율 !=
# 계층 간·지역 간·산업 간 != 공통과제에 직면해 있음을 확인하였다. 양국은 세계적인 저성장시대에 나타나고 있는 계층 간 · 지역 간 · 산업 간 격차의 확대로 어려움을 겪고 있다. 또한 저출산과 겹쳐 고령화가 급진전됨에 따라 사회복지의 부담이 늘어나고 생산인구가 감소하여 경기부양의 효과도 잘 나타나지 않는 구조적 어려움에 직면하고 있다. 사회적으로 핵가족화가 진행되고 교육에 대한 과잉투자가 나타나고 있는 것도 양국이 공통적으로 직면한 현실이다. 아울러 양국은 미국과의 동맹을 지켜가면서 중국과도 우호적인 관계를 유지해야 하는 외교적 도전도 함께 하고 있다. 나아가 개방적인 국제질서를 지키는 일원으로서 글로벌한 역할을 함께 수행할 수 있는 기반도 갖추고 있다. 또한 두 나라는 에너지를 해외에 의존하는 나라로서 환경 보전 및 에너지 확보
# 미국 !=
# 어뢰음향대항체계 !=
# 미국 != 운전 및 운송 관련직
# 2,200만 명 != 타임워너케이블
# 콘텐츠 중심 기업 !=
# 유럽 인구이동 != 유럽연합
# 혁신 != 고객 지향은 혁신
# 중재자 != 안중근의 중재 역할
# 공동의 역사 교과서 !=
# 갈등 !=
# ISO !=
# 오클라호마주와 사우스캐롤라이나주 != 인디아나주
# 2013년 !=
# CAD 프로그램 != 3D 프린팅
# 온라인 != 특허법상 실시
# 저작권법 != 컴퓨터프로그램저작물
# 종합물류 != 종합물류 비용
# SERV*OR != SERV * OR
# 경제성장 !=
# 문화교육과 언어교육 != 한국문화교육과 한국어교육
# 모든 학생 != 다문화교육 중점학교
# 에너지관리서비스 != 에너지관리서비스 산업
# 북미 셰일혁명의 여파로 인한 글로벌 LNG 거래 != 脫 러시아 化
# Family 500+ != Family 500 + ’ 아동수당
# 0.312점 !=
# 보호처분의 변경･취소 != 가정폭력범죄
# 가치증가익 != Capital Gains
# 납세의무자 != 납세의무자와 일방국가의 과세당국간에 이루어진다. 납세의무자의 거주지국인 타방국가는 APA에 참여하지 않는다. 이 방법은 조세조약의 적용에 따른 혜택이 없거나 체결된 조세조약이 없는 국가에 소재하는 특수관계자와 거래한 경우에 적용할 수 있는 방법이다. 과세당국간의 쌍방 APA에 대한 협의가 이루어지지 않는 경우에도 적용할 수 있다. 둘째, 쌍방 ( bilateral ) APA이다. 국제거래의 당사자가 속하는 관련국가인 거주지국과 원천지국의 과세당국이 개입하여 납세의무자가 신청한 APA를 합의하는 제도이다. 국제거래소득에 가장 일반적으로 적용되는 APA 방식이다. [SEP] 일방 APA
# 취업모 !=
# 기초재정수지 != 순융자 / 순차입 ’ 지표를 규정하고 있다. 이는 발생주의 기준을 충실히 적용하고자 하는 이유도 있지만 국가 간 비교가능성을 높이기 위한 IMF의 의도와도 연관된다. 또한 이 기준은 GFS, 마스트리히트조약 및 ESA 2010 / OECD 등 국제적 기준에 부합된다. 본 연구의 핵심은 이른바 Dual system적 접근으로 GFS 2014에 규정된 발생주의기준과 현금주의 기준을 공통적으로 활용하자는 것이다. 다시 말해 재정운영의 지속 가능성 관점에서 ‘ 순융자 / 순차입 ’ 을 활용하고, 유동성 관리 관점에서 ‘ 현금흑자 / 적자 ’ 를 활용하자는 것이다. 한편, 총 ( 순 ) 채무의 지속가능성 분석을 위해 기초재정수지
# 벅스팜 != 장수풍뎅이의 해피하우스
# 1차 산업 사고 !=
# 탄화수소 != Upstream 공정은 석유화학업종의 원료를 생산하는 분류 및 정제공정으로 석유화학산업에서 upstream 공정은 일반적으로 NCC, BTX, BD 공정을 지칭한다. 석유화학산업의 대표적 공정인 NCC공정
# 비전 2030 != 보건산업 R & D는 점차적으로 삶의 질의 중시와 더불어 보건의료 개념의 확대로 인해 차츰 사회문제 해결로 확대하는 경향에 있다. 2006년 「 비전 2030
# 고령전기·중기 != 고령후기 노인
# 사지 != 사역의 범위
# 대구 월성동 777-2번지 유적 !=
# 세종실록 != 정양산성
# Billett != 일터교육학
# 유전체 연구 != 조기진단 유전자 마커
# 폐경기 혈관운동증상 != 유치원장은 여성으로서 오랜 시간 일할 수 있는 직업군 중 하나로 갱년기나 폐경과 같은 나이듦에 따라 나타나는 증상들을 일하면서 경험할 수 있는 직업이기에 연구의 필요성이 크다 하겠다. 또한 유치원장의 다수가 갱년기를 경험하는 연령대이기에 유치원장의 갱년기 증상에 대한 연구는 유치원장의 건강 관련에서 매우 중요한다. 중년 여성의 다수가 경험하는 갱년기는 열감, 땀, 질 건조, 성욕감퇴, 불면증, 두통, 가슴 두근거림, 주의집중 결핍, 피로, 체중증가, 관절통, 기억력 감퇴 등의 증상을 동반할 뿐만 아니라 우울, 불안, 예민 등의 증상도 동반한다. 특히 열감이나 식은땀과 같은 폐경기 혈관운동증상
# 승˙하차 이용자 수 != 서울 도시철도 역세권
# 압구정역 != 대림역
# 국산화 실행 != 무기체계 SW 국산화 관리체계
# 전략수립 != 기회요인
# 300만원 != 300만원 이하의 과태료
# 항공법 != 초경량비행장치사고
# 2018년 11월 13일 != 2019년 1월 11일
# 1992년 !=
# 경영조직 != 정부의 역할 또한 고려하여야 한다. 경영조직
# 사교육 경감 != 기혼 여성들은 저출산 정책당국자들에게는 매우 중요한 집단이다. 분석에 따르면 대학등록금으로 대표되는 교육 부담은 그 다음 자녀 출산 여부에 별다른 영향을 미치지 않지만 더 나중이고 그렇지만 더 큰 부담이 될 수 있는 결혼식 지원에 대한 태도는 큰 영향을 주고 있다. 현재 우리나라는 양육의 경제적 부담과 관련해서는 정책적 관심이 사교육 경감에 쏠리고 있는 실정이다. 그렇지만 어쩌면 더욱 신경써야 할 사항은 성인이 된 자녀에게 들어가는 결혼 지원이라든지 생활비 지원일지 모른다. 이와 관련해서는 이미 사회적으로 많이 환영받고 있는 소위 ‘ 작은 결혼식 ’ 운동에 적극적으로 동참할 것을 촉구하여 결혼식 문화 자체를 바꾸려 노력할 필요가 있다. 이제는 결혼식 행사에 대해 사회적으로 다시금 생각해볼 때가 되었다. 결혼식
# 역할 증대 관점 !=
# 자녀 != 출산
# 1990년대 중반 이후 != 2000년
# 커버드본드 != 투자자의 신뢰 문제
# 독일의 연방통계청 != 연방통계청
# 적극적 권리와 소극적 권리 != 교육권
# 예산 확보 != 성 평등 조치사항
# 여성 단체 !=
# 성별영향분석평가 != 성별영향분석평가 제도
# 중소기업청 != 시장스타일
# 패스스루 MBS의 시장성 != 패스스루 MBS
# 옥시토신 != 주사제
# 보충설명 !=
# 2004년 != 비정규직근로자비율은 임금근로자의 고용안정성 정도와 근로조건 수준을 가늠할 수 있게 해 주는 지표이기도 하다. 비정규직근로자의 규모를 엄밀한 정의에 따라 측정하고 해당 통계가 안정적으로 집계되기 시작한 것은 2003년부터이며, 비정규직근로자의 비율은 2004년
# 김종서 != 김종서는 그 업적뿐만 아니라 놀라운 충의로도 유명하다. 세종 때 승승장구한 이후 3대에 걸친 왕에게 최고의 충성을 보여준 ‘ 충신의 상징 ’. 김종서는 역설적이게도 왕을 꿈꾸던 자에 의해 비극적인 최후를 맞는다. 그의 죽음은 지금까지도 매우 충격적이고 안타까운 역사로 기억된다. 시신조차 제대로 수습하지 못하고 만든 그의 묘에는 ‘ 한 다리 전설 ’ 이 전해 내려온다. 김종서가 어린 단종을 지키려다 수양대군
# 중앙녹지공간 !=
# OECD 국가들 != OECD 국가들을 중심으로 20여년 전부터 시행되고 있다. 금융위기 이전에는 주로 기존 재정사업에 대한 일회적 재점검 및 세출구조조정의 성격이 강하였다. 예컨대, 네덜란드의 지출검토 제도는 1980년대 초에Reconsideration Procedure
# 세종시 !=
# 직업공무원제 != 직업공무원제는 법치행정의 필수조건이며, 부패를 효과적으로 예방하는데 기여할 수 있고, 효율적인 정부운영에 기여하며, 정부의 인적자원관리 및 개발에 매우 중요한 의의를 지닌다. 우리나라의 경우, 공무원의 97 % 이상이 국가공무원법의 직업공무원제 규정을 적용받는다는 점에서 직업공무원제가 상당히 정착되었다고 볼 수 있다. 그러나 직업공무원제
# 80% != 계산하지 않았다. 이미 많은 사람들이 계산을 하였고 상황과 개념정의에 따라 다르게 산출되기 때문이다. 경제적으로 볼 때 독일의 통합은 동서독 간의 소득격차를 줄이기 위해 지원금을 주는 형태로 가능했다. 독일 통일비용의 80 % 이상이 동독 지원금으로 사용되었고, 나머지 20 % 정도가 인프라구축에 사용되었다. 남북한의 정치, 경제적 상황을 보면 독일과 같은 상황은 불가능하다. 남북한의 인구격차는 2대1
# 필수성능 !=
# EMC 내성시험 !=
# 체념적 침묵과 방어적 침묵 != 상호작용공정성
# 역할행위 != 조직시민행동
# 부산의 감천문화마을 != 감천문화마을
# 공정관광 != 감성적 가치
# 2003년 !=
# 미시경제 수준 != 거시경제 변수
# 소득 또는 학력 수준 != 상품시장규제 정책의 효과는 상품시장규제가 강화될 경우 개인의 시간당 소득 변동성은 증가하는 것으로 나타나 정부규제와 무역, 투자 등에 대한 장벽이 높아지면 기업운영이나 창업 환경이 나빠지고 그로 인해 근로자의 고용 및 소득 안정성에 부정적 영향을 미치는 것으로 확인되었으며, 소득 또는 학력 수준이 높을수록 시간당 소득 및 근로시간 변동성은 증가하는 모습을 보였다. 또한 정규고용보호정책의 효과는 고용보호가 강화될수록 개인의 시간당 소득 및 근로시간 변동성이 감소하는 형태로 나타났으며, 대체로 소득수준
# 다문화교육지원계획 != 2019년 다문화교육지원계획
# 여성가족부 != 법무부가 중심이 되고, 다문화가족정책위원회는 여성가족부
# 미국 != 무모성
# 다양한 인적특성 != 인적특성
# 1961 != 1961년 지식재산권법 이래 무려 30여 차례의 크고 작은 법 개정을 통하여 글로벌 스탠다드에 부합하는 현행 법 체제를 갖추게 되었다. 중국의 경우도 한국의 사례와 같이 특허제도가 국제적 수준에 부합하기 위해서 1985년
# 200L드럼당 1,310만원 !=
# 저출산 대책 != 아빠의 달
# 시간선택제 일자리, 유연근무제도, 스마트워크 != 성별 형평성
# 취업경력단절 != 현실적 문제를 언급하고 있다. 육아휴직이 전형적인 여성적 제도로서 작동하는 결과가 취업경력단절이다. 취업활동 과정에서 발생하는 경력단절
# 외교통일위원회 !=
# 공익위원안 != 공무원직장협의회의 설립 ․ 운영에 관한 법률 을 개정할 것 ” 을 제안하고 있다. 이는 공익위원안에 따라 공무원노조의 가입대상에서 제외되는 공무원에게는 공무원직장협의회법
# 클라우제비츠 !=
# 심사전치제도 != 2013년
# 발생량 != 중고온성 표고품종
# 통신판매중개업자 != 통신판매중개의뢰자의 신원정보를 확보하고 제공할 의무를 부과함으로써 의무부담자를 명확히 하였다. 둘째, 확보해야 할 신원정보의 대상을 사업자와 비사업자로 구분하지 않고 동일하게 취급하였다. 셋째, 신원정보 미확보, 미제공으로 인한 책임과 잘못된 신원정보제공으로 인한 책임의 경우 면책을 동일하게 인정할 수 있는 것은 아니므로 이를 구분하였다. 잘못된 신원정보의 경우 기본적으로 이를 제공해야 하는 것은 통신판매중개의뢰자
# 민간 != 민간 참여
# 1983년 != 정보적 자기결정권
# 미지급 보상금에 대한 지급 청구일 != 형사보상금의 지연이자
# 1980년 != 新 [UNK] 産 業 技 術 總 合 開 發 機 構 ( NEDO : New Energy Development Organization ) 를 설립하고 관련법을 발표하면서 본격적으로 재생에너지 보급정책을 추진하기 시작하였다. 특히 2011년 후쿠시마 원전사고
# 유류오염비용 추정 != 유류오염비용
# 사망사고 != 인피불기소
# 교통안전 부문 !=
# 저어새 != 강화갯벌이
# 근본적인 기본권 침해 요소 != 법관에 의한 통제 강화
# HRD-Index !=
# KIPnet 컨퍼런스 2014 != KIPnet 컨퍼런스
# 중국 != 제13차 5개년 계획 ” 및 “ 중국 제조 2025 전략 ” 등에 따라 이러한 구조고도화는 더 빨라지게 되어 우리 주력산업을 위협하고 있다. 이미 세계 수출시장 점유율과 같은 양적인 측면에서는 중국이 모든 산업에서 우리를 크게 넘어섰을 뿐만 아니라 동일 산업 내 품질, 기술, 신산업 대응 등과 같은 질적인 측면에서도 우리에 근접하거나 우리를 넘어선 부분도 있다. 우리 산업이 중국과 경쟁하고 중국시장에서 진출을 확대하기 위해서는 과거와는 다른 전략이 필요할 것이다. 생산기지로서의 역할보다 시장 공략을 위한 중국 내 R & D 기능 등이 강조되는 새로운 가치사슬 분업전략
# 텃제 != 개기제
# 대곡 문화 != 곡비가 전통사회의 애환으로 각인된 것은 최근의 일이다. 『 국어사전 』 에는 ‘ 양반의 장례 때 주인을 대신하여 곡하던 계집종 ’ 이라고 풀고 사례로 『 혼불 』 ( 1981 ~ 1996 ) 이라는 소설에서 ‘ 곡비의 울음소리 온 밤 내내 구슬픈 물굽이를 … ’ 이라는 대목을 들고 있다. 또한 2014년 3월 방영된 ( KBS2 ) ‘ 곡비 ’ 와 2015년 4월 ‘ 총체적 난극 - 곡비 ’ 라는 연극이 그 주인공이다. 그러나 이들은 하나같이 ‘ 곡비 = 천민 ’ 이라 는 등식으로만 바라보고 있어 곡비와 대곡문화의 실체와 그 본래 의미를 읽어내지 못했다. 실제 곡비는 극히 드문 일이었고, 소설 외에 어떤 형태로 존재했는지 알 수 없기에 일반화할 수는 없다. 우리에게 곡비라는 슬픈 역사로 알려져 버린 ‘ 대곡 ’ 은 슬픔에 빠진 상주를 보호하고, 고인에 대한 여운을 풀어주며, 자식 된 도리를 일깨우는 배려의 풍습이었다. 그래서인지 대곡 문화
# 심리학자 프랭크 미너스Frank minirth 박사 !=
# 정보기관과 수사기관 != 테러범죄 예방을 실패했다는 개념이다. 이러한 반성적 고려를 통해 미국은 ‘ 정보개혁 및 테러방지법 ’ 과 ‘ 애국법 ’ 등을 제정함으로써 정보기관과 수사기관의 정보공유를 제도적으로 보장하며, 최근에는 사이버안보 정보공유법
# 1999년 != 2008년
# 1 ~ 2개월 != 성과평가 일정은 2018. 12. 11. 성과평가계획 ( 안 ) 의견수렴, 2018. 12. 20. 성과평가계획 수립, 2019. 1. 성과평가 실시로 추진되어 불과 1 ~ 2개월
# 증권형 크라우드펀딩 != 크라우드펀딩
# 지능적 != Google Brain
# 48억 7,000만 != 48억 7, 000만 통이
# 뉴질랜드 != 고등학교 졸업학력 상호인증 제도
# 해양수산부 != 해양수산부 양식산업과
# 사회통합과 공정성 != 노르딕 국가중심의 사회적 시장 모델
# 안전공제회 != 학교를 옮기는 것은 피해회복이나 선도에 있어 도움이 되는 방향은 아닌 것은 분명하다. 학교폭력 사안처리과정뿐만 아니라 사안처리가 완료되고 난 이후 피해학생과 가해학생이 직면한 문제를 파악하고 이를 해결할 수 있도록 통합적인 지원이 필요하다. 안전공제회를 통한 치료비 보상은 사후적인 처리에 한정되어 있기 때문에 피해학생에게 신체적이고 정신적인 치료가 필요한데도 가해학생측이 손해배상 능력이 없는 경우 피해학생의 치유를 위한 경제적, 의료적 지원이 별도로 필요한 경우가 있다. 또한 학교폭력사안처리과정 에서 피해학생과 학부모 간의 갈등이 심화되는 사례들도 발견된다. 가해학생의 학교폭력행위의 원인이 가정 내의 문제로 인한 영향인 경우 가해학생의 폭력행위
# 청중 !=
# 학습 분포도 != 분포도 ( map ) ’ 가 요구된다. 이러한 학습 분포도의 특징 중 하나는 학습과 발전 또는 성장의 의미가 무엇인지에 대한 설명을 포함한다는 것이다. 학습 분포도
# 학습영역 분포도 != 읽기능력
# 자녀양육 !=
# 경제적이고 효율적인 복합운송방식 != 마지막 1km
# 새로운 경제발전 시스템 != 경제발전 시스템
# 상하이 자무구 != 대외개방 확대
# 가출청소년들의 가정복귀 != 가정복귀
# 정당 지배적 대의 민주주의 != 정당
# 표류부이 != 해양기상부이는 기상청, 국립해양조사원, 한국해양과학기술원, 서울대학교 등에서 서해, 동해, 남해 등의 먼 바다 수역에 31대를 띄워 놓고 있다. 표류부이는 소모성 장비로서 기상청에서 우리나라 주변 해역에 2013년부터 2015년까지 총 24대를 투하하였고, 매년 20여대를 추가로 투하하여 관측하고 있다. 기상관측선박은 바다에 떠있는 기상대라 할 만큼 육상의 관측소와 같은 기상관측시설을 갖출 수 있고, 원해의 해양기상자료를 얻을 수 있는 좋은 수단이 된다. 현재 기상청은 기상관측선박 기상1호
# 낙인 효과 != 다문화가족정책
# 중앙정부 != 동반자적 모델
# 유럽 != 중앙정부
# 쇼루밍(showrooming)족 != 쇼루밍 ( showrooming ) 족
# 휴대폰 사용요금의 현실화 != 스마트폰
# 2000년 != 2000년대 중반 이후
# 노동시장 제도의 포섭성 != 저임금은 성별, 연령, 학력, 경력 등의 노동공급 측 요인, 업종, 규모, 지배구조, 사용자 전략 등의 노동수요 측 요인, 그리고 최저임금제도, 고용보호제도, 노조조직률 등의 제도적 요인이 상호작용한 결과라는 것이다. Bosch et al. ( 2010 ) 은 저임금을 결정하는 가장 중요한 요인으로 노동시장 제도의 포섭성 ( inclusiveness ) 을 지목한다. 포섭성
# 가격구조 != 관련시장 ( relevant market ) 분석에 대해 검토하였다. 패널은 비교기준에 대한 분석을 완료하고 나서 관련시장을 정의하였으며, 제소국측 주장을 받아들여 관련시장은 모든 에너지원 발전이 망라된 단일 전력도매시장
# 고용보험 데이터 != 행정통계이므로, KED 데이터와 비교하여 신뢰성이 높다고 판단하여, 산업분류코드 및 지역과 규모코드는 모두 고용보험의 자료를 사용하였다. 한편 스마트공장 구축 지원 사업 참여 기업들의 산업코드는 추진단에서 제공한 자료를 사용하였고, 그 외 기업들의 산업분류 코드는 모두 고용보험 사업장 데이터에서 추출하였다. 한편 사업 참여 기업 및 비참여 기업들의 연도별 고용량과 이를 바탕으로 계산한 고용증가율 역시 고용보험 데이터에서 가져왔다. 한편 스마트공장 구축 지원 사업이 2014년에 처음 시행되었으므로 기업들의 이전 추세 통제 등을 위하여 모든 자료는 2008년과 그 이후부터를 사용하였다. KED 데이터
# 선호-비선호시설 유치 != 선호 - 비선호시설 유치
# 7억 유로 != 약 7억 유로
# 대학생 시기 !=
# 1982년 != 1961년
# 출산 != 결혼과 출산
# ‘서커스 예술’ 거점 지역으로 이와 관련한 지역의 공연시설 != 생마클루 납골당
# 여성 != 여성의 교육수준
# 순자산분위 != 순자산분위가 올라갈수록 출생아수가 많아지는 경향이 있다. 25 ~ 29세, 30 ~ 34세 집단에서는 1분위에서 평균 출생아수가 가장 많았으며 5분위에서 평균 출생아수가 가장 적었다. 그러나, 출산이 완료된 집단에서는 이러한 경향이 반대로 바뀌었는데, 35 ~ 39세, 40 ~ 44세 집단에서는 4 ․ 5분위 가구에서 평균 출생아수가 가장 많았으며, 2분위에서 평균 출생아수가 가장 적었다. 그러나 자산에 따른 차별 출산력
# 인센티브 경매 != 간섭 문제
# 최하위 != 최하위권
# 미국 != 연방재난관리청 ( FEMA
# 국가 R&D사업 != 국가 R & D사업
# 특허청 !=
# IT 기술 != 주민신고제도
# 대상지역 주민 != NKDE
# 의무지정 대상지 != 의무지정 대상지가
# 제84조 != 선원법은 선내 보건과 안전 등에 관해 위와 같이 자세한 규정을 두고 있으나, 선원에 대한 의료지원 및 보건에 관한 권리보장에 관한 실태를 살펴보면 선원이 타 직역에 종사하는 국민에 비해 다음과 같은 점에서 상대적으로 열악한 의료지원 및 보건권 보장을 받고 있다는 사실을 알 수 있다. 첫째, 선원법 제84조는 일정한 선박에 의사를 승무시키도록 규정하고 있으나, 동 조항에 따라 의사승무가 강제되는 선박은 원칙적으로 3일 이상의 국제항해선박
# 외부 연구개발 동기를 고려하여 외부 연구개발 목표와 요구사항 != 제안요청서
# 일본 != 독도를 한국
# 특허법 != 변리사 ” 비용의 심판비용 산입에 대하여 그 기준을 특허청 고시
# 프로파일링 제도 != 프로파일링
# 전통공연예술 != 전통공연예술의 분류
# 공동기술 이니셔티브 != 공동 기술 이니셔티브 ( JTIs ) 를 들 수 있겠다. 이것은 유럽연합 기능에 관한 조약 ( Treaty on the functioning of the European Union ) 187항을 기반으로 심의회에서 채택한 제 7차 Framework Program ( FP ) 의 새로운 재정 도구이다 ( 구 유럽이사회 조약 171항 ). 공동기술 이니셔티브
# 7천억 원 != 7천억 원의
# 만 24개월 != 만 24개월이상
# 미국 != 부모
# 신윤정·김지연 != 전국보육실태조사
# 가구주 != 소비함수의 역설
# 7년 != 국가기밀을 탐지 수집 누설 전달하거나 중개한 때에는 다음의 구별에 따라 처벌한다. 가. 군사상 기밀 또는 국가기밀이 국가안전에 대한 중대한 불이익을 회피하기 위하여 한정된 사람에게만 지득이 허용되고 적국 또는 반국가단체에 비밀로 하여야 할 사실, 물건 또는 지식인 경우에는 사형 또는 무기징역에 처한다. 나. 가목외의 군사상 기밀 또는 국가기밀의 경우에는 사형 무기 또는 7년 이상의
# 고철질 규산염 암석 덩어리 != 고철질 규산염 암석 덩어리로 구성되어 있다. 외핵은 액상, 내핵은 고체로 이루어져 있다. 지구는 하나의 커다란 자석이다. 자기의 세기는 지역에 따라 차이가 있지만, 우리 나라는 약 0. 5 G ( 가우스 ) 이다. 이 자기장 역할은 태양에서 나오는 강력한 태양풍과 고에너지 입자들이 지구에 직접적으로 도달하지 못하게 하여, 지구상의 생명체들을 보호하는 역할을 한다. 즉, 지구 자기장
# 합리적인 정책성 != 일자리창출정책
# 동태적 확인 != 역사요인
# 스웨덴 !=
# 대선 결과 != 사탄의 세력과 동일시되어왔다. 악의 축이
# 이스라엘과 사우디아라비아 != 이란
# 프로그램모니터링 != 성과모니터링
# 15 != 질적인 측면
# 1% != 청소년정책의 예산
# 국가도로망의 종합정보 !=
# 1970 != 1970년
# 효율성 평가 지표 != 효율성 평가 지표의 선별 과정
# 일본 != 복수의 역사들 ( histories ) ’ 이 만주에서는 이미 이루어지고 있었던 것은 아닌가? 물론 만주국은 유토피아적 다민족 국가가 아니라 윤휘탁의 지적처럼 그 자체 내에 위계질서와 권력 간의 작동에 의해 갈등이 내재한 ‘ 상상에 의한 복합적 민족국가 ’ 였을 지라도 그 이상은 미래의 세계가 지향해야 할 교훈이 내재해 있음을 자각할 필요도 있다. 일본
# 한국 != 일본
# 제2외국어 교육 경비 항목 != 고등학교 제2외국어 교육 경비
# 자존감 != 스케이트
# 보안정책 != 국방정책 가이드라인
# 신임장 !=
# 작곡가 != 나화랑
# 2010년 != 2010년 이후
# 여성연맹 != 국제결혼
# 2010년 12월 != 투싼??? ix35
# 2014년 12월 !=
# 양극화 !=
# 독일 != 4차 산업혁명
# 52.3% != 취업
# 10% != 노령소득보장체계
# 교과서 !=
# SDGs != 보편성
# 41,174ha != 사방공사의 실시과정 중 얻은 경험과 기술축적을 토대로 1973년 기조사 보고된 황폐지면적 120, 078ha 중 84, 220ha와 야계 500km에 대하여 현실적인 사업설계와 효율적인 복구를 목표로 추진되었다. 본 사업은 전국 황폐지를 나지녹화 일반사방 및 특수사방으로 구분하여 황폐임지에 대한 총열대장 ( 總 [UNK] 台 帳 ) 과 총열도면을 작성함으로써 요사방지를 총열화하였다. 동시에 전국 황폐지를 24개 단지로 구분하고 주요 단지를 중심으로 지구별 완결원칙에 입각 집약적으로 복구하는 한편 전국적으로 사방공법, 공종, 설계시공 및 양식 등에 통일을 기하여 적지적공법을 토대로 하는 사방기술을 정비하여 사업을 수행하였다. 본 사업은 1973년부터 10년간 산지사방 83, 268ha, 해안사방 592ha, 야계사방 500km를 실행키로 계획하였으나 6년 ( 1973～1978 ) 동안 산지사방 41, 174ha
# 7, 8, 9월 !=
# 수서곤충류 != 파리목 6종 ( 10. 2 % ), 하루살이목 4종 ( 6. 8 % ), 잠자리목과 노린재목이 각각 3종 ( 5. 1 % ), 딱정벌레목과 날도래목이 각각 2종 ( 3. 4 % ) 이 출현하였다. [SEP] 낙동강 8개 조사지점에서 절지동물군
# 신자도 != 대마등
# 94m != 약 94m
# 청소년회복센터나 6호 시설만의 자립지원관 != 자립지원관
# 전문가 및 숙련자 != 생물 위해성 평가
# 의약품 제조 및 품질관리기준 != 생물안전
# 구동독 != 아동중심 Program
# 2월 21일 !=
# 기본권 침해 !=
# 6~70% != 65. 9 %
# 36.8% != 무직
# 아동․청소년 != 시설 아동 ․ 청소년의 긍정적인 측면에 대해 보고한 연구들도 있다. 이들은 시설에서 집단생활을 하면서 공동체 의식
# 매개효과 != SPSS WIN 23. 0을 이용하였으며 구체적인 분석방법은 다음과 같다. 첫째, 연구 대상자의 일반적 특성은 빈도와 백분율을 이용하여 분석하였고, 내부마케팅, 직무스트레스, 조직커뮤니케이션 만족 및 고객지향성은 평균과 표준편차로 구하였다. 둘째, 연구 대상자의 일반적 특성에 따른 내부마케팅, 직무스트레스, 조직커뮤니케이션 만족 및 고객지향성의 차이는 t - test와 ANOVA를 이용하여 분석하였고, 사후 검정은 Scheffé test
# 학교장 != 학교자치임을 밝히고 있으나, 교육자치정책협의회 산하 교육부 - 시도교육청 공동 특별위원회가 제시한 법률안에서는 ‘ 학교자치 ’ 라는 구절이 사라지거나, 학교의 자율성, 학교 민주주의라는 용어로 대체되어 있다. 학교의 자율성은 현재의 법령 체제에서는 학교장이 책임지는 자율성이어서, 학교장의 권한만을 강화시킬 우려가 있다. 학교민주주의
# 항공권 != 항공권의 가격
# 43,577,471명 != 1개월
# 증량 != 새끼돼지
# 북한 이탈주민 != 북한경제 연구
# 120cm != 120cm 이상
# 미군철수/국가보안법 폐지 != 미군철수 / 국가보안법 폐지
# 출산장려금 정책 != 충청지역
# 논산시 != 논산시가 2002년
# 영업비밀이기 때문 != 간이평가 모델
# 국가R&D사업 표준성과지표 != 국가R & D사업 표준성과지표
# R&D정액기술료 != 정액기술료 제도
# 72% != 청소년 특별지원
# 3개소 != 화상전문치료병원을 들 수 있다. 2014년 현재 화상전문응급의료센터로 한강성심병원이 유일하게 지정되어 중증화상환자에 대한 급성기치료를 담당하고 있다. 보건복지부가 지정한 화상전문병원은 2014년 현재 전국에 3개소
# 63.1% != 건강검진
# 훈련기관 != 내일배움카드제에 대한 이해를 높이고, 본인에게 적절한 훈련직종을 선택하도록 돕고, 해당 피상담자가 국가의 지원을 받아 훈련을 받는다면 성공적으로 노동시장에 진입할 수 있는가를 판단하여 지원여부를 결정하는데 있다고 볼 수 있다. 하지만 본 연구에서 드러난 바로는 대부분의 피상담자는 훈련기관과의 상담을 통해 내일배움카드제
# 지니계수 != 소득불평등에 미치는 영향에 대해서도 분석해 보았다. 구체적으로 경상소득이나 처분가능소득을 이용하여 추정한 지니계수와 잔여소득을 이용하여 추정한 지니계수를 비교하여 에너지 소비지출이 소득불평등에 미친 영향을 추정해 보았다. 본 연구의 지니계수 추정결과는 잔여소득을 이용하여 추정한 지니계수가 에너지 소비지출을 차감하지 않은 소득을 이용하여 구한 지니계수보다 큰 것으로 나타났다. 연간 월평균 자료를 이용하여 추정한 결과는 잔여소득을 사용하였을 때 지니계수가 0. 007에서 0. 010 더 크게 추정되었고 1분기 월평균 자료를 사용하였을 때에는 0. 013에서 0. 017 더 크게 추정되었다. 지니계수는 0에서 1사이의 값을 갖고 1에 가까울수록 불평등이 크므로 본 연구의 분석결과는 에너지 소비지출이 불평등
# 에너지복지 != 에너지 지원정책
# 1991년 9월 17일 !=
# 인상될 최저임금 != 최저임금의 고용효과를 추정하였다. 이병희 ( 2008 ) 과 같이 Stewart ( 2004a ) 의 방법을 이용하였는데, 관심집단
# 지역별 추세변수 != 지역별 추세변수 추가 여부에 대한 논쟁이 진행 중이다. 지역별 추세변수 추가 여부에 따라 고려하는 비교집단
# 직무 단위 !=
# 중소기업 연구소 != 기업연구소에 대해 최초로 시도하는 본 조사연구에 있어서는 가급적 우수하여 정형성이 높은 소수의 연구소들을 대상으로 하는 것이 연구 위험을 줄이는 적절한 전략이다. 이렇게 우수한 중소 / 중견기업 연구소
# 1996년 != 기술 기반 창업으로 진화하게 된다. 이를 통해서 한국의 중소기업 정채도 미국의 1970년대의 새로운 혁신 주체로서의 중소기업 정책의 포지션을 갖게 된다고 할 수 있다. 보호의 관점이 아니라 혁신주체인 중소기업에 주목하고 이들 중소기업이 성장을 통해 경제의 기관차 역할을 할 것에 주목하는 것이다. 1996년 코스닥 시장은 1987년
# 44% != 3 % 미만
# 교통부 !=
# 1.1% != 여유자금
# 국가교통DB != 대도시권 목적별 여객통행 OD자료
# 고효율 제품 != Pacific Power
# 제81조 != 변상금
# 14.2% != 고령사회
# 1989년 !=
# 기술개발정책 != 무역협정의 결과를 기술개발정책
# 지자체 != 유명무실법 ( 有 名 無 實 法 ) ’, 즉 법률이 상징적 효과만 가질 뿐, 실질적 효력은 가지지 못하는 법이 상당히 많다는 사실이다. 특히 ‘ 진흥법 ’ 이라는 이름의 법 가운데 국가는 재정을 투입하는 등의 실질적 조치는 하지 않은 채 학교에 보고 부담만 지우는 경우가 적지 않다. 예를 들어, 현행 「 과학 수학 정보교육 진흥법 」 은 국가가 당해 교육 진흥에 관한 시책을 부진하게 추진하거나 예산 조치가 부족하다고 인정하는 지자체에 대하여 예산 증액 등 필요한 조치를 권고하도록 규정하고 있다. 국가가 직접 재정을 투입하지 않고 지자체
# 후회 최소화 != 사교육 지출
# 문화매개자 !=
# 문화매개 != 문화매개자
# 성인 !=
# 딥러닝 != 빅데이터 분석
# 삼차예방 != 범죄예방
# 53세 != 약 53세
# 뮌헨 != 유럽특허협약 ( European Patent Convention, EPC ) 에 의거 설립된 것으로 회원국 등이 EPO에 특허신청을 하면 회원국이 각 특허청에 개별적으로 신청하지 않더라도 단일신청으로 유럽 각 지정국법에 다른 승인에 의해 특허등록을 받을 수 있음. 2000년 12월 현재 총 20개국의 회원국을 두고 있으며 알바니아, 리투아니아, ( 전 ) 유고공화국, 루마니아, 슬로베니아 등 일부 동구유럽국가도 회원국 가입을 준비 중에 있음. 조직구조를 보면 청장아래에 5개의 국 ( Directorate General, DG ) 이 있어 5명의 국장이 청업무를 총괄하고 있음. DG1
# 탈러와 선스테인 != 작은 자극을 통한 행동변화가 필요하다. 미국의 행동경제학자 탈러와 선스테인
# 자기결정성이론 != 자기결정성은 개인이 자신의 행동에 대해 조절이나 통제를 할 수 있다고 느끼는 정도를 의미한다. 자기결정성이론
# 발진과 수포 != 부작용
# 4학년 != 4학년에 대한 평가도 함께 시행되었기 때문에, 본 연구의 대상 학년이 8학년
# 학생 != 학생들이 교수 ․ 학습 활동이나 기타 활동시에 수학 관련 도서
# 화천군 != 상징조형물
# 검찰청 !=
# 수용자 != 정식재판청구권 회복청구서
# 교수 != 지식큐레이터
# 43개 != 초등학생
# Cowen != Belton
# 이스라엘 != 유대인 이민
# 국토교통부 !=
# 한국도로공사 != 3년
# 0.62 !=
# 보건복지부 != 건보공단
# 제16조 !=
# 38명 != CRV망 연결
# 미국 RAND연구소 != 델파이 기법은 미국 RAND연구소
# 통일이 가시화되는 시점 != 통일을 준비하는 시기로 개념화하는 것이 바람직한 것으로 사료된다. [SEP] 어느 시점까지를 통일을 대비하는 시기
# 일면 !=
# 2개 != 경정청구
# 법인세 및 지방소득세 != 재투자인정금액
# 3.4억 != 3. 4억원
# 51.2% != 유통 업종 종사자
# 9개 !=
# 4억 원 정도 != 청항선 업무는 80명 정도가 담당하고 있다. 청항선은 척당 4억 원
# 2003년 != 범죄처리절차법 ( Proceeds of Crime Act 2002 ) ’ 을 제정하였고, 이를 관리하기 위해 2003년에 자산몰수청 ( Asset Recovery Agency. ARA ) 을 설립하고 몰수자산기금 ( Recovered Assets Incentivization Fund, RAIF ) 을 설치하였다. 이후 자산몰수청은 2007년
# 처벌에 있어 무관용 원칙의 확대를 통한 부패비용의 증가와 함께 부패수익의 적극적 환수를 통한 부패유인 제거 != 범죄수익
# 90만 명 != 크루즈 관광을 하기 위해서는 비행기를 타고 해외로 나가거나 가끔씩 소개되는 국제 크루즈 상품을 기다려야 했다. 국내 크루즈 선사가 부산항내 크루즈와 한 일간을 운항하는 크루즈 상품을 개발하여 간간히 상품을 판매했지만 이도 지금은 모두 중단된 상황이다. 우리나라에서는 크루즈에 대한 국민들의 관심도 높고, 정책의지도 높았지만 실제 크루즈 상품이 풍부하게 개발되지 못했다. 반면 우리나라를 기항하는 외국선사의 크루즈 선박은 매년 급증하고 있다. 크루즈 선박의 기항은 2012년 약 200척에서 2014년에는 400척으로 예상되고, 우리나라로 입항하는 크루즈 관광객도 2년 전 28만 명에서 올해는 90만 명
# Laidra와 Pullmann 그리고 Allik != 성실성이
# 15일 != 15일로
# 발고 시기 != 아동 성학대 피해
# 네트워크 !=
# 개인 콘텐츠 != 클라우드 전성기
# 전력 !=
# 등가교환 방식의 합의 != 외규장각 도서 반환
# 프랑스 !=
# 문체부 != 외규장각
# 경영조직법 제99조 != 경영조직법 제94조
# 센서스 != 10년 주기로 진행되었다. 센서스의 주요 목적은 법정 인구 확정과 인구통계 및 사회 · 경제적 특성 수집에 있다. 또한 지자체 주민등록대장
# 서비스디자인 도입 != 서비스디자인
# 3학년 2학기 != 3학년 2학기에
# 읽기, 쓰기, 말하기 능력  != 대학생 역량
# 진리 != 학문 ( 學 問 ) 은 배움을 통해 진리에 접근해간다는 의미라고 이해할 수 있다. 서양적 의미의 학문
# 타인(피해자)의 심리에 대한 해악 != 외상 후 스트레스 장애
# 뇌 !=
# 기술변화 != 경계이동 효과
# 적절한 실행체계 != 기본계획
# 일본기업 != 일본기업들은 제조업의 디지털화 ( IoT 등 ) 등 제조업 혁신을 위한 인프라 확충에 노력하고 있다. 일본 중소기업들도 디지털화를 통한 효율 제고를 위해 관련 인프라의 표준화 수준 향상에 노력하고 있다. 일본정부와 기업은 빅데이터와 사물 인터넷 ( IoT ) 등 디지털화된 첨단제조기업으로 변신시키는 독일의 인더스트리 4. 0에 대하여 큰 관심을 가지고 대응책을 강구하고 있다. 제품의 대량생산에서 주문생산으로의 이행, 공장의 리드타임 단축을 위한 효율적인 생산라인의 구축이 핵심이다. 일본정부는 공장자동화 등 제조 ( 모노즈쿠리 ) 의 미래 모습에 대한 연구를 강화하고 있다. 경산성은 ‘ 로봇혁명 이니시어티브협의회 ( 2015. 5 ) ’ 산하의 ‘ IoT 에 의한 제조변혁 워킹 그룹
# 위법수집 증거 !=
# 미국 법무부 != 미국장애인법
# 24개 군 != 지방자치법 개정안
# 4 != 4인
# 일본 != 기술인력 부족상황에 직면해 있다. 일본
# 중국 != 미국
# 트럼프 != 보호주의 무역조치
# 청년 != Off to a good start? Jobs for Youth
# G20 노동고용장관회의 != 청년실천계획
# 60만원 != 중소기업청년취업인턴제
# 또래 != 카친
# 중간생략등기형 != 중간생략등기형 명의신탁
# 아동 청소년기 != 초4 패널 자료를 연구대상으로 선정한 이유는 아동의 휴대전화 보유가 보편화되는 시점부터 청소년기 전반에 걸쳐 휴대전화 사용 패턴을 살펴보고자 했기 때문이다. 초등학교 4학년 이후부터 휴대전화 보유율이 급격하게 늘어나며, 아동 청소년기
# 100% != 100 %
# 각 지역의 산업경제 여건 != 지역경제 활성화 전략계획
# 울산, 거제 !=
# 정보 손실 != sdc 객체
# 통계기관 != 원격접속
# 고탄소형 != 고탄소형 에너지
# 학대 != 학대 문제는 해결되지 않고 있다. 본 연구에서는 2014년 노인실태조사를 활용하여 노인 학대와 건강 수준의 관계를 각 학대의 유형별로 살펴보고, 각 유형의 학대 경험들이 중복되었을 때 나타나는 건강 결과의 젠더 차이를 알아보았다. 연구 결과, 지난 1년간 전체 노인의 10 % 가 학대
# 청소년기 != 청소년기 자녀
# 가족경계 !=
# 특허침해 판단단계 != 발명의 설명 ’ 에 기재된 범위로 좁혀 부여함으로써 청구범위의 표현의 자유재량은 확대하면서도 그로 인한 실익은 상대적으로 ‘ 발명의 설명 ’ 의 기재로 제한하여 PbP 청구항의 기재 형태로부터 얻는 불로소득을 없애는 동시에 불필요한 PbP 청구항의 출원을 억제하여 반드시 필요한 경우에만 PbP 청구항
# 항저우 !=
# 이니셔티브 != 이해당사자
# 장관선언문 이행을 위한 부속서1 !=
# 부과권 행사 != 사전소득은닉행위
# 시·도 지방자방자치단체 != 자유학기제의 학생 지역 체험활동 지원에 관한 조례
# 문명의 기기 != 여자아이들이
# 2012 DSG != 안보 환경의 큰 변화란 ① 2011년 8월 발효된 예산통제법 ( Budget Control Act of 2011 ) 에 의해 구조화된 가용 국방재원 축소 상황을 고려한 전략 우선순위 재설정 필요성, ② 이라크 / 아프가니스탄 전쟁 종결 이후의 전략 제시 필요성, ③ 그리고 의회의 국방비 추가삭감 움직임이다. 2012 DSG는 이러한 국내외 안보 환경의 변화를 고려한 신국방전략
# 양적 성장 != 아웃바운드 관광
# 4.1부동산대책 != 4. 1 부동산대책
# 패킷감청 !=
# 영장주의원칙 != 인터넷 패킷감청
# 패킷의 헤더 부분 != 패킷 헤더에 패킷이 이동하는 경로 ( 목적지 ) 가 입력되어 있기 때문이다. 이 편지 봉투는 패킷이 분실되지 않고 제대로 목적지까지 도달하게 하기 위하여 필요한 정보를 담고 있다. 라우터가 패킷을 받으면 그 패킷의 목적지가 어디인지를 알아 내기 위해 헤더를 검사한 후 패킷을 목적지로 보내게 된다. 같은 데이터를 이루는 패킷들은 일반적으로 같은 경로로 움직이지 않고 임의적인 순서로 목적지에 도달하는데 목적지에 도착한 패킷들이 올바른 순서로 재결합하기 위해 필요한 정보 역시 헤더에 포함되어 있다. [SEP] 이동하는 경로가 입력되어 있어 전송되는 데이터의 편지 봉투
# 형사소추와 형사재판 != 형사소추와 형사재판의 영역
# 아시아~유럽 != 아 · 태지역 항공사들에게 유리하다. 먼저 태평양 시장의 경쟁은 ‘ 아시아 ~ 유럽 ’ 시장에 비해 상대적으로 지역 항공사간 경쟁이 덜 하며, 걸프 ( Gulf ) 지역 항공사들은 유럽에서와 달리 태평양 시장의 점유율은 아직 미미한 수준이다. 미국의 중국인 비자발급 절차 개선 역시 시장 성장에 긍정적인 영향을 준다. 중국인들의 경제적인 부가 증가하면서 미국 여행을 원하는 중국인 수는 늘고 있으나, 미국의 까다로운 비자 발급 절차는 시장 성장의 장애요인이었다. 그러나 최근 미국 정부는 중국인에 대한 비이민비자 발급을 늘리고 있다. 미국의 중국인 비이민비자 발급건수 증가율은 2010년부터 3년 동안은 전년 대비 약 30 % 이상 증가를 나타냈으며, 2013년 미국을 찾은 중국인 관광객 수는 약 180만 명으로 사상 최대치를 기록하였다. 중국만이 시장 성장을 견인하고 있는 것은 아니다. 동남아지역의 국가들은 자국 항공사들이 미국행 여객수요를 충족시켜주지 못함에 따라, 중화항공 ( China Airlines
# 영아기 != 자연탐구활동
# 영유아 != 보육교사 주도식 대집단 활동일 경우가 많으며, 영유아의 현재 발달적 수준을 파악하고 있지 못하는 외부 교사
# 주요 의사결정 단계의 문서 != 정부
# 도급계약 != 공사의 도급계약
# 30일 전 != 30일
# 500만원 != 강제력
# 중학교육과정 != 3단 평가제
# 서울 != 스포츠클럽과 교내리그, 방과 후 스포츠클럽
# 유로-6 != 유로 - 6
# 범죄피해 != 사이버범죄피해
# 24개 법규 != 24개
# 개인 != 크라우드 워커
# 대인관계 유능성 != 긍정적 정서표현은 부정적 정서에 대한 회복력을 증가시키고 감정조절 기술을 발달시키며 가족 내의 긍정적인 정서환경은 정서에 대한 지식, 긍정적 감정, 형제간의 친사회적 행동을 증가시킨다는 점에서 중요하다. 아동의 또래관계
# 수사와 기소 != 수사와 기소의 분리
# 루오 != 아노미 ’ 현상을 일으키며, 이것이 그 사회의 자살률을 높일 수 있다 ( 아노미적 자살
# 세계보건기구 != 노인 인권세계연맹
# 내수 != 제조업의 부진
# CES-D11 !=
# 8.7명 != 8. 7명
# 한국 != 국공립유치원의 부족
# 성범죄 != 피해자변호사제도
# 검사 != 국선변호사
# 2과목 !=
# 51% != 모바일 쇼핑이 차지하는 비중은 2013년 17 % 에서 2016년에는 54. 2 % 로 매년 증가하는 것으로 나타났다. 이와 같은 모바일 쇼핑
# 브롱코스트의 정의 !=
# 국립해양조사원 !=
# 구축과정 != 부분균형모형
# 산업별 부가가치율 !=
# 교육인적자원부 != 교육인적자원부와 산업자원부
# 2,000시간 != 어린 시기는 언어의 습득에 적합한 시기 ( 적기교육 ) 이므로 어릴 때부터 영어에 익숙해지면 고생하지 않고 자연스럽게 영어습득이
# 사교육 이용 수 !=
# 2개 != 완전정보최대우도법
# 82.2억 위안 != 82. 2억 위안
# 50% != 50 %
# 미래창조과학부 != 과학기술기본계획
# 국제형사재판소 !=
# 정부3.0 != 정부3. 0 추진실적을 점검하는 평가체계
# 청년 창업 != 청년 창업 지원
# 중소기업청 != 청소년 기준 연령은 9세에서부터 24세이
# 지역 현장 중심 != 지역문화정책포럼
# 문체부 != 지역문화 정책사업
# 생산공정 및 상시업무 != 중앙교섭 시급을 적용하도록 했다. 물론 노사가 합의한 문구에는 ‘ 적용하도록 노력한다 ’ 고 표현돼 있지만, 금속 최저임금을 사내하청 직원까지 적용대상을 확장한 것은 의미 있는 결과로 평가할 수 있다. 사내하청 회사가 다른 업체로 바뀌더라도 이들의 고용이나 근속연수가 승계될 수 있도록 한 내용도 사내하청 직원의 고용안정에 도움이 될 것으로 보인다. 하지만 이번 중앙교섭에서 짚어야 할 부분은 중앙교섭 의제로 상정된 ‘ 생산공정 및 상시업무 정규직화
# 병과체계 != 진화적으로 발전시키도록 해야 한다. 병과체계 및 특기제도의 급격한 변화는 조직 구성원에게 상당한 부담을 줄 뿐 아니라, 조직 및 인사관리에 혼란을 낳아 조직 능률을 저해할 수 있다. 둘째, 기술 발달과 미래 해군 전력구조 발전에 부합되도록 해야 한다. 기술 발달에 따라 일부 병과 간에 직무영역의 중첩이 발생하는 데다 기능의 중요성이 바뀔 수 있다. 또 미래 해군은 해상 및 항공전력 발전 못지않게 정보전 및 사이버전력
# 해당 관리감독기관의 장 != 교육청의 장에
# 실적 관련 변수 != 실적 관련 변수 간 선형 결합 정도가 매우 낮다는 부분이다. 변수 설명과정에서 언급하였듯, 사회적 자본 점수
# BMI != BMI를 중심으로 연구되어 왔으며 건조환경이 BMI에 미치는 영향에 대한 분석결과가 경험적으로 일치하지 않는다는 점이 눈에 띈다. 몇몇 변수 ( 토지이용균형도, 인구 / 주거밀도 등 ) 만 유의하게 나타나는 경우, 모든 변수가 유의하지 않은 경우가 혼재하며, 건조환경을 지수화한 경우 ( 스프롤 / 압축도 지수 ) 에서도 통계적 유의성이 일관되지 않는다. 특히 종단적 분석을 사용한 경우나 다단계 분석으로 개인특성을 엄밀히 통제한 경우 등 인과성을 엄밀히 분석한 경우 ( 각각 시간적 선행성 및 외생변수 통제가 보다 잘 만족됨 ), 건조환경과 BMI 간의 관계가 사라지는 경향이 발견되었다. BMI
# 69.5% != 개인영업잉여보다 큰 현상은 받아들일 수 없으며, 개인영업잉여 전체를 노동소득으로 간주하는 LS1은 노동소득분배율을 과대측정하는 문제를 가진다. 자영업의 노동소득분배율이 다른 경제 부문과 동일하다고 가정하는 LS2는 노동집약적인 자영업 부문의 특성을 반영하지 못하지만, 자영소득 가운데 얼마가 노동소득인지를 알 수 없는 상황에서 현실에 가장 부합한 방법이라고 판단한다. LS2 방법에 따라 조정된 노동소득분배율은 SNA 2008 기준으로 2013년 69. 5 %
# 2년 != 2년으로 제한하는 ‘ 출구 ’ 규제 방식을 취하고 있다. 하지만 기간제 근로자의 ‘ 남용 ’ 을 제한하기 위해서는 이러한 출구 규제 방식이 아니라 객관적이고 합리적인 이유가 존재할 경우에 한정하여 기간제근로의 활용을 허용하는 ‘ 입구 ’ 규제 방식으로 규제방식이 전환되어야 한다. 기간제근로의 활용을 입구에서 규제하는 방식은 ①당사자의 선택의 편의를 제한한다, ②고용 전반의 경직성을 높일 우려가 있다, ③당사자의 법적용 회피 행동을 촉진하여 법규제의 실효성을 확보하기 어렵다는 문제를 안고 있다 ( 水 町 勇 一 郞 · 連 合 總 硏 編, 2010, p. 76 ). 그럼에도 불구하고 입구 규제 방식
# 세 가지 변수 != 노동시장 이중구조화의 진전을 부추길 것으로 우려된다. 문제의 본질은 정기상여금
# 13.4년 != 13. 4년
# 중국 != 사드체계
# 시진핑 != 시진핑 시기부터는 한국에 대한 보다 적극적인 교류가 이루어졌다. 다시 말해서 장쩌민, 후진타오 시기에는 한반도에 대한 균형적인 관여정책이 추진되었다면, 시진핑
# 인원 != 심리적인 원인
# Penrose != 부하 중심적 리더십이 가능하기 위해서는 부하들이 가지고 있는 다양한 경험과 아이디어가 체계적으로 모여 경영에 반영되고 과거의 경험들이 누적되어 지식 경영이 가능할 수 있는 환경의 조성이 필요할 것이다. 이러한 점에서 종업원 제안제도는 유용하게 활용될 수 있는 지식 경영의 방법으로 볼 수 있다. 여러 학자들에 의하여 지식경영에 대한 다양한 정의가 있었는데 지식경영은 Penrose ( 1959 ) 에 의해 처음 기업에 관한 지식 기반의 관점이 소개된 이후 발전되어 왔다. Wing ( 1997 ) 은 지식 경영이란 경영활동의 효과성을 극대화하고 지식자산으로부터 부가가치를 창출 해내기 위하여 지식을 창출, 갱신, 적용하는 체계적이고, 명시적이며 의도적인 활동이라고 정의하였다. 지식경영의 활동을 구분하여 살펴보면 Ruggles ( 1998 ) 은 지식의 생성, 축적, 이전, 활용 및 학습의 5단계로 구분하였고, 최만기 ･ 권정미
# 증거물 != 압수대상물의 관련성은 전제된 범죄혐의 사건의 증거물로 사용될 수 있음을 말한다. 하지만 디지털 본래증거
# 레지스트리 != 디지털 전문증거
# 압수·수색·검증 영장 != 압수 · 수색 · 검증 영장
# 조대엽 !=
# 국민건강보험공단 != 지자체
# 환자 != 면적규모
# 일본 != 의료시설가이드라인
# 싱크대 != 손씻기 싱크의 basin
# 2016년 9월 !=
# 90% != 90 %
# 12.5억원 != 12. 5억원
# 경기 지역 !=
# 44% != 분만 취약지 지원 사업에 대한 개선이 절실한 것으로 파악되었다. 분만 취약지 지원 사업이 다른 방향으로 개선되어야 한다고 응답한 보건소 담당자들은 근본적인 문제로 분만과 같은 산부인과 처치의 저수가 제도를 개선하고, 의료진의 수급, 의료 분쟁에 대한 대처, 응급 산모 이송체계의 확립 등이 중요하다고 꼽았다. 이는 산부인과가 당면한 현실적인 문제들을 보여주고 있는 것으로 분석되었다. 분만 취약지 지원사업
# 1990년대 중반 이후 != 1998년 4월 17일
# 빠이바꼬띠 종일제 != 가정보육사 종일제
# 관광진흥5개년계획 != 제2차 관광진흥5개년계획
# 이성근, 이성인 != 박기현
# 86% != 86 %
# 허둥항, 쿵판빈 !=
# 세종시 5-1 생활권 != 세종시 5 - 1 생활권
# 하버드 대학 != 소프트파워
# 백의현 프로젝터 리더 != 서중해 소장
# 중앙정부의 지역개발 심의 권한 != 분권형 국가 균형발전의 실천을 위해서는 자치분권의 핵심 요소인 지방정부의 행정 · 조직 · 재정 · 입법권을 강화하고, 이를 국가 균형발전 정책의 핵심 요소인 공간계획, 추진체계, 지원체계, 법 제도에 접목하는 분권형 정책 추진체계를 정립해야 한다. 공간계획의 기획 및 계획수립, 공간 구분, 사업 구상의 분권화, 균형발전 정책의 추진 주체 및 거버넌스의 분권화, 균형발전 재정 및 예산, 인력 및 조직의 분권화, 균형발전 지원 제도 및 법률 제정의 분권화가 함께 이루어져야 하는 것이다. 이를 더 구체적으로 살펴보면, 먼저 국가 균형발전 분야에서 지방정부의 계획고권 확대를 위해 지방정부의 계획수립권 · 계획승인권 · 계획조정 및 참여권을 강화하고, 중앙정부의 지역개발 심의 권한을 지방으로 이양해야 한다. 국가 균형발전 재정의 분권화 확대를 위해서는 국가 균형발전 특별회계 포괄보조금의 지역 자율성 강화, 지역 간 차등 지원 확대, 국가 균형발전 특별회계 구조 개편이 필요하다. 다음으로 자치분권 분야에서는 지역 주도의 지역발전 추진체계를 강화할 수 있도록 지역발전 관련 재정 · 입법 · 조직 제도를 자치분권형으로 개편하고, 정부 간 협력 및 거버넌스를 강화하며, 중앙과 지방의 분권형 계획계약 제도
# 청소년 !=
# 네트워크 체계 !=
# 미국 샌프란시스코 != 우버
# 수행목표 != 수행목표 진술과의 차이
# 2005년 != 평화적 핵이용 권리를 보장하라는 요구를 제기할 수 있음이 암시되어 있다. 2019년 신년사에서는 전력문제 해결을 위해 원자력 발전 능력을 추구할 것이라는 입장을 밝혔던 것이다. 2005년 9 ･ 19 공동성명을 통해 6자회담 참가국들은 북한의 평화적 핵이용 권리를 보장하기로 한 바 있으나, 이 문제는 북미 간, 북한과 국제사회 간의 입장차를 야기하는 사안이다. 과거의 북핵 협상 사례를 볼 때에도 북한의 평화적 핵이용 권리를 인정할 경우, 북한이 경수로 건설을 요구할 가능성이 높다. 반면, 미국에게 경수로 제공 요구는 받아들이기 어려운 문제이다. 1990년대 중반 북한에 대한 경수로 제공문제
# 지시적 연수체계 != 학습연구년 참여교원의 활용방안을 내실화할 필요가 있다. 중등교사와 달리, 유치원 및 초등교사는 학습연구년 종료 후 복귀하여 학급을 전담하게 되므로 장학, 컨설팅요원으로 활용함에 있어서 시간적 제약이 커서 실질적으로 거의 활용하지 못하는 실정이다. 온라인을 통한 연수주제관련 일대일 또는 소집단 컨설팅 요원, 워크숍 강사 등으로 활용 방안을 모색하고, 특히, 학습연구년에 선발된 교원 오리엔테이션에 활용하도록 한다. [SEP] 무슨 이유로 학습연구년에 참가한 대학 교원을 장학인력
# 생산적 직업 활동 != 정상노동시간
# Canto != 소득이동성에 대한 국가별 연구를 살펴본다. Canto ( 2000 ) 는 스페인가구패널조사 ( Spanish Household Panel Survey : ECPF ) 를 사용하여 가구와 개인의 소득이동성을 각각 추정하였다. Khor & Pencavel ( 2006 ) 은 1990년대 도시 거주자를 대상으로 중국과 미국의 상대 소득이동성을 비교하여 중국의 소득이동성이 미국 혹은 다른 국가들보다 높음을 보였다. Lukiyanova & Oshchspkov ( 2009 ) 는 2000년 ~ 2005년 기간 동안의 러시아의 소득이동성을 Russian Longitudinal Monitoring Survey ( RLMS ) 의 소득과 소비자료를 이용하여 분석하였다. Chen
# 현장적응감각훈련 != 심신장애별로 구분되며, 중등 과정은 중등교사의 표시과목과 심신장애의 구분을 동시에 적용하여 자격을 구분한다. 시각장애인 담당 교사는 시각장애학생을 대상으로 점자판, 점필 등을 사용하여 점자 쓰는 방법을 가르치고 일상생활에 적응할 수 있도록 현장적응감각훈련을 계획하고 지도한다. 청각장애인 담당 교사는 농아 및 청각장애학생에게 보청기 또는 기타 전기ㆍ전자 증폭장치를 사용하여 대화기술을 가르친다. 교과수업, 사회 및 일상생활에서의 의사소통과 기술 습득이 용이하도록 수화나 구화 같은 언어적 의사전달 학습을 하며 정규 교과목도 교육한다. 정신지체장애인 담당 교사는 정신지체장애나 정서장애가 있는 학생을 대상으로 특수한 교수법을 활용하여 학습능력을 향상시키며 생활적응 방법과 기본적인 교과를 가르친다. [SEP] 시각장애인 담당 교사가 시각장애인을 가르칠 때 무엇
# 연방정부 != 아동낙오 방지법
# 제3차 != 제3차 전기사업법 개정안
# 공화당 != 공화당 대통령
# 승용차 != 대중교통
# 광역 또는 기초 지자체 != 기술혁신 연계
# 50-65자 != 글자체와 크기는 읽기 편한 정도, 읽는 시간, 선호도 등에 영향을 준다. 어떤 글자체
# NCS !=
# 전기요금과 위험성, 수입의존도 != 가구 소득이 높은 사람일수록 위험성에 민감한 것으로 해석할 수 있다. 따라서 향후 발전원
# 진로 개발 != 브리티시 컬럼비아 ( 이하 약칭 BC ) 주의 진로교육 동향을 좀 더 자세히 살펴보겠다. BC주
# 만 3, 4세의 취원율 != 만 3, 4세의 취원율은 2004년부터 지속적인 증가 추세로 5세 누리과정
# 잊혀진 학교교육 단계 !=
# 사업자등록 != 사업자
# 아시아 금융중심지 != 정부 주도 하에 이루어졌기 때문에 시장참여자, 특히 헤저들의 요구에 부합되는 선물계약의 설계에 한계가 있었다. 시장참여자의 부족으로 거래량이 미미했고 이는 유동성 부족으로 시장참여자들을 끌어 들이지 못하는 악순환을 낳았다. 역내 빈약한 금융환경으로 시장 유동성 증대의 한 축을 담당하는 투기세력들에 대한 유인도 실패하였다. 도쿄상품거래소
# 지분참여의 형태 != 지분참여
# 한국 != 한반도
# 사내하청 != 3자관계
# 위기 극복, 경제 회복 != 영미권에서는 소득불평등이 늘어났고, 유럽과 일본에서는 최상위 소득비중이 늘어나지 않았다. 기술변화와 세계화가 소득불평등을 확대하는 압력이 되지만 제도와 정책에 따라 불평등이 늘어나지 않을 수 있다. 유럽에서는 최상위 소득이 지나치게 늘어나지 못하도록 하고 저소득자를 보호하는 제도와 정책이 많이 마련되어 있어서 소득불평등이 확대되지 않았다. 반면, 한국
# 한국 != F - 15K
# 보복공격능력 != 연평도 포격사태
# 시군구 치매상담센터 != 혈관성 치매
# 카메라 측정방식과 티켓 != 무선신호기반 측정방식을 도입한 것으로 가정해 살펴보도록 한다. 이러한 이유는 전자카운터 방식 중에서 중복되는 대상을 파악할 수 있는 방식은 무선신호기반 측정방식
# 정신보건센터 != 교정심리치료센터
# 참여연대 사법감시센터 != 검찰개혁추진단
# 용접작업 != 사내하도급업체의 산재사고
# 금속노조 != 산별노조
# 노동조합 != 노동조합의 직업능력개발사업 개입이 근본적으로 정부실패를 치유하고, 직업능력개발사업의 조정자로서의 정부의 역할 전환에 기여함을 인식해야 한다. 이에 따라 노동조합이 직업능력개발사업에 참여할 수 있도록 여러 가지 정책적 조치를 취할 필요가 있다. 먼저 현재 고용보험 직업능력개발사업의 평가를 사용자 단체와 노동조합에 위임할 필요가 있다. 직업능력개발사업의 수요자들인 사용자와 노동조합이 사업 평가를 담당함으로써 정부주도의 훈련에 대한 문제점을 파악하고 이를 극복하기 위한 방안을 강구할 수 있게 해야 한다. 평가에 노동조합과 사용자 단체
# 사용자 != 인적자본투자
# 2019년 6월 19일 != 2019년 1월
# 일본 !=
# 193개국 != 지속가능한 발전에 걸림돌이 되곤 한다. 지속가능한 발전의 이상을 충족시키는 것이 결코 쉬운 일이 아니지만 지속가능한 발전을 이루기 위해서는 과학기술의 힘이 절대적으로 필요하다. 과학기술이 지속가능발전의 도전이자 실현의 지렛대인 셈이다. 글로벌 이슈들이 융합하여 새로운 문제를 일으키는 것과 비례하여 과학기술도 융복합 발전하여 응전할 필요가 있다. 한편, 2015년 9월 25일 유엔 지속가능발전 정상회의에서 193개국
# 20세기 != 글로벌 이슈
# 0.940점 != 0. 940점
# 지역의 명망가들이나 부호 != GUCI
# 제도적 설계 != 협력 과정
# 이메일 != 선순환
# 디지털교과서 != 서책형 교과서
# 교사 역량 != 교사
# 건축·건조환경위원회 != 건축 · 건조환경위원회
# 10 !=
# 30세 != 만30세
# 2008년 !=
# Beck !=
# 노동시장 수요와 대졸자 공급 != 청년층 실업문제
# 영동교육지원청 != 블루와인펜션농원
# 절접법 != 저위 변형할접법
# 30~60cm != 1년생 묘목
# 공직의 기강해이 != 기강해이
# 통치이념의 변화 !=
# 성능목표 != 성능에 기초한 내진설계
# 특사경과 일반사경 != 권리의 ‘ 충돌
# 국민의 자유와 권리의 위축 !=
# 지역생활정착지원센터 !=
# 사회구성원 != 사회구성원들의 인식
# 2001년 != 혼인 후 첫째아 출산까지의 기간 ’ 을 분석 시간 ( analytical time ) 으로 설정하였다. 개인별로 비교가능한 출산시점을 설정함에 있어 모든 이들에게 공통적으로 적용할 수 있는 ‘ 연령 ’ 이라는 보편적인 기준이 존재하지만 개인별로 교육수준이 다를 수 있고 같은 정도의 교육을 받았다고 할지라도 대학입학과정에서의 재수나 재학 중의 휴학 경험 등으로 서로 다른 졸업시점을 가질 수 있다. 일반적으로 재학 중에는 혼인을 하지 않는 경향이 강한 한국의 특성을 감안한다면 단순히 출산 당시의 연령을 비교하는 것 보다는 별도의 기준을 설정하고 이를 비교 ･ 분석하는 것이 보다 설득력을 얻을 수 있을 것이다. 이러한 논의를 바탕으로 한국이 초저출산 국가의 반열에 들어선 2001년 이후 혼인을 경험한 혼인 당시 임금근로자였던 여성표본을 대상으로 이들의 혼인 후 첫 출산
# KLIPS != 한국노동패널 ( Korean Labor and Income Panel Study : 이하 KLIPS ) ｣ 자료를 이용하여 근로자의 일 ･ 가정 양립 지원을 위한 가장 대표적인 제도인 출산전후 휴가와 육아휴직의 이용가능성이 여성의 출산에 어떤 영향을 주는지를 구체적으로 살펴보고자 하였다. KLIPS
# 사립학교 != 가톨릭학교
# 북한 != 북한의 도발에 대응하였다. IMO는 2016년 11월 제97차 해사안전위원회에서 북한의 사전 통보 없는 미사일 발사에 심각한 우려를 표명하고, IMO의 관련 협약 및 결의를 준수할 것을 촉구하는 결정회람문 ( circular ) 을 채택하였다. 또한 북한이 2016년 초 수도권과 강원도 일대에 위성항법장치 ( GPS ) 교란 전파를 발사한 것과 관련하여, IMO는 북한의 GPS 교란 행위가 해사 안전에 심각한 위협이 된다고 지적하였다. 또한 북한이 참여하고 있는 비동맹 운동
# 베드타운 != 베드타운 ( Bed Town ) 개발이 주류를 이뤄왔습니다. 이들 신도시에서는 주거의 수용성을 높이기 위한 공동주택, 특히 우리나라에서 가장 보편적 주거 형태인 아파트 중심의 개발이 이뤄졌습니다. 행복도시
# CANWFZ 조약 !=
# 시진핑 != 시진핑 정부
# 85세 !=
# 소규모 공동생활거주 != 노인공동생활거주
# 정확성 != 잠정치
# 인공지능 알고리즘 !=
# 6.4% !=
# 뉴스매체 != 뉴스매체에 대한 이용 현황이다. 현대 사회의 개인들이 각자의 경험, 귀속집단, 이해관계를 넘어 공공사안에 관련된 일반적 정보와 의견을 접하는 지배적 창구는 뉴스매체이며, 개인들은 목적의식적으로 특정 뉴스매체를 선택하거나 자신도 모르게 특정 뉴스매체에 반복적으로 노출됨으로써 일정한 방향으로 구조화된 의견을 형성하는 경향이 있기 때문이다. 또 급속한 개인화 추세 속에서 계층과 집단에 대한 귀속의식이 약화되는 한편 사회정치적 정체성과 태도 형성에서 개인적 선택이 중요해짐에 따라, 이에 상당한 영향을 미치는 일반적 요인으로 부상한 것이 바로 뉴스매체
# 형법상 강간죄 != 비동의 간음죄의 도입입법이 마치 ‘ 국제적 ’ 기준 내지 영국을 비롯한 ‘ 선진국 ’ 이 앞서 도입한 선례를 당연히 뒤따라야 하는 과제인지의 여부, 그리고 종래 강간죄를 기본으로 하는 성폭력 형법체계가 비동의 간음죄 규정 신설이나 대체 법개정을 통해 여성의 성적 자기결정권을 강화하며, 성폭력 피해를 줄이는 방향으로 강간죄 처벌 실효성을 높이는 결과를 낳을지의 여부는 비판적 검토가 필요하다. 현행 형법상 강간죄
# 민간부패 != 공직부패
# 심리학자 반두라 !=
# 자치경찰의 전속관할 != 전속관할
# 10억원 != 중소기업 컨설팅사업이 있다. 중소기업기술개발인력 활용지원 사업은 해외고급 기술개발인력 지원과 산업통상자원부 사업과의 중복 문제가 지적되어 10억원이 감액 ( 115 → 105억원 ) 되었으며, 중소기업 컨설팅사업은 녹색경영 컨설팅의 사업관리 부실 문제로 1억 8, 000만원이 감액 ( 215. 8 → 214억원 ) 되었다. 심사 과정에서 예산이 감액되지는 않았으나 사업의 필요성 ․ 타당성 등에 대해 논란이 있었던 사업으로 ① 소상공인 성장기반조성사업
# 소상공인 사업체 !=
# 심미적 경험 != 문학적 읽기
# 어휘 != 독자
# 장안식 != 학교폭력 피해경험은 청소년기 심리적 문제를 유발하는 요인이 된다. 피해경험은 우울, 불안, 자살생각 등의 심리적 문제를 경험하게 되면서 청소년들의 건강한 성장을 방해한다 ( 김재엽, 이근영, 2010 ; 이완정, 정혜진, 2010 ; Baldry & Winkel, 2003 ; Barker, Arseneault, Brendgen, Fontaine & Maughan, 2008 ; Herba et al., 2008 ; Klomek et al., 2009 ). 또한 시간이 지나도 자아존중감, 학교적응, 성적이 낮아지며, 우울, 주의집중, 위축된 모습을 보이게 될 뿐 아니라 자살생각까지도 이어질 수 있다 ( 김현숙, 2013 ; Arseneault et al., 2006 ; Egan & Perry, 1998 ). 권세원, 이동은, 장은혜와 한기주 ( 2013 ) 는 중학생 시기의 피해경험은 고등학교 시기의 우울과 자살생각까지 영향을 미치는 것으로 보고하면서 학교폭력 피해경험으로 인한 고통은 오랜 시간이 지나도 계속됨을 보여주었다. 장안식
# 외국 투자자 != 문화정책과 충돌
# Baltijos Parkingas != Parkerings 사건
# 프리에이전트 != 경력전환
# 주교통이사회 != 6개년 개선사업
# 원유 도입가 != 원유 도입가와
# 100분의 20 !=
# 중학교 != 대학의 교육봉사 활성화
# 교과목 != 교육봉사 교과목
# CGE != CGE ( Computable General Equilibrium ) 모형
# 한-중 FTA 추진 != 프로빗
# 성별영향분석평가 != 성별영향분석평가를 실시하는 주요 목적과 의미는 각 기관의 주요 정책방향에 성평등 가치를 포괄할 수 있도록 설정하고, 핵심사업 안에 그러한 성평등 가치를 실현하기 위한 사업들이 포괄될 수 있도록 하기 위한 것이라고 생각된다. 현재 중앙정부와 지방정부 각 기관은 고유의 성평등 목표와 정책방향, 핵심사업을 설정하고 있지 못한 상황이다 ( 예를 들어 고용노동부와 국토교통부의 성평등 목표는 무엇인가? 핵심 성평등 정책과제는 무엇인가? ). 성별영향분석평가는 각 기관 및 부서들이 성평등 목표와 정책방향, 핵심과제를 가지고 추진할 수 있도록 하여야 한다. 따라서 계획에 대한 성별영향분석평가
# 제3자 효과 != Pearson상관관계 분석을 실시하였다. 상관관계 분석
# 헌법규정 != 헌법 제110조 제4항
# 청탁방지담당관 !=
# 기후변화와 환경오염 != 환경오염
# 공공외교 자산 != 한류의 지속성에 대해서는 진지한 고민이 수반되어야 한다. 과거 아시아를 풍미했던 일본의 J - Pop이나 J - 드라마의 열풍이 소진된 예에서 볼 수 있듯이 대중문화 상품의 인기의 지속성에는 뚜렷한 한계가 있기 때문이다. 따라서 국가적인 차원에서는 한류가 절정기에 있을 때 이를 보완하거나 후속할 수 있는 새로운 공공외교 자산
# 소통 != 지식외교
# 운영 방식 문제 !=
# 106억 9,890만원 != 106억 9, 890만원의 과징금을 부과하였다. 이번 시정조치의 효과가 단기에 그치지 않도록 방통위는 시장 모니터링을 강화하는 등 지속적인 현장점검을 실시하며, 특히 과도하게 차별적인 ‘ 경품 등 ’ 을 지급함으로써 시장을 교란하는 주도사업자에 대해서는 선별적으로 제재하거나 제재수위를 강화하는 등 엄정하게 대처하겠다고 밝혔다. 마지막으로, 방통위는 유료방송사업자들에 대해서 시청자 이익을 저해하는 불공정행위 여부에 대한 조사의 필요성이 제기되어 종합유선방송사업자, IPTV사업자를 대상으로 불공정행위
# 자신의 근간 != 근간
# 융합 != 창의융합형 인재 양성이 이번 교육과정 개정의 주요 방향이었다는 점에 서 개정의 주요 내용을 살펴보기에 앞서 창의융합형 인재가 과연 어떻게 만들어진 용어이며 어떠한 의미를 지니는지에 대해 먼저 이해하는 것이 필요하다. 이번 개정 교육과정에서는 ‘ 창의성 ’ 과 ‘ 융합 ’ 의 용어를 결합하여 ‘ 창의융합형 인재 ’ 라는 인재상을 제시하였다. 교육과정은 학생들의 삶과 학습에 있어 기대되는 바람직한 변화를 현재 시점에서 계획하는 것이기 때문에 교육과정에서 사용되는 용어들은 현재의 사실 관계를 설명하는 것이라기보다 앞으로 추구하고자 하는 가치 진술이라는 점에서 규범적 성격을 갖는다. 창의성은 흔히 아이디어, 사물, 기술, 접근 방법을 새로운 방식으로 결합하여 독창적인 산출물을 만들어 내는 능력의 의미로 사용된다. 창의성은 현 시대뿐만 아니라 미래에도 여전히 중요한 가치를 지닐 것으로 기대되기 때문에 창의성이
# 단순정제마진 !=
# 위해 != 적합한 ’ 운송물을 인도하여야 한다는 것은 다른 사람이나 운송물에 아무런 위해 ( harm ) 를 입히지 말아야 한다는 의미이다 ( 제27조 제1항 ). 규칙이 ‘ 위해
# 헤이그 비스비 규칙 != 감항능력주의의무
# 직업교육훈련 != 과정평가형 국가기술자격
# SC != SC 조직의 개편을 위해 좀 더 노력해야 한다. SC는 산업 숙련수요 파악, NCS 및 학습모듈 개발, 자격 설계 및 운영, NQF 운영을 위해 기존의 산업별 협회의 하위조직이 아닌 별도의 독립적인 조직 구성이 필요하고, 다양한 SC 육성방안과 SC의 비영리 법인화 추진이 요구된다 ( 김상진 외, 2014 ). SC
# 액션모니터링 시스템 != 워터쇼케이스
# 2000년대 !=
# 경제/문화적 인센티브 != 규제
# 2015년 3월 27일 != 2011년 6월
# 수준 평가 가능성 != 객관성
# Input-Process-Output-Feedback !=
# 9,429억 원 != 글로벌 경제위기 등에 대비하여 그 중요성이 더해가고 있으며, 이러한 중심축으로서 기술혁신의 가치 향상을 위한 노력 또한 더욱 더 증가하고 있는 상황이다. 단기적 기업 경영 위기에 대한 구제가 아닌 미래 중장기 경쟁력 제고를 위한 중소기업 지원 정책으로서 중소기업청의 2016년 R & D 예산은 9, 429억 원
# 20% !=
# 일본 !=
# 글로벌 수요침체 !=
# 82% != 82 %
# 베이비루프 != 베이비루프 ( Baby - Loup ) 사건
# 후기 청소년 != 뉴스저이용집단
# 중기교통시설투자계획 !=
# 기관 !=
# 환경평가제도 != 환경평가 관련 해외 정보는 현안 대응을 위한 중요한 정보를 제공해주지만, 개별 연구자를 중심으로 연구 목적에 맞게 조사가 이뤄지고 자료 축적이 산발적으로 이뤄지고 있어 정책 현장이나 관련 전문가가 정보를 공유하고 2차적으로 이용하는 사례는 드물다. 특히 환경 문제와 이슈가 발생할 때마다 선제적으로 대응하기 위해서는 해외 정보와 사례 조사가 빠르게 수행될 필요가 있지만, 어느 정보가 어떤 연구에서 다루어졌는지 과거 정보 수집 경력과 경로를 확인하는 것이 어려워 관련 정보를 직접 활용하는 데 많은 시간이 들고, 불필요한 추가 조사가 시행되는 사례도 빈번하다. 한편, 환경평가제도는 학제적 특성으로 인하여 관련 내용을 이해하는 데 전문성이 높아 일반인의 이해도가 낮은 부문이다. 환경평가제도
# 2008년 != 탐색구조 임무
# 전라북도 != 종교문화자원의 활용과 정책적 지원이 새로운 과제로 대두되고 있다. 본 연구는 대규모 종교행사를 지방자치단체에서 어떻게 지원할 것인가에 대한 쟁점을 정리하고 정책방향을 모색하는 데 연구의 목적이 있다. 종교자원개발 및 종교지원에 대한 정부와 지방자치단체의 선행 논의들을 바탕으로 대규모 종교행사 지원에 대한 쟁점을 도출했다. 종교문화자원 개발 및 종교행사를 중심으로 정책적 논의가 진행되고 있는 전라북도를 대상으로 대규모 종교행사를 지원하기 위한 과제와 문제점을 정리했다. 특히 종교행사의 정책적 지원이 지역사회의 합의를 전제로 한다는 측면에서 정책의 수용자인 지역주민을 대상으로 종교행사의 파급효과나 지원방식에 대한 인식을 분석했다. 분석결과를 바탕으로 지방자치단체에서 대규모 종교행사에 대한 공공지원을 위한 몇 가지 정책방향을 제시했다. 종교지원
# 이형구 작가 != 이형구
# <고려인 마을> != S대표를 만났다. S대표
# 국제전화입니다 !=
# 걸쇠와 걸림쇠의 불필요한 접촉 != 불필요한 접촉
# 풍력발전 != 풍력 발전기술
# 경기도 판교신도시 != 판교신도시
# 10명 중 1명 != 보이지 않는 불평등
# 광주광역시 != 인본디자인
# 25개 != KDRC는 기존 사업과는 다른 몇 가지 특징을 가지고 있다. 첫 번째, 기존 산업부의 중 · 단기 상용화 기술 위주 지원에서 미래 원천기술 위주로 지원 대상기술이 달라졌다는 점이다. KDRC 사업은 총 7개 기술 분야를 25개
# 당연 대항제도 != 당연 대항제도를 2011년부터 도입하였다. 등록에는 시간과 비용이 소요된다는 점, 실시의 범위에 관한 상세한 조건을 전부 등록해야 한다는 점, 특허권자가 등록에 협력하지 않는다는 점 등을 이유로 통상실시권 등록제도는 거의 이용되고 있지 않고 있었다. 2006년 기준으로 일본의 통상실시권등록률은 약 1. 3 % 로 추계되었다. 이러한 상황에서 등록 대항제도는 그 기능을 다할 수 없기 때문에 기업의 안정적인 사업운영 및 기술개발을 위해서 당연대항제도를 도입한 것이다. 우리나라의 경우도 일본과 마찬가지로 통상실시권의 등록 건수가 매우 작아 통상실시권자의 대부분이 미등록상태로 있는 실정이며 등록대항제도는 통상실시권자의 보호에 매우 미흡하다. 따라서 일본의 경우와 같이 등록대항제도를 폐지하고 당연대항제도
# 빈도의 증가 != 그린링크
# 회복적 사법 이념 != 형사조정 참여
# 미래부 소속 기구 != 중앙전파관리소
# 만성질환으로 인한 지출 != 만성질환
# 성희롱 != 법적인 대응
# 변혁적 리더십 !=
# 미국 !=
# 300억달러 != 커버드본드
# 원수 != 223천㎥
# 3% != 산업투자기금
# 제6조 != 지역노사민정협의회
# 김정홍 외 != 김정홍
# 폐저어콘 != 폐저어콘은 주기적으로 회수된다. 폐저어콘은 톤백에 담겨 보관창고에 격리 보관되며, 유실된 폐저어콘 분량만큼 새 저어콘 샌드를 유동조에 투입하는 방식으로 공정이 유지되고 있다. 해당 공정을 위해 업체는 연간 2톤 미만의 저어콘 샌드를 취급하는 것으로 조사되었다. 반면 업체 B는 상기 공정을 통한 제품 생산을 중단한 상태이다. 동 업체는 2018년 3월 말 스틸코드
# 일자리 만족 != 일자리 만족도는 취업을 통해 궁극적으로 얻고자하는 개인의 삶의 질에 크게 영향을 미치기 때문에 특성화고 졸업 이후 노동시장으로의 이행에 대한 성과를 판단하는데 있어서 주요한 변인이라고 할 수 있다 ( 백병부 외, 2009 ). 또한 전공일치 등의 직무일치도는 임금, 안정성 등의 일자리 만족에 긍정적인 영향을 미치며 ( 유현숙 조영하, 2005 ), 학교가 학생들에게 전문적인 진로교육 및 취업지원을 제공할 때 학생들이 전공에 부합하는 분야로 취업할 확률이 높아진다 ( 백병부 외, 2009 ). 따라서 특성화고의 진로지도 및 취업지원과 직무일치도 사이의 관계를 파악하고, 직무일치도를 매개로 한 특성화고의 진로지도 및 취업지원과 직업만족도의 관계를 규명하는 것은 향후 특성화고의 운영에 일정한 시사점을 제공해줄 것으로 기대된다. 이에 본 연구에서는 특성화고의 진로지도 및 취업지원 프로그램이 실제로 학생들의 직업만족도에 어떠한 영향을 미치는가를 분석하고자 하였으며, 특히 진로지도와 취업지원의 효과를 직무일치도
# 4 !=
# 사업주 != 산재보험
# 덴마크 != 신속대응여단
# 의원입법 절차 != 국가연구개발사업 법제의 개편방향을 제시하고자 하였다. 이를 위해 연구진은 연구의 기획 및 수행과정에서 관련 법제의 수범자인 출연연, 대학, 전문기관 등과 긴밀한 협조체제를 구축하였고, 국가연구개발사업의 연구과제를 수행하는 연구기관 ( 연구자 ) 들과 지속적으로 의견을 교환하여 현행 법제의 문제점을 분석하고 대안을 마련하고자 하였다. 또한 종전의 선행연구가 연구의 궁극적인 목적인 법안 성안을 도달하지 못한 원인, 즉 국가연구개발사업 법제가 다수의 소관부처에 걸쳐 있다는 점에서 정부입법보다는 이해관계자의 이해관계 조정이라는 측면에서 여야 합의에 따른 의원입법 절차를 통해 해결해야 한다는 방법론을 제시하였다. [SEP] 국가연구개발사업 법제
# 미국 !=
# 정치적 선동성 !=
# 독일제국 != 바벨탑
# 한류 !=
# 400명 != 약 400명
# R&D 투자 계획 != R & D 투자 계획
# 정원수 규모 != 1, 실시하지 않으면 0으로 구분하여 4개의 이분변수를 만들었다. 재가장기요양서비스
# 지역 경제 != one size all fit
# 대구고용센터 != 협업
# 구창모 != 시간제약
# Heatnot-burn != 궐련형 전자담배
# 노무현 정권 != 무상보육
# U-City 도시안전 다중 비상벨 != U - City 도시안전 다중 비상벨
# CCTV != 비상벨
# 포스코 !=
# 챗봇 안내 도우미 != 빅데이터 기술
# Smart Tunnel != 미래여객보안검색대
# 영장실질심사 != 강제수사
# 제4조 != 구체적인 수사지휘
# 설악산 != 비룡 폭포
# OPLC6) Requirements Team != CNSTAT
# 15,750엔 != 15, 750엔
# Campylobacter species != Rifaximin
# 정구현 != 학습률
# 담보나 보증 != 보수적 금융행태
# 담보나 보증 != 은행 혁신성평가
# 12% !=
# 공공기관 != 하방경직적 지출행태
# 자체수입 비중 != 하방경직적 원가행태
# 더빙 != 화면해설방송
# 불확실성 != 불확실성이
# 북한 !=
# 연 338만원 != 338만원
# 20조 != 정신병리학적 장애로부터 기인하는 것인지 분명하게 해명될 수 없는 경우도 가정해볼 수 있다. 물론 그 원인이 정신장애
# 2009 != 2009년
# 폐쇄형 연구개발 프로세스 != 외부 연구개발
# 외부 연구개발 프로세스 != 네트워크형 연구개발 관리
# 공정근로기준법 != 공정근로기준법상 근로자
# 공소시효 != 국제범죄
# 메디치 효과 !=
# 상업용 != 건축의 용도
# 민간부문 != 아파트
# 한국 != 북한인권정책
# 북한 != 북한인권정책
# 무료 보편적인 시청권 != 지상파 MMS
# 일-가정 양립제도 != 일 - 가정 양립제도
# 일본 != 통합방공미사일 방어
# 아베 정권 !=
# 일본 != 운송업
# 3년 != 북한인권증 진기본계획을 수립하고, 매년 그 집행계획을 수립해야 한다 ( 동법 제6조 ). 북한 인권증진기본계획에는 북한주민의 인권실태 조사, 남북인권대화와 인도적 지원 등 북한주민 인권증진 방안이 포함되어야 한다. 앞서 2011년 국가인권위원회는 ‘ 북한인권개선을 위한 국가정책 ’ 권고안을 통해, 정부가 북한인권 개선 중장기 실행계획을 수립하는데 체계적인 정책 방향을 제시한 바 있다. 첫째, 북한주민의 인권은 복합적 요인에 의해 광범위하고 조직적으로 침해되고 있기 때문에 개선방안은 자유권과 사회권의 통합적 관점에서 추진되어야 한다. 둘째, 북한주민의 인권개선
# 1971년 1월 != 농림수산업자신용보증기금은 농어촌 경제의 균형 있는 발전에 기여할 목적으로 1971년 1월
# 한국무역보험공사 != 무역보험기금
# 김홍수 != 김홍수 강사
# 선사유물전시관 != 60만 년 전 후기 구석기 시대 한반도 사람들의 생활단면을 그린 벽화를 보기위해 그곳에 있는 선사유물전시관을 자주 찾았다. 전시관 출입구 벽에 그려진 벽화는 남한강 상류 강변에 살던 우리 조상들이 돌망치, 주먹도끼, 주먹칼 등 석기시대 연장으로 물고기와 조개 등을 잡으면서 살아가는 모습을 보여주고 있다. 맨발에 아랫도리만 가린 맨 몸이고 팔과 다리 그리고 가슴과 어깨 등의 뼈에는 살이 별로 붙지 않은 앙상한 모습이다. 물론 당시는 문명생활 이전이었기 때문에 입을 옷도 없었을 것이고 먹을거리도 모자랐을 것이다. 따라서 맨발 맨 몸은 당연했고 영양 상태 또한 균형을 이루기 어려웠을 것이다. 그러나 그림 속의 그들은 어딘가로 향해 움직이는 모습이고 뼈에 붙은 살은 빈약하지만 근육질임을 알 수 있게 해준다. 따라서 그들의 생활은 움직임의 연속이었을 것이고 동시에 부지런하고 독립적이었을 것이란 추리를 가능케 한다. 그렇지 않았다면 60만년 동안 대대손손이 이어지도록 살아남지 못했을 것이기 때문이다. [SEP] 단양 수양개 마을의 어디에 후기 구석기 한반도 사람의 벽화
# 국제관계의 중요성 != 국제관계의 중요성이
# 서양 !=
# 100조 원 !=
# 네 가지 != 번역
# 가성적 회귀 != 가성적 회귀 ( Spurious Regression ) 현상
# 한국공학인증원 !=
# 뿌리 != 토양의 유효수분
# 70여 종 != 딸기세균모무늬병
# 기술지도 != 고위험업종 안전보건지킴이 사업
# 농협중앙회 NH식품사업부 !=
# 미국 != 미국의 동맹 체제
# 0.024~0.227 pg I-TEQ/L 수준 !=
# 90억 명 !=
# 모바일 플랫폼 != 카카오톡
# 비타민 A != 엽산 단독 제제는 임신부에게 반드시 필요한 비타민을 매우 싼값으로 가볍게 복용할 수 있다는 장점이 있지만, 임신부가 아닌 가임기 여성이 챙겨서 복용하는 것이 낯설게 느껴질 수 있습니다. 종합 비타민제는 엽산보다 꽤 비싸다는 단점이 있지만, 많은 사람들에게 친숙하고 어디에서나 쉽게 구할 수 있습니다. 다만, 여러 비타민제를 중복 복용하는 것은 피해야 합니다. 특히 비타민 A
# 1972년 != 국가산림자원조사
# 인간관계 != 학교폭력
# 국민 !=
# 일본의 경제보복 != 경제보복
# NQF != 병역문제
# 소방대원 != 민간위탁
# 감시와 인센티브 != 비용절감으로 인해 효율성이
# 원격진료 != IoT 헬스케어 제품
# 고혈압 관리 IoT 헬스케어 제품 != 고혈압 관련 현황을 살펴보도록 하겠다. 고혈압
# 고졸취업 != 고졸취업에 직접적으로 영향을 주는 기업과 학교의 채용연계 체계
# 기업의 이윤창출과 조직의 유지 != 학생 교육
# 법령 != 행정규칙 제명
# 111.7백만 톤 != KEEI - EGM System ) 을 사용하였다. 전망방법을 개략적으로 살펴보면, 에너지부문은 업종별 생산량 ( 예, 조강생산량 등 ) 등 활동자료 전망치에 활동자료당 에너지 수요량을 나타내는 에너지효율 변수를 곱하여 에너지수요량을 산정하고, 이에 배출계수를 적용하여 온실가스 배출량 전망하는 방식을 사용한다. 비에너지부문은 활동자료 전망을 바탕으로 각 부문별 배출계수를 직접 적용하여 온실가스 배출량을 전망한다. 온실가스 배출전망 결과 2030년 배출전망치는 850. 6백만 톤으로 전망기간 중 연평균 1. 33 % 증가하는 것으로 분석되었다. 에너지부문은 2030년 738. 9백만 톤으로 총 배출의 86. 9 % 를 차지하고, 전망기간에 연평균 1. 32 % 증가하며 2020년 이후 증가율은 약간 감소하는 것으로 나타났다. 한편, 비에너지부문의 배출량은 2030년 111. 7백만 톤
# 일본의 보수 오피니언 리더 != 외환과 금융위기
# 기업들 != 비금융기업
# 자본시장법 != 금융자산지표 계산을 위한 금융자산을 어떻게 측정할 것인가는 또 다른 이슈이다. 본 분석에서는 금융자산을 이자, 배당, 매매차익 등을 기대할 수 있는 증권 및 예적금을 의미하는 것으로 실제 수익을 얻었는지 그리고 그 수익이 유의미한 수준인지와는 무관하다. 여기서 증권은 채무증권, 지분증권, 수익증권 등을 모두 포괄하는 의미이므로 대상이 되는 금융자산은 예금, 적금, 주식, 회사채, 수익증권, 금융기관 단기예치금 ( MMF, MMDA 등 ) 이 모두 포함되는 개념이다. 따라서 금융자산에는 현금 및 현금등가물은 포함되지 않는다. 참고로 증권은 자본시장법상의 증권과 동일한 개념으로 자본시장법
# 중소기업 != 지식재산이 기업의 연구개발 결과를 고정 ( Fixation ) 또는 전유화 ( Appropriation ) 하는데 실질적인 도움이 되는 것이 중요하다. 따라서 중소기업
# 형사소송법 제201조 제3항 != 구속영장의 발부여부를 결정하여야 한다. ” 에서도 구속영장의 발부를 ‘ 결정 ’ 하도록 하고 있으며, 우리는 통상 구속영장 발부 또는 기각 ‘ 결정 ’ 으로 하지 ‘ 명령 ’ 이라 하지 않는다. 또한, ‘ 명령
# 한국 !=
# 인용설 != 가능성설
# 1981~1985 != 인구증가율 1 % 조기달성 운동기
# 1990년대 중후반 기근 !=
# 보정론 != 해체론
# 2019년 1분기 != 2019년 1분기에
# 인도 != 블루이코노미
# ACR != Real - time TV Commerce
# 2014년 != 외국어 위탁교육은 최근 3년간 연례적으로 집행실적이 저조하였다. 연도별 예산 집행률은 2012년 53. 0 %, 2013년 31. 5 %, 2014년 60. 7 % 이었다. 다만 2014년의 경우 집행률이 다소 개선되었는데 이는 외국어위탁교육 과정의 수료인원이 전년대비 일부 증가한 것에 기인한다. 2014년 국외 국 ‧ 과 장급 직무훈련 예정자 등에 대한 사전 어학연수가 의무화됨에 따라 한국외대 및 충남대의 수료인원이 50명 정도 늘어났다. 국회예산결산특별위원회는 2014년 예산안 심사시 외국어교육 및 대학원 위탁교육 실적이 저조하다는 이유로 동 사업의 예산이 1억 7, 800만원 감액된 바 있다. 그럼에도 2014년 동 사업의 집행실적이 미흡한 수준이며, 이는 사업의 집행관리리를 충실히 하라는 국회의 지적사항을 제대로 이행하지 못하였다고 볼 수 있다. 인사혁신처에 의하면 2012년
# 감정이입적 염려 !=
# 실현가능성 != 주택수요
# 아동·청소년 != 아동 · 청소년
# 활동보조서비스 != 발달재활서비스
# 중국 != 2035∼2049년
# 2025년 != 중국제조 2025
# 직무 != 능력기반훈련
# 전문가 인력풀 != NCS 기반 훈련과정의 심사기준은 훈련 품질의 제고와 활용 확산의 측면에서 사전 설명회 등을 통해 인지시키고 훈련기관으로 하여금 사전에 준비할 수 있도록 하는 것이 바람직하다. 또한, 훈련과정 심사를 실시한 후 그 결과에 따라 인정 비율이 낮으면서 컨설팅을 희망하는 훈련기관에 대해서는 NCS 기반 훈련과정 개발 및 운영에 필요한 맞춤형 컨설팅을 제공해주는 것이 바람직하다. 아홉째, 훈련과정 심사의 공정성과 효율성을 높이고 심사위원의 전문성을 고려하여 NCS 세분류 기준으로 심사위원 풀을 구성하는 것이 바람직하다. 이때 NCS 개발 등 관련 업무 수행 경험이 풍부한 전문가 ( NCS, 기반 학습모듈, 기반 훈련기준 등 개발 ･ 심의 참여 ) 를 심사위원으로 활용하여 NCS의 이해를 바탕으로 심사가 이루어지도록 해야 한다. 한편, 지역별로 훈련과정 심사가 이루어질 경우 지역 단위로 전문가 인력풀
# 일-기반 학습 프로젝트 != 일 - 기반 학습 프로젝트
# 열악한 가정환경 != 대효
# 농협, 수협, 산림조합 != 사회적경제
# 일본이주여성 일본어교실 != 상월마을학교 협동조합
# 경제적 어려움 != 문화행사 참여
# 항공식별구역 != 남중국해 문제
# 1992년 8월 24일 != 평화적 · 자주적 추진
# 보건사회연구소 != 경제적 부담감이 40 % 로 가장 높았는데 이는 60세 이상 노인들의 필요 의료서비스의 가장 큰 원인이이 경제적 어려움 때문이라고 보고한 김정희 ( 2008 ) 의 연구와 일치하였다. 또한 필요 의료서비스 미 검진을 개인과 가족의 수준을 넘어서 제도와 시스템적인 문제로 보며 해결되어야 한다고 최근 연구에서 보고하고 있다 ( Cavalieri, 2013 ). 이탈리아의 국가 추적조사로 분석한 Cavalieri의 연구에서 성별, 연령, 교육수준, 결혼유무, 고용상태, 소득수준, 건강수준, 만성질환 등을 통제한 상태에서도 제도와 시스템이 다른 지역 간의 필요 의료서비스 미 검진이 차이가 유의미하게 있음을 밝혔다. 2009년 보건사회연구소
# 좋은 성과에 대한 지속적인 경험 != 자기효능감
# 평등권 != 평등권 침해 차별행위로 본다는 헌재의 위헌결정 판례에 근거할 수 있다. 지난 2013년 11월 28일, ｢ 공직선거법 ｣ 제60조의3 제2항 제3호와 관련한 헌법재판소 위헌판결이 나왔다. 동 조항은 예비후보자의 배우자가 지정하는 동행 1인까지 명함 배포를 가능하게 한 것으로 배우자의 유무에 따른 예비후보자간 차별효과를 더욱 크게 한다는 이유로 위헌 결정을 내린 것이다. 그러나 함께 청구한 제1호 예비후보자의 배우자와 직계존비속에 대해서는, 과거 아래의 참조판례에서 보는 바와 같이 평등권 침해로 보기 어렵다는 결정이 내려진 바 있어 각하되었다. [SEP] 예비후보의 배우자
# 사물인터넷 != FIRE
# 복지시설 != 다양한 프로젝트를 개발할 수 있어야 한다. 정보기술이 융합된 복지서비스를 시설 전체로 확대하기 전에 앞에서 제시했던 여러 조건별 시범사업을 우선 실시해 시범사업에서 도출된 개선 사항을 반영한 후 본 사업이 추진되는 절차로 계획을 수립해야 한다. 독일이나 네덜란드의 경우, 정부나 지자체는 복지시설
# 노동계약 != 산재사고
# 반기문 사무총장 != 콩고민주공화국
# 국가과학기술위원회 != 기획재정부
# 공윤정 != 정승헌과 김금미
#  클라우드 기술 != 클라우드 컴퓨팅
# 미국 != 대협상
# 성장률 != 성장률이 저하
# 교사 != 묵독
# 이머징 기술 != 가능 기술
# 모호성 != 시스템 리스크의 모호성
# 상용직 != 고령층 임금근로자
# 공적이전소득 != 가처분소득
# 1626 696
# accuracy = 0.4280442804428044

# %%
# Out:
#           question_id                                            context  \
# 0     QUES_cyOI2451l1  생활방사선법 제23조(생활주변방사선 안전관리 실태조사 및 분석) 제1항에 따른 안전...
# 1     QUES_pz2vbWpWWo  또한 최근 위기청소년의 증가와 더불어 위기청소년 사회안전망 구축사업에서 가출청소년 ...
# 2     QUES_1g3jI4y7eo  고등학교 시기는 삶의 경험 속에서 지속적인 자아 탐색, 직업정보 검색 및 평가 등의...
# 3     QUES_qzwOZwaeeY  흥미롭게도 물류로봇과 배송로봇은 모두 세계최대의 전자상거래 기업인 Amazon에 의...
# 4     QUES_hfdtXCtdzf  미국의 사례를 통해 살펴보면 현행 우리나라의 활동지원서비스는 장애인케어서비스와 유사...
# ...               ...                                                ...
# 1621  QUES_JtsKBSQITG  고령층의 자영업 비중이 감소하면서 고령층 임금근로자 비중은 증가하고 있다. 2008...
# 1622  QUES_IajaDLmxvq  통계청의 가계동향조사에 의하면 60세 이상 노인 단독 가구의 처분가능소득(2015년...
# 1623  QUES_lR6hjzsptY  여성의 시간배분 결정에 있어서 중요한 가격요인 중 하나가 대체보육서비스 비용이다. ...
# 1624  QUES_ACwZJGYBfp  노르웨이 Cermaq사는 IBM Food Trust Labeyrie사와 협력하여 연...
# 1625  QUES_UB3Fj0NPIX  유엔식량농업기구(FAO)는 개발도상국의 수산업 역량 강화 및 지속가능성 제고를 위해...
#
#                                               question  \
# 0               어디서 모나자이트 취급사업장을 생활주변방사선 실태조사 대상으로 뽑았어
# 1                   어떤 문제가 위기청소년 사회안전망 형성사업에서 중요한 부분인가
# 2           어떤 시기 때문에 고등학생 시기가 혼란스럽고 정서적 불안을 느낄 가능성이 커
# 3                Amazon은 2013년 무슨 드론을 이용한 배송 서비스를 발표했지
# 4                  한국의 활동지원서비스는 미국의 예를 통해 살펴보면 뭐와 비슷할까
# ...                                                ...
# 1621          2016년 약 27프로로 꾸준히 증가하는 추세를 보인건 고령층의 무엇이지
# 1622     어떤 소득이 60세 이상 독거 노인 가구의 가처분소득에서 가장 높은 비율을 차지해
# 1623            무엇이 여성의 시간배분 결정에 있어서 주요한 가격소이 가운데 하나일까
# 1624  노르웨이 Cermaq사가 어느 회사와 협력하여 연어의 생산과 유통 정보시스템을 구축했니
# 1625      FAO와 중국이 남남협력과 연계한 개발도상국 지원 프로그램을 신설한 것은 언제야
#
#                         answer                      pred Unnamed: 5
# 0                   한국원자력안전기술원                한국원자력안전기술원        NaN
# 1                     가출청소년 문제                  가출청소년 문제        NaN
# 2                          탐색기                      고등학생        NaN
# 3                    Prime Air                 Prime Air        NaN
# 4                     장애인케어서비스                  장애인케어서비스        NaN
# ...                        ...                       ...        ...
# 1621                       상용직                 고령층 임금근로자        NaN
# 1622                    공적이전소득                     가처분소득        NaN
# 1623                대체보육서비스 비용                대체보육서비스 비용        NaN
# 1624  IBM Food Trust Labeyrie사  IBM Food Trust Labeyrie사        NaN
# 1625                     2009년                     2009년        NaN
#
# [1626 rows x 6 columns]
