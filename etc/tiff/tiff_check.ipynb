# %%
# !ls
# Out:
# image001.bmp  img000001.tif  tiff_check.ipynb

# %%
with open('img000001.tif', mode='rb') as file:
    tiff = file.read()

# %%
len(tiff)
# Out:
# 11611000

# %%
img = tiff[204:]
img = tiff[:1654*2339*3]

# %%
len(img)
# Out:
# 11606118

# %%
type(img)
# Out:
# bytes

# %%
import numpy as np

img_numpy = np.frombuffer(img, np.uint8)

# %%
img_numpy2 = np.reshape(img_numpy, (2339, 1654, 3))

# %%
import matplotlib.pyplot as plt

# %%
imgplot = plt.imshow(img_numpy2)
